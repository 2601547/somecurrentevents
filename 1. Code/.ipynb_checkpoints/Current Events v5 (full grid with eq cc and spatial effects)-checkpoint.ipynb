# %%
import numpy as np
import matplotlib.pyplot as plt


def stable_time_step(vx, Dx, Dz, dx, dz):
    dx2, dz2 = dx * dx, dz * dz
    max_diffusion = max(np.max(Dx), np.max(Dz), 1.0e-10)
    max_velocity = max(np.max(vx), 1.0e-10)
    diffusive_dt = dx2 * dz2 / (2 * max_diffusion * (dx2 + dz2))
    cfl_dt = dx / max_velocity
    dt = min(cfl_dt, diffusive_dt) * 0.5
    return min(dt, 0.002)  # MAKING THIS SMALLER WORKED


def euler_advection_diffusion_timestep(c0, vx, Dx, Dz, src, dt, dx, dz, inversion=True, upwind=True):
    nz, nx = c0.shape
    c = c0.copy()

    # Compute stability limits
    dt_advection = min(dx, dz) / np.max(np.abs(vx))
    dt_diffusion = min(dx**2, dz**2) / (2 * np.max([Dx.max(), Dz.max()]))
    dt_stable = min(dt_advection, dt_diffusion)
    
    if dt > dt_stable:
        print(f"Warning: dt={dt} exceeds stable timestep={dt_stable:.5f}. Adjusting dt.")
        dt = dt_stable
    
    # Storage for face-centered fluxes
    Fx = np.zeros((nz, nx + 1))
    Fz = np.zeros((nz + 1, nx))

    # Diffusive fluxes (per unit volume)
    Fx[:, 1:nx] = -Dx[:, 1:nx] * (c[:, 1:nx] - c[:, 0:nx-1]) / (dx * dx)
    Fz[1:nz, :] = -Dz[1:nz, :] * (c[1:nz, :] - c[0:nz-1, :]) / (dz * dz)

    # Advective fluxes
    if upwind:
        Fx[:, 1:nx] += np.where(vx[:, 1:nx] > 0,
                                vx[:, 1:nx] * c[:, 0:nx-1],
                                vx[:, 1:nx] * c[:, 1:nx]) / dx
    else:
        Fx[:, 1:nx] += vx[:, 1:nx] * (c[:, 0:nx-1] + c[:, 1:nx]) * 0.5 / dx

    # Update concentrations in interior cells
    c[0:nz, 0:nx] += dt * (
        -(Fx[0:nz, 1:nx+1] - Fx[0:nz, 0:nx])
        -(Fz[1:nz+1, 0:nx] - Fz[0:nz, 0:nx])
        + src[0:nz, 0:nx]
    )

    # Enforce non-negativity
    c = np.maximum(c, 0)

    return c


def create_grid(P0, Z0, domain_size, params):
    if P0.shape != Z0.shape:
        raise ValueError(f"P0 and Z0 must have the same shape. Got P0.shape={P0.shape}, Z0.shape={Z0.shape}")

    nz, nx = P0.shape
    dx = domain_size[0] / nx
    dz = domain_size[1] / nz

    vx = np.full((nz, nx + 1), params['current_velocity'])
    Dx = np.full((nz, nx + 1), params['diffusion'])
    Dz = np.full((nz + 1, nx), params['diffusion'])

    dt = stable_time_step(vx, Dx, Dz, dx, dz)
    print(f"Stable timestep: {dt:.5f}s")

    return {'nz': nz, 'nx': nx, 'dx': dx, 'dz': dz, 'vx': vx, 'Dx': Dx, 'Dz': Dz, 'dt': dt, 'P': P0.copy(), 'Z': Z0.copy()}


def lotka_volterra_sources(P, Z, params):
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    K = max(K, 1.0e-6)
    P = np.maximum(P, 1e-6)
    Z = np.maximum(Z, 1e-6)

    prey_growth = alpha * P * (1.0 - P / K)
    prey_death = -beta * P * Z
    predator_gain = delta * beta * P * Z
    predator_death = -gamma * Z

    src_prey = prey_growth + prey_death
    src_pred = predator_gain + predator_death

    # Add optional noise for debugging symmetry
   # noise = np.random.normal(0, 0.01, size=src_prey.shape)
   # src_prey += noise
   # src_pred += noise

    return src_prey, src_pred


def predator_prey_advection_diffusion_step(P, Z, vx, Dx, Dz, params, dt, dx, dz):
    src_prey, src_pred = lotka_volterra_sources(P, Z, params)

    P_updated = euler_advection_diffusion_timestep(P, vx, Dx, Dz, src_prey, dt, dx, dz)
    Z_updated = euler_advection_diffusion_timestep(Z, vx, Dx, Dz, src_pred, dt, dx, dz)

    return P_updated, Z_updated


def run_simulation_and_visualise():
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    nx, nz = 5, 5  # Grid size
    P0 = np.full((nz, nx), gamma / (delta * beta) + 200) # + np.random.uniform(-20, 20, (nz, nx))
    Z0 = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )
    domain_size = (10, 10)
    grid = create_grid(P0, Z0, domain_size, params)

    P = grid['P'].astype(np.float64)
    Z = grid['Z'].astype(np.float64)

    timesteps = 10000  # Adjust to a reasonable number for visualisation
    P_history = np.zeros((timesteps, nz, nx))
    Z_history = np.zeros((timesteps, nz, nx))

    # Store initial conditions
    P_history[0, :, :] = P
    Z_history[0, :, :] = Z

    for t in range(1, timesteps):
        P, Z = predator_prey_advection_diffusion_step(
            P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
        )
        P_history[t, :, :] = P
        Z_history[t, :, :] = Z

        # Debugging information
        if t % 20 == 0:
            print(f"Timestep {t}: P min={np.min(P):.4f}, P max={np.max(P):.4f}, Z min={np.min(Z):.4f}, Z max={np.max(Z):.4f}")

    # Visualisation of phase plots
    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    for i in range(nz):
        for j in range(nx):
            ax = axes[i, j]
            ax.plot(P_history[:, i, j], Z_history[:, i, j], label=f"Cell ({i}, {j})")
            ax.set_title(f"Phase Plot: Cell ({i}, {j})")
            ax.set_xlabel("Prey Density")
            ax.set_ylabel("Predator Density")
            ax.legend()
    plt.tight_layout()
    plt.show()


params = {
    'alpha': 1.0,
    'beta': 0.01,
    'delta': 0.25,
    'gamma': 1.0,
    'K': 1000000000000000000000000000000000000000000000000000000.0, # its high as I just wanted to include the code at this point rather than just think about parameters
    'current_velocity': 0.1,
    'diffusion': 0.01
}

run_simulation_and_visualise()
# Out:
# Stable timestep: 0.00200s
# Timestep 20: P min=598.5958, P max=600.9467, Z min=101.8091, Z max=102.2280
# Timestep 40: P min=596.7609, P max=601.3498, Z min=103.6342, Z max=104.5123
# Timestep 60: P min=594.4962, P max=601.1953, Z min=105.4706, Z max=106.8487
# Timestep 80: P min=591.8045, P max=600.4717, Z min=107.3131, Z max=109.2322
# Timestep 100: P min=588.6907, P max=599.1706, Z min=109.1563, Z max=111.6572
# Timestep 120: P min=585.1621, P max=597.2866, Z min=110.9944, Z max=114.1174
# Timestep 140: P min=581.2282, P max=594.8177, Z min=112.8216, Z max=116.6060
# Timestep 160: P min=576.9007, P max=591.7655, Z min=114.6316, Z max=119.1156
# Timestep 180: P min=572.1932, P max=588.1352, Z min=116.4182, Z max=121.6381
# Timestep 200: P min=567.1218, P max=583.9358, Z min=118.1751, Z max=124.1648
# Timestep 220: P min=561.7040, P max=579.1798, Z min=119.8957, Z max=126.6869
# Timestep 240: P min=555.9594, P max=573.8837, Z min=121.5737, Z max=129.1947
# Timestep 260: P min=549.9092, P max=568.0676, Z min=123.2026, Z max=131.6784
# Timestep 280: P min=543.5760, P max=561.7549, Z min=124.7762, Z max=134.1279
# Timestep 300: P min=536.9836, P max=554.9724, Z min=126.2885, Z max=136.5330
# Timestep 320: P min=530.1568, P max=547.7499, Z min=127.7334, Z max=138.8833
# Timestep 340: P min=523.1213, P max=540.1198, Z min=129.1055, Z max=141.1687
# Timestep 360: P min=515.9034, P max=532.1170, Z min=130.3995, Z max=143.3789
# Timestep 380: P min=508.5294, P max=523.7781, Z min=131.6105, Z max=145.5042
# Timestep 400: P min=501.0262, P max=515.1414, Z min=132.7341, Z max=147.5350
# Timestep 420: P min=493.4202, P max=506.2462, Z min=133.7663, Z max=149.4625
# Timestep 440: P min=485.7375, P max=497.1326, Z min=134.7035, Z max=151.2783
# Timestep 460: P min=478.0040, P max=487.8406, Z min=135.5429, Z max=152.9746
# Timestep 480: P min=470.2443, P max=478.4102, Z min=136.2819, Z max=154.5446
# Timestep 500: P min=462.4827, P max=468.8807, Z min=136.9187, Z max=155.9822
# Timestep 520: P min=454.7422, P max=459.2903, Z min=137.4519, Z max=157.2820
# Timestep 540: P min=447.0445, P max=449.6759, Z min=137.8807, Z max=158.4399
# Timestep 560: P min=439.4103, P max=440.4285, Z min=138.2048, Z max=159.4524
# Timestep 580: P min=430.5146, P max=431.9456, Z min=138.4246, Z max=160.3171
# Timestep 600: P min=421.0321, P max=424.4084, Z min=138.5408, Z max=161.0325
# Timestep 620: P min=411.6545, P max=417.0750, Z min=138.5545, Z max=161.5981
# Timestep 640: P min=402.4084, P max=409.8738, Z min=138.4676, Z max=162.0142
# Timestep 660: P min=393.3178, P max=402.8184, Z min=138.2820, Z max=162.2820
# Timestep 680: P min=384.4044, P max=395.9211, Z min=138.0004, Z max=162.4034
# Timestep 700: P min=375.6873, P max=389.1926, Z min=137.6254, Z max=162.3813
# Timestep 720: P min=367.1834, P max=382.6424, Z min=137.1603, Z max=162.2189
# Timestep 740: P min=358.9070, P max=376.2786, Z min=136.6085, Z max=161.9204
# Timestep 760: P min=350.8702, P max=370.1082, Z min=135.9736, Z max=161.4903
# Timestep 780: P min=343.0831, P max=364.1370, Z min=135.2594, Z max=160.9335
# Timestep 800: P min=335.5537, P max=358.3696, Z min=134.4700, Z max=160.2555
# Timestep 820: P min=328.2881, P max=352.8098, Z min=133.6093, Z max=159.4620
# Timestep 840: P min=321.2909, P max=347.4603, Z min=132.6817, Z max=158.5590
# Timestep 860: P min=314.5650, P max=342.3230, Z min=131.6914, Z max=157.5527
# Timestep 880: P min=308.1119, P max=337.3992, Z min=130.6426, Z max=156.4494
# Timestep 900: P min=301.9318, P max=332.6891, Z min=129.5397, Z max=155.2554
# Timestep 920: P min=296.0239, P max=328.1928, Z min=128.3870, Z max=153.9773
# Timestep 940: P min=290.3866, P max=323.9094, Z min=127.1885, Z max=152.6213
# Timestep 960: P min=285.0171, P max=319.8377, Z min=125.9485, Z max=151.1939
# Timestep 980: P min=279.9121, P max=315.9763, Z min=124.6710, Z max=149.7013
# Timestep 1000: P min=275.0679, P max=312.3231, Z min=123.3601, Z max=148.1495
# Timestep 1020: P min=270.4799, P max=308.8758, Z min=122.0195, Z max=146.5446
# Timestep 1040: P min=266.1436, P max=305.6319, Z min=120.6531, Z max=144.8923
# Timestep 1060: P min=262.0537, P max=302.5888, Z min=119.2644, Z max=143.1982
# Timestep 1080: P min=258.2051, P max=299.7436, Z min=117.8569, Z max=141.4677
# Timestep 1100: P min=254.5924, P max=297.0933, Z min=116.4339, Z max=139.7059
# Timestep 1120: P min=251.2100, P max=294.6348, Z min=114.9986, Z max=137.9178
# Timestep 1140: P min=248.0524, P max=292.3650, Z min=113.5542, Z max=136.1080
# Timestep 1160: P min=245.1141, P max=290.2807, Z min=112.1034, Z max=134.2810
# Timestep 1180: P min=242.3897, P max=288.3788, Z min=110.6490, Z max=132.4411
# Timestep 1200: P min=239.8737, P max=286.6561, Z min=109.1936, Z max=130.5921
# Timestep 1220: P min=237.5610, P max=285.1096, Z min=107.7397, Z max=128.7379
# Timestep 1240: P min=235.4464, P max=283.7363, Z min=106.2896, Z max=126.8820
# Timestep 1260: P min=233.5249, P max=282.5330, Z min=104.8454, Z max=125.0276
# Timestep 1280: P min=231.7919, P max=281.4971, Z min=103.4092, Z max=123.1779
# Timestep 1300: P min=230.2427, P max=280.6255, Z min=101.9829, Z max=121.3357
# Timestep 1320: P min=228.8729, P max=279.9157, Z min=100.5683, Z max=119.5036
# Timestep 1340: P min=227.6784, P max=279.3650, Z min=99.1670, Z max=117.6842
# Timestep 1360: P min=226.6552, P max=278.9709, Z min=97.7806, Z max=115.8798
# Timestep 1380: P min=225.7995, P max=278.7310, Z min=96.4104, Z max=114.0923
# Timestep 1400: P min=225.1079, P max=278.6431, Z min=95.0579, Z max=112.3239
# Timestep 1420: P min=224.5770, P max=278.7049, Z min=93.7241, Z max=110.5762
# Timestep 1440: P min=224.2036, P max=278.9144, Z min=92.4103, Z max=108.8509
# Timestep 1460: P min=223.9850, P max=279.2697, Z min=91.1175, Z max=107.1494
# Timestep 1480: P min=223.9183, P max=279.7689, Z min=89.8465, Z max=105.4731
# Timestep 1500: P min=224.0012, P max=280.4102, Z min=88.5983, Z max=103.8233
# Timestep 1520: P min=224.2312, P max=281.1921, Z min=87.3736, Z max=102.2010
# Timestep 1540: P min=224.6064, P max=282.1130, Z min=86.1731, Z max=100.6072
# Timestep 1560: P min=225.1247, P max=283.1715, Z min=84.9975, Z max=99.0428
# Timestep 1580: P min=225.7844, P max=284.3663, Z min=83.8474, Z max=97.5086
# Timestep 1600: P min=226.5840, P max=285.6960, Z min=82.7232, Z max=96.0053
# Timestep 1620: P min=227.5220, P max=287.1596, Z min=81.6255, Z max=94.5336
# Timestep 1640: P min=228.5972, P max=288.7559, Z min=80.5547, Z max=93.0939
# Timestep 1660: P min=229.8085, P max=290.4840, Z min=79.5111, Z max=91.6868
# Timestep 1680: P min=231.1548, P max=292.3428, Z min=78.4950, Z max=90.3126
# Timestep 1700: P min=232.6355, P max=294.3315, Z min=77.5068, Z max=88.9717
# Timestep 1720: P min=234.2497, P max=296.4493, Z min=76.5468, Z max=87.6645
# Timestep 1740: P min=235.9969, P max=298.6954, Z min=75.6151, Z max=86.3912
# Timestep 1760: P min=237.8767, P max=301.0690, Z min=74.7120, Z max=85.1519
# Timestep 1780: P min=239.8887, P max=303.5694, Z min=73.8377, Z max=83.9469
# Timestep 1800: P min=242.0325, P max=306.1959, Z min=72.9923, Z max=82.7763
# Timestep 1820: P min=244.3080, P max=308.9478, Z min=72.1759, Z max=81.6402
# Timestep 1840: P min=246.7152, P max=311.8246, Z min=71.3888, Z max=80.5387
# Timestep 1860: P min=249.2540, P max=314.8254, Z min=70.6309, Z max=79.4719
# Timestep 1880: P min=251.9244, P max=317.9497, Z min=69.9025, Z max=78.4399
# Timestep 1900: P min=254.7265, P max=321.1967, Z min=69.2037, Z max=77.4425
# Timestep 1920: P min=257.6605, P max=324.5657, Z min=68.5344, Z max=76.4800
# Timestep 1940: P min=260.7264, P max=328.0560, Z min=67.8949, Z max=75.5522
# Timestep 1960: P min=263.9246, P max=331.6668, Z min=67.2853, Z max=74.6592
# Timestep 1980: P min=267.2552, P max=335.3971, Z min=66.7055, Z max=73.8011
# Timestep 2000: P min=270.7183, P max=339.2461, Z min=66.1559, Z max=72.9777
# Timestep 2020: P min=274.3143, P max=343.2128, Z min=65.6363, Z max=72.1892
# Timestep 2040: P min=278.0433, P max=347.2959, Z min=65.1471, Z max=71.4355
# Timestep 2060: P min=281.9055, P max=351.4944, Z min=64.6883, Z max=70.7167
# Timestep 2080: P min=285.9009, P max=355.8069, Z min=64.2600, Z max=70.0328
# Timestep 2100: P min=290.0296, P max=360.2319, Z min=63.8624, Z max=69.3839
# Timestep 2120: P min=294.2916, P max=364.7678, Z min=63.4957, Z max=68.7700
# Timestep 2140: P min=298.6868, P max=369.4128, Z min=63.1601, Z max=68.1912
# Timestep 2160: P min=303.2150, P max=374.1649, Z min=62.8558, Z max=67.6476
# Timestep 2180: P min=307.8758, P max=379.0221, Z min=62.5830, Z max=67.1393
# Timestep 2200: P min=312.6687, P max=383.9819, Z min=62.3419, Z max=66.6666
# Timestep 2220: P min=317.5933, P max=389.0418, Z min=62.1329, Z max=66.2295
# Timestep 2240: P min=322.6486, P max=394.1989, Z min=61.9562, Z max=65.8282
# Timestep 2260: P min=327.8338, P max=399.4502, Z min=61.8122, Z max=65.4631
# Timestep 2280: P min=333.1475, P max=404.7922, Z min=61.7011, Z max=65.1344
# Timestep 2300: P min=338.5885, P max=410.2214, Z min=61.6234, Z max=64.8423
# Timestep 2320: P min=344.1549, P max=415.7337, Z min=61.5795, Z max=64.5873
# Timestep 2340: P min=349.8449, P max=421.3248, Z min=61.5697, Z max=64.3696
# Timestep 2360: P min=355.6562, P max=426.9899, Z min=61.5946, Z max=64.1897
# Timestep 2380: P min=361.5861, P max=432.7242, Z min=61.6546, Z max=64.0481
# Timestep 2400: P min=367.6317, P max=438.5220, Z min=61.7503, Z max=63.9452
# Timestep 2420: P min=373.7896, P max=444.3775, Z min=61.8821, Z max=63.8816
# Timestep 2440: P min=380.0561, P max=450.2844, Z min=62.0507, Z max=63.8579
# Timestep 2460: P min=386.4270, P max=456.2360, Z min=62.2566, Z max=63.8747
# Timestep 2480: P min=392.8974, P max=462.2249, Z min=62.5005, Z max=63.9662
# Timestep 2500: P min=399.4622, P max=468.2434, Z min=62.7830, Z max=64.1839
# Timestep 2520: P min=406.1157, P max=474.2832, Z min=63.0878, Z max=64.4433
# Timestep 2540: P min=412.8515, P max=480.3356, Z min=63.3449, Z max=64.7451
# Timestep 2560: P min=419.6625, P max=486.3912, Z min=63.6445, Z max=65.0902
# Timestep 2580: P min=426.5413, P max=492.4401, Z min=63.9873, Z max=65.4794
# Timestep 2600: P min=433.4794, P max=498.4718, Z min=64.3743, Z max=65.9135
# Timestep 2620: P min=440.4679, P max=504.4754, Z min=64.8064, Z max=66.3936
# Timestep 2640: P min=447.4971, P max=510.4391, Z min=65.2847, Z max=66.9205
# Timestep 2660: P min=454.5563, P max=516.3508, Z min=65.8099, Z max=67.4952
# Timestep 2680: P min=461.6342, P max=522.1977, Z min=66.3833, Z max=68.1186
# Timestep 2700: P min=468.7186, P max=527.9664, Z min=67.0058, Z max=68.7917
# Timestep 2720: P min=475.7964, P max=533.6429, Z min=67.6785, Z max=69.5154
# Timestep 2740: P min=482.8537, P max=539.2129, Z min=68.4023, Z max=70.2907
# Timestep 2760: P min=489.8757, P max=544.6613, Z min=69.1785, Z max=71.1186
# Timestep 2780: P min=496.8464, P max=549.9726, Z min=70.0080, Z max=72.0000
# Timestep 2800: P min=503.7494, P max=555.1309, Z min=70.8919, Z max=72.9357
# Timestep 2820: P min=510.5668, P max=560.1198, Z min=71.8311, Z max=73.9266
# Timestep 2840: P min=517.2803, P max=564.9227, Z min=72.8266, Z max=74.9734
# Timestep 2860: P min=523.8703, P max=569.5225, Z min=73.8793, Z max=76.0768
# Timestep 2880: P min=530.3166, P max=573.9020, Z min=74.9901, Z max=77.2374
# Timestep 2900: P min=536.5981, P max=578.0438, Z min=76.1596, Z max=78.4557
# Timestep 2920: P min=542.6928, P max=581.9306, Z min=77.3885, Z max=79.7319
# Timestep 2940: P min=548.5782, P max=585.5450, Z min=78.6774, Z max=81.0663
# Timestep 2960: P min=554.2311, P max=588.8698, Z min=80.0265, Z max=82.4589
# Timestep 2980: P min=559.6278, P max=591.8881, Z min=81.4360, Z max=83.9094
# Timestep 3000: P min=564.7441, P max=594.5835, Z min=82.9059, Z max=85.4174
# Timestep 3020: P min=569.5555, P max=596.9399, Z min=84.4359, Z max=86.9822
# Timestep 3040: P min=574.0377, P max=598.9421, Z min=86.0256, Z max=88.6029
# Timestep 3060: P min=578.1660, P max=600.5758, Z min=87.6741, Z max=90.2781
# Timestep 3080: P min=581.9163, P max=601.8275, Z min=89.3803, Z max=92.0063
# Timestep 3100: P min=585.2647, P max=602.6849, Z min=91.1429, Z max=93.7855
# Timestep 3120: P min=588.1881, P max=603.1372, Z min=92.9600, Z max=95.6134
# Timestep 3140: P min=590.6644, P max=603.1747, Z min=94.8294, Z max=97.4872
# Timestep 3160: P min=592.6724, P max=602.7896, Z min=96.7486, Z max=99.4039
# Timestep 3180: P min=594.1926, P max=601.9758, Z min=98.7146, Z max=101.3598
# Timestep 3200: P min=594.7749, P max=601.4859, Z min=100.7237, Z max=103.3510
# Timestep 3220: P min=593.7629, P max=601.0745, Z min=102.7722, Z max=105.3730
# Timestep 3240: P min=592.2691, P max=600.1672, Z min=104.8220, Z max=107.4210
# Timestep 3260: P min=590.2916, P max=598.7584, Z min=106.6800, Z max=109.4895
# Timestep 3280: P min=587.8311, P max=596.8450, Z min=108.5411, Z max=111.5730
# Timestep 3300: P min=584.8911, P max=594.4267, Z min=110.3995, Z max=113.6652
# Timestep 3320: P min=581.4777, P max=591.5059, Z min=112.2495, Z max=115.8872
# Timestep 3340: P min=577.5995, P max=588.0879, Z min=114.0847, Z max=118.3238
# Timestep 3360: P min=573.2682, P max=584.1808, Z min=115.8989, Z max=120.7738
# Timestep 3380: P min=568.4980, P max=579.7959, Z min=117.6856, Z max=123.2290
# Timestep 3400: P min=563.3054, P max=575.2971, Z min=119.4383, Z max=125.6809
# Timestep 3420: P min=557.7099, P max=570.2908, Z min=121.1505, Z max=128.1205
# Timestep 3440: P min=551.7329, P max=564.7780, Z min=122.8157, Z max=130.5385
# Timestep 3460: P min=545.3980, P max=558.7803, Z min=124.4274, Z max=132.9252
# Timestep 3480: P min=538.7307, P max=552.3224, Z min=125.9793, Z max=135.2710
# Timestep 3500: P min=531.7582, P max=545.4318, Z min=127.4655, Z max=137.5659
# Timestep 3520: P min=524.5090, P max=538.1387, Z min=128.8801, Z max=139.8002
# Timestep 3540: P min=517.0127, P max=530.4757, Z min=130.2177, Z max=141.9642
# Timestep 3560: P min=509.2999, P max=522.4773, Z min=131.4731, Z max=144.0485
# Timestep 3580: P min=501.4012, P max=514.1793, Z min=132.6416, Z max=146.0439
# Timestep 3600: P min=493.3480, P max=505.8167, Z min=133.7192, Z max=147.9417
# Timestep 3620: P min=485.1711, P max=497.4616, Z min=134.7019, Z max=149.7338
# Timestep 3640: P min=476.9014, P max=488.9718, Z min=135.5866, Z max=151.4127
# Timestep 3660: P min=468.5687, P max=480.3797, Z min=136.3706, Z max=152.9716
# Timestep 3680: P min=460.2022, P max=471.7174, Z min=137.0518, Z max=154.4043
# Timestep 3700: P min=451.8302, P max=463.0160, Z min=137.6286, Z max=155.7056
# Timestep 3720: P min=443.4792, P max=454.3054, Z min=138.1001, Z max=156.8712
# Timestep 3740: P min=435.1749, P max=445.6143, Z min=138.4656, Z max=157.8974
# Timestep 3760: P min=426.9410, P max=436.9696, Z min=138.7254, Z max=158.7816
# Timestep 3780: P min=418.7998, P max=428.3968, Z min=138.8801, Z max=159.5221
# Timestep 3800: P min=410.7717, P max=419.9197, Z min=138.9306, Z max=160.1181
# Timestep 3820: P min=402.8755, P max=412.3630, Z min=138.8787, Z max=160.5696
# Timestep 3840: P min=395.1282, P max=405.1949, Z min=138.7262, Z max=160.8773
# Timestep 3860: P min=387.0777, P max=398.1830, Z min=138.4756, Z max=161.0429
# Timestep 3880: P min=378.5064, P max=391.3389, Z min=138.1297, Z max=161.0686
# Timestep 3900: P min=370.1326, P max=384.6723, Z min=137.6916, Z max=160.9575
# Timestep 3920: P min=361.9711, P max=378.1921, Z min=137.1645, Z max=160.7132
# Timestep 3940: P min=354.0347, P max=371.9054, Z min=136.5522, Z max=160.3397
# Timestep 3960: P min=346.3342, P max=365.8186, Z min=135.8584, Z max=159.8417
# Timestep 3980: P min=338.8782, P max=359.9366, Z min=135.0873, Z max=159.2243
# Timestep 4000: P min=331.6738, P max=354.2634, Z min=134.2428, Z max=158.4926
# Timestep 4020: P min=324.7261, P max=348.8021, Z min=133.3293, Z max=157.6524
# Timestep 4040: P min=318.0389, P max=343.5549, Z min=132.3510, Z max=156.7094
# Timestep 4060: P min=311.6145, P max=338.5230, Z min=131.3123, Z max=155.6698
# Timestep 4080: P min=305.4540, P max=333.7070, Z min=130.2175, Z max=154.5395
# Timestep 4100: P min=299.5572, P max=329.1070, Z min=129.0710, Z max=153.3247
# Timestep 4120: P min=293.9232, P max=324.7223, Z min=127.8770, Z max=152.0315
# Timestep 4140: P min=288.5500, P max=320.5518, Z min=126.6398, Z max=150.6661
# Timestep 4160: P min=283.4351, P max=316.5939, Z min=125.3635, Z max=149.2344
# Timestep 4180: P min=278.5751, P max=312.8467, Z min=124.0522, Z max=147.7425
# Timestep 4200: P min=273.9663, P max=309.3080, Z min=122.7098, Z max=146.1961
# Timestep 4220: P min=269.6044, P max=305.9753, Z min=121.3401, Z max=144.6008
# Timestep 4240: P min=265.4851, P max=302.8457, Z min=119.9469, Z max=142.9622
# Timestep 4260: P min=261.6034, P max=299.9165, Z min=118.5337, Z max=141.2854
# Timestep 4280: P min=257.9543, P max=297.1845, Z min=117.1039, Z max=139.5757
# Timestep 4300: P min=254.5329, P max=294.6467, Z min=115.6608, Z max=137.8378
# Timestep 4320: P min=251.3339, P max=292.2999, Z min=114.2076, Z max=136.0764
# Timestep 4340: P min=248.3521, P max=290.1408, Z min=112.7471, Z max=134.2960
# Timestep 4360: P min=245.5823, P max=288.1663, Z min=111.2822, Z max=132.5006
# Timestep 4380: P min=243.0195, P max=286.3730, Z min=109.8156, Z max=130.6944
# Timestep 4400: P min=240.6587, P max=284.7580, Z min=108.3499, Z max=128.8810
# Timestep 4420: P min=238.4949, P max=283.3180, Z min=106.8872, Z max=127.0639
# Timestep 4440: P min=236.5233, P max=282.0499, Z min=105.4300, Z max=125.2466
# Timestep 4460: P min=234.7394, P max=280.9509, Z min=103.9804, Z max=123.4320
# Timestep 4480: P min=233.1387, P max=280.0180, Z min=102.5401, Z max=121.6232
# Timestep 4500: P min=231.7170, P max=279.2484, Z min=101.1112, Z max=119.8227
# Timestep 4520: P min=230.4701, P max=278.6395, Z min=99.6953, Z max=118.0331
# Timestep 4540: P min=229.3942, P max=278.1887, Z min=98.2939, Z max=116.2568
# Timestep 4560: P min=228.4857, P max=277.8935, Z min=96.9086, Z max=114.4959
# Timestep 4580: P min=227.7409, P max=277.7516, Z min=95.5407, Z max=112.7523
# Timestep 4600: P min=227.1567, P max=277.7606, Z min=94.1914, Z max=111.0280
# Timestep 4620: P min=226.7300, P max=277.9186, Z min=92.8619, Z max=109.3245
# Timestep 4640: P min=226.4579, P max=278.2235, Z min=91.5533, Z max=107.6434
# Timestep 4660: P min=226.3377, P max=278.6734, Z min=90.2664, Z max=105.9862
# Timestep 4680: P min=226.3669, P max=279.2665, Z min=89.0023, Z max=104.3540
# Timestep 4700: P min=226.5431, P max=280.0011, Z min=87.7617, Z max=102.7481
# Timestep 4720: P min=226.8644, P max=280.8757, Z min=86.5453, Z max=101.1695
# Timestep 4740: P min=227.3287, P max=281.8888, Z min=85.3538, Z max=99.6191
# Timestep 4760: P min=227.9343, P max=283.0390, Z min=84.1878, Z max=98.0978
# Timestep 4780: P min=228.6796, P max=284.3251, Z min=83.0477, Z max=96.6063
# Timestep 4800: P min=229.5631, P max=285.7458, Z min=81.9342, Z max=95.1453
# Timestep 4820: P min=230.5835, P max=287.3001, Z min=80.8477, Z max=93.7154
# Timestep 4840: P min=231.7397, P max=288.9868, Z min=79.7884, Z max=92.3171
# Timestep 4860: P min=233.0306, P max=290.8051, Z min=78.7568, Z max=90.9509
# Timestep 4880: P min=234.4555, P max=292.7540, Z min=77.7532, Z max=89.6172
# Timestep 4900: P min=236.0134, P max=294.8327, Z min=76.7778, Z max=88.3162
# Timestep 4920: P min=237.7040, P max=297.0403, Z min=75.8308, Z max=87.0484
# Timestep 4940: P min=239.5265, P max=299.3762, Z min=74.9126, Z max=85.8140
# Timestep 4960: P min=241.4805, P max=301.8397, Z min=74.0232, Z max=84.6131
# Timestep 4980: P min=243.5658, P max=304.4300, Z min=73.1628, Z max=83.4460
# Timestep 5000: P min=245.7822, P max=307.1464, Z min=72.3316, Z max=82.3128
# Timestep 5020: P min=248.1293, P max=309.9884, Z min=71.5297, Z max=81.2137
# Timestep 5040: P min=250.6073, P max=312.9553, Z min=70.7572, Z max=80.1486
# Timestep 5060: P min=253.2159, P max=316.0464, Z min=70.0143, Z max=79.1177
# Timestep 5080: P min=255.9553, P max=319.2610, Z min=69.3010, Z max=78.1211
# Timestep 5100: P min=258.8256, P max=322.5986, Z min=68.6174, Z max=77.1588
# Timestep 5120: P min=261.8267, P max=326.0583, Z min=67.9637, Z max=76.2308
# Timestep 5140: P min=264.9589, P max=329.6394, Z min=67.3398, Z max=75.3372
# Timestep 5160: P min=268.2223, P max=333.3410, Z min=66.7460, Z max=74.4780
# Timestep 5180: P min=271.6171, P max=337.1624, Z min=66.1823, Z max=73.6533
# Timestep 5200: P min=275.1433, P max=341.1025, Z min=65.6488, Z max=72.8630
# Timestep 5220: P min=278.8011, P max=345.1603, Z min=65.1456, Z max=72.1072
# Timestep 5240: P min=282.5906, P max=349.3346, Z min=64.6729, Z max=71.3859
# Timestep 5260: P min=286.5119, P max=353.6242, Z min=64.2308, Z max=70.6992
# Timestep 5280: P min=290.5649, P max=358.0277, Z min=63.8195, Z max=70.0472
# Timestep 5300: P min=294.7496, P max=362.5435, Z min=63.4390, Z max=69.4299
# Timestep 5320: P min=299.0658, P max=367.1700, Z min=63.0896, Z max=68.8474
# Timestep 5340: P min=303.5132, P max=371.9053, Z min=62.7715, Z max=68.2998
# Timestep 5360: P min=308.0915, P max=376.7473, Z min=62.4850, Z max=67.7874
# Timestep 5380: P min=312.8001, P max=381.6939, Z min=62.2301, Z max=67.3101
# Timestep 5400: P min=317.6385, P max=386.7425, Z min=62.0073, Z max=66.8682
# Timestep 5420: P min=322.6058, P max=391.8903, Z min=61.8167, Z max=66.4620
# Timestep 5440: P min=327.7009, P max=397.1346, Z min=61.6588, Z max=66.0915
# Timestep 5460: P min=332.9228, P max=402.4720, Z min=61.5338, Z max=65.7572
# Timestep 5480: P min=338.2698, P max=407.8989, Z min=61.4421, Z max=65.4593
# Timestep 5500: P min=343.7404, P max=413.4116, Z min=61.3841, Z max=65.1981
# Timestep 5520: P min=349.3326, P max=419.0058, Z min=61.3602, Z max=64.9740
# Timestep 5540: P min=355.0441, P max=424.6770, Z min=61.3708, Z max=64.7874
# Timestep 5560: P min=360.8723, P max=430.4204, Z min=61.4165, Z max=64.6388
# Timestep 5580: P min=366.8142, P max=436.2306, Z min=61.4977, Z max=64.5286
# Timestep 5600: P min=372.8666, P max=442.1019, Z min=61.6150, Z max=64.4573
# Timestep 5620: P min=379.0258, P max=448.0281, Z min=61.7689, Z max=64.4256
# Timestep 5640: P min=385.2875, P max=454.0027, Z min=61.9601, Z max=64.4340
# Timestep 5660: P min=391.6471, P max=460.0186, Z min=62.1891, Z max=64.5012
# Timestep 5680: P min=398.0995, P max=466.0682, Z min=62.4566, Z max=64.7368
# Timestep 5700: P min=404.6391, P max=472.1434, Z min=62.7633, Z max=65.0141
# Timestep 5720: P min=411.2596, P max=478.2356, Z min=63.0582, Z max=65.3338
# Timestep 5740: P min=417.9543, P max=484.3357, Z min=63.3346, Z max=65.6967
# Timestep 5760: P min=424.7155, P max=490.4338, Z min=63.6539, Z max=66.1037
# Timestep 5780: P min=431.5354, P max=496.5198, Z min=64.0170, Z max=66.5556
# Timestep 5800: P min=438.4050, P max=502.5828, Z min=64.4249, Z max=67.0533
# Timestep 5820: P min=445.3149, P max=508.6112, Z min=64.8785, Z max=67.5977
# Timestep 5840: P min=452.2547, P max=514.5931, Z min=65.3788, Z max=68.1898
# Timestep 5860: P min=459.2134, P max=520.5157, Z min=65.9268, Z max=68.8304
# Timestep 5880: P min=466.1792, P max=526.3658, Z min=66.5235, Z max=69.5205
# Timestep 5900: P min=473.1392, P max=532.1297, Z min=67.1700, Z max=70.2611
# Timestep 5920: P min=480.0801, P max=537.7928, Z min=67.8674, Z max=71.0530
# Timestep 5940: P min=486.9872, P max=543.3404, Z min=68.6167, Z max=71.8971
# Timestep 5960: P min=493.8454, P max=548.7568, Z min=69.4190, Z max=72.7942
# Timestep 5980: P min=500.6384, P max=554.0263, Z min=70.2754, Z max=73.7453
# Timestep 6000: P min=507.3491, P max=559.1325, Z min=71.1868, Z max=74.7510
# Timestep 6020: P min=513.9595, P max=564.0585, Z min=72.1543, Z max=75.8121
# Timestep 6040: P min=520.4508, P max=568.7873, Z min=73.1788, Z max=76.9290
# Timestep 6060: P min=526.8033, P max=573.3016, Z min=74.2612, Z max=78.1024
# Timestep 6080: P min=532.9966, P max=577.5838, Z min=75.4024, Z max=79.3326
# Timestep 6100: P min=539.0094, P max=581.6162, Z min=76.6029, Z max=80.6197
# Timestep 6120: P min=544.8199, P max=585.3814, Z min=77.8635, Z max=81.9639
# Timestep 6140: P min=550.4056, P max=588.8617, Z min=79.1845, Z max=83.3650
# Timestep 6160: P min=555.7434, P max=592.0399, Z min=80.5662, Z max=84.8227
# Timestep 6180: P min=560.8100, P max=594.8990, Z min=82.0087, Z max=86.3363
# Timestep 6200: P min=565.5817, P max=597.4226, Z min=83.5120, Z max=87.9052
# Timestep 6220: P min=570.0346, P max=599.5950, Z min=85.0756, Z max=89.5281
# Timestep 6240: P min=574.1451, P max=601.4011, Z min=86.6989, Z max=91.2037
# Timestep 6260: P min=577.8895, P max=602.8268, Z min=88.3811, Z max=92.9302
# Timestep 6280: P min=581.2448, P max=603.8592, Z min=90.1208, Z max=94.7054
# Timestep 6300: P min=584.1883, P max=604.4866, Z min=91.9165, Z max=96.5270
# Timestep 6320: P min=586.6984, P max=604.6987, Z min=93.7661, Z max=98.3920
# Timestep 6340: P min=588.7546, P max=604.4866, Z min=95.6674, Z max=100.2973
# Timestep 6360: P min=590.3375, P max=603.8435, Z min=97.6176, Z max=102.2390
# Timestep 6380: P min=591.4296, P max=602.7642, Z min=99.6132, Z max=104.2131
# Timestep 6400: P min=590.5115, P max=602.1787, Z min=101.6507, Z max=106.2152
# Timestep 6420: P min=588.8420, P max=601.5355, Z min=103.7259, Z max=108.2401
# Timestep 6440: P min=586.6992, P max=600.3899, Z min=105.8340, Z max=110.2826
# Timestep 6460: P min=584.0850, P max=598.7375, Z min=107.8820, Z max=112.3369
# Timestep 6480: P min=581.0037, P max=596.5764, Z min=109.7591, Z max=114.3968
# Timestep 6500: P min=577.4624, P max=593.9077, Z min=111.6303, Z max=116.4558
# Timestep 6520: P min=573.4705, P max=590.7350, Z min=113.4893, Z max=118.5073
# Timestep 6540: P min=569.0405, P max=587.0651, Z min=115.3298, Z max=120.5440
# Timestep 6560: P min=564.1869, P max=582.9078, Z min=117.1453, Z max=122.5588
# Timestep 6580: P min=558.9271, P max=578.2755, Z min=118.9292, Z max=124.8596
# Timestep 6600: P min=553.2806, P max=573.1839, Z min=120.6750, Z max=127.2560
# Timestep 6620: P min=547.2691, P max=567.6511, Z min=122.3758, Z max=129.6329
# Timestep 6640: P min=540.9162, P max=561.6982, Z min=124.0253, Z max=131.9812
# Timestep 6660: P min=534.2474, P max=555.3486, Z min=125.6169, Z max=134.2913
# Timestep 6680: P min=527.2894, P max=548.6279, Z min=127.1445, Z max=136.5537
# Timestep 6700: P min=520.0705, P max=541.5637, Z min=128.6020, Z max=138.7591
# Timestep 6720: P min=512.6197, P max=534.1855, Z min=129.9837, Z max=140.8978
# Timestep 6740: P min=504.9667, P max=526.5242, Z min=131.2844, Z max=142.9607
# Timestep 6760: P min=497.1418, P max=518.6115, Z min=132.4990, Z max=144.9390
# Timestep 6780: P min=489.1750, P max=510.4804, Z min=133.6232, Z max=146.8240
# Timestep 6800: P min=481.0966, P max=502.1638, Z min=134.6529, Z max=148.6077
# Timestep 6820: P min=472.9362, P max=493.6952, Z min=135.5846, Z max=150.2827
# Timestep 6840: P min=464.7226, P max=485.1077, Z min=136.4155, Z max=151.8421
# Timestep 6860: P min=456.4841, P max=476.4338, Z min=137.1432, Z max=153.2799
# Timestep 6880: P min=448.2475, P max=467.7054, Z min=137.7658, Z max=154.5908
# Timestep 6900: P min=440.0385, P max=458.9533, Z min=138.2821, Z max=155.7701
# Timestep 6920: P min=431.8816, P max=450.2070, Z min=138.6916, Z max=156.8143
# Timestep 6940: P min=423.7995, P max=441.4947, Z min=138.9939, Z max=157.7205
# Timestep 6960: P min=415.8133, P max=432.8427, Z min=139.1897, Z max=158.4868
# Timestep 6980: P min=407.9426, P max=424.2760, Z min=139.2797, Z max=159.1120
# Timestep 7000: P min=400.2052, P max=415.8173, Z min=139.2655, Z max=159.5959
# Timestep 7020: P min=392.6173, P max=407.7501, Z min=139.1489, Z max=159.9391
# Timestep 7040: P min=385.1932, P max=400.6232, Z min=138.9322, Z max=160.1427
# Timestep 7060: P min=377.9457, P max=393.6622, Z min=138.6181, Z max=160.2089
# Timestep 7080: P min=370.8859, P max=386.8778, Z min=138.2096, Z max=160.1403
# Timestep 7100: P min=364.0236, P max=380.2791, Z min=137.7100, Z max=159.9402
# Timestep 7120: P min=356.6661, P max=373.8739, Z min=137.1230, Z max=159.6124
# Timestep 7140: P min=349.0084, P max=367.6688, Z min=136.4523, Z max=159.1612
# Timestep 7160: P min=341.5860, P max=361.6693, Z min=135.7020, Z max=158.5913
# Timestep 7180: P min=334.4064, P max=355.8797, Z min=134.8761, Z max=157.9077
# Timestep 7200: P min=327.4756, P max=350.3033, Z min=133.9791, Z max=157.1160
# Timestep 7220: P min=320.7978, P max=344.9425, Z min=133.0151, Z max=156.2216
# Timestep 7240: P min=314.3759, P max=339.7989, Z min=131.9887, Z max=155.2302
# Timestep 7260: P min=308.2117, P max=334.8732, Z min=130.9041, Z max=154.1479
# Timestep 7280: P min=302.3055, P max=330.1656, Z min=129.7658, Z max=152.9805
# Timestep 7300: P min=296.6570, P max=325.6757, Z min=128.5782, Z max=151.7340
# Timestep 7320: P min=291.2646, P max=321.4022, Z min=127.3456, Z max=150.4143
# Timestep 7340: P min=286.1264, P max=317.3439, Z min=126.0722, Z max=149.0274
# Timestep 7360: P min=281.2394, P max=313.4987, Z min=124.7620, Z max=147.5791
# Timestep 7380: P min=276.6003, P max=309.8645, Z min=123.4193, Z max=146.0751
# Timestep 7400: P min=272.2054, P max=306.4388, Z min=122.0478, Z max=144.5209
# Timestep 7420: P min=268.0504, P max=303.2187, Z min=120.6514, Z max=142.9220
# Timestep 7440: P min=264.1309, P max=300.2015, Z min=119.2337, Z max=141.2836
# Timestep 7460: P min=260.4423, P max=297.3839, Z min=117.7982, Z max=139.6107
# Timestep 7480: P min=256.9796, P max=294.7629, Z min=116.3483, Z max=137.9081
# Timestep 7500: P min=253.7380, P max=292.3351, Z min=114.8871, Z max=136.1805
# Timestep 7520: P min=250.7125, P max=290.0974, Z min=113.4178, Z max=134.4323
# Timestep 7540: P min=247.8982, P max=288.0465, Z min=111.9432, Z max=132.6677
# Timestep 7560: P min=245.2901, P max=286.1789, Z min=110.4660, Z max=130.8906
# Timestep 7580: P min=242.8833, P max=284.4916, Z min=108.9889, Z max=129.1049
# Timestep 7600: P min=240.6731, P max=282.9813, Z min=107.5143, Z max=127.3141
# Timestep 7620: P min=238.6548, P max=281.6449, Z min=106.0445, Z max=125.5215
# Timestep 7640: P min=236.8239, P max=280.4793, Z min=104.5817, Z max=123.7302
# Timestep 7660: P min=235.1760, P max=279.4816, Z min=103.1278, Z max=121.9433
# Timestep 7680: P min=233.7071, P max=278.6488, Z min=101.6848, Z max=120.1634
# Timestep 7700: P min=232.4129, P max=277.9784, Z min=100.2544, Z max=118.3930
# Timestep 7720: P min=231.2898, P max=277.4675, Z min=98.8383, Z max=116.6347
# Timestep 7740: P min=230.3340, P max=277.1136, Z min=97.4379, Z max=114.8904
# Timestep 7760: P min=229.5421, P max=276.9145, Z min=96.0546, Z max=113.1624
# Timestep 7780: P min=228.9108, P max=276.8676, Z min=94.6898, Z max=111.4523
# Timestep 7800: P min=228.4371, P max=276.9709, Z min=93.3446, Z max=109.7621
# Timestep 7820: P min=228.1181, P max=277.2222, Z min=92.0201, Z max=108.0932
# Timestep 7840: P min=227.9511, P max=277.6197, Z min=90.7173, Z max=106.4471
# Timestep 7860: P min=227.9336, P max=278.1615, Z min=89.4371, Z max=104.8251
# Timestep 7880: P min=228.0632, P max=278.8458, Z min=88.1804, Z max=103.2283
# Timestep 7900: P min=228.3379, P max=279.6710, Z min=86.9479, Z max=101.6580
# Timestep 7920: P min=228.7557, P max=280.6357, Z min=85.7402, Z max=100.1151
# Timestep 7940: P min=229.3147, P max=281.7384, Z min=84.5581, Z max=98.6004
# Timestep 7960: P min=230.0134, P max=282.9778, Z min=83.4019, Z max=97.1148
# Timestep 7980: P min=230.8502, P max=284.3526, Z min=82.2723, Z max=95.6589
# Timestep 8000: P min=231.8239, P max=285.8618, Z min=81.1697, Z max=94.2334
# Timestep 8020: P min=232.9332, P max=287.5042, Z min=80.0945, Z max=92.8389
# Timestep 8040: P min=234.1771, P max=289.2789, Z min=79.0470, Z max=91.4758
# Timestep 8060: P min=235.5547, P max=291.1850, Z min=78.0275, Z max=90.1446
# Timestep 8080: P min=237.0652, P max=293.2216, Z min=77.0364, Z max=88.8457
# Timestep 8100: P min=238.7079, P max=295.3878, Z min=76.0738, Z max=87.5793
# Timestep 8120: P min=240.4823, P max=297.6830, Z min=75.1400, Z max=86.3458
# Timestep 8140: P min=242.3879, P max=300.1064, Z min=74.2351, Z max=85.1454
# Timestep 8160: P min=244.4243, P max=302.6574, Z min=73.3594, Z max=83.9783
# Timestep 8180: P min=246.5912, P max=305.3353, Z min=72.5130, Z max=82.8446
# Timestep 8200: P min=248.8885, P max=308.1394, Z min=71.6959, Z max=81.7446
# Timestep 8220: P min=251.3159, P max=311.0691, Z min=70.9084, Z max=80.6783
# Timestep 8240: P min=253.8736, P max=314.1239, Z min=70.1505, Z max=79.6458
# Timestep 8260: P min=256.5613, P max=317.3030, Z min=69.4223, Z max=78.6473
# Timestep 8280: P min=259.3791, P max=320.6058, Z min=68.7239, Z max=77.6827
# Timestep 8300: P min=262.3272, P max=324.0316, Z min=68.0555, Z max=76.7522
# Timestep 8320: P min=265.4055, P max=327.5797, Z min=67.4170, Z max=75.8557
# Timestep 8340: P min=268.6142, P max=331.2493, Z min=66.8086, Z max=74.9934
# Timestep 8360: P min=271.9534, P max=335.0396, Z min=66.2304, Z max=74.1652
# Timestep 8380: P min=275.4232, P max=338.9497, Z min=65.6825, Z max=73.3713
# Timestep 8400: P min=279.0237, P max=342.9786, Z min=65.1649, Z max=72.6116
# Timestep 8420: P min=282.7548, P max=347.1252, Z min=64.6779, Z max=71.8862
# Timestep 8440: P min=286.6168, P max=351.3883, Z min=64.2215, Z max=71.1951
# Timestep 8460: P min=290.6094, P max=355.7666, Z min=63.7958, Z max=70.5385
# Timestep 8480: P min=294.7326, P max=360.2587, Z min=63.4011, Z max=69.9165
# Timestep 8500: P min=298.9862, P max=364.8629, Z min=63.0375, Z max=69.3290
# Timestep 8520: P min=303.3700, P max=369.5776, Z min=62.7052, Z max=68.7762
# Timestep 8540: P min=307.8834, P max=374.4007, Z min=62.4043, Z max=68.2584
# Timestep 8560: P min=312.5261, P max=379.3301, Z min=62.1352, Z max=67.7755
# Timestep 8580: P min=317.2974, P max=384.3634, Z min=61.8980, Z max=67.3278
# Timestep 8600: P min=322.1963, P max=389.4981, Z min=61.6931, Z max=66.9156
# Timestep 8620: P min=327.2220, P max=394.7314, Z min=61.5208, Z max=66.5390
# Timestep 8640: P min=332.3731, P max=400.0600, Z min=61.3813, Z max=66.1982
# Timestep 8660: P min=337.6483, P max=405.4807, Z min=61.2751, Z max=65.8937
# Timestep 8680: P min=343.0459, P max=410.9896, Z min=61.2025, Z max=65.6257
# Timestep 8700: P min=348.5639, P max=416.5829, Z min=61.1638, Z max=65.3946
# Timestep 8720: P min=354.2000, P max=422.2561, Z min=61.1597, Z max=65.2007
# Timestep 8740: P min=359.9518, P max=428.0045, Z min=61.1905, Z max=65.0446
# Timestep 8760: P min=365.8164, P max=433.8229, Z min=61.2566, Z max=64.9266
# Timestep 8780: P min=371.7904, P max=439.7058, Z min=61.3588, Z max=64.8473
# Timestep 8800: P min=377.8702, P max=445.6473, Z min=61.4974, Z max=64.8073
# Timestep 8820: P min=384.0517, P max=451.6408, Z min=61.6732, Z max=64.8071
# Timestep 8840: P min=390.3304, P max=457.6796, Z min=61.8866, Z max=64.8474
# Timestep 8860: P min=396.7012, P max=463.7563, Z min=62.1384, Z max=65.0515
# Timestep 8880: P min=403.1587, P max=469.8629, Z min=62.4293, Z max=65.3388
# Timestep 8900: P min=409.6966, P max=475.9910, Z min=62.7598, Z max=65.6686
# Timestep 8920: P min=416.3084, P max=482.1317, Z min=63.1309, Z max=66.0415
# Timestep 8940: P min=422.9868, P max=488.2755, Z min=63.4692, Z max=66.4584
# Timestep 8960: P min=429.7238, P max=494.4121, Z min=63.8139, Z max=66.9201
# Timestep 8980: P min=436.5108, P max=500.5310, Z min=64.2031, Z max=67.4276
# Timestep 9000: P min=443.3385, P max=506.6208, Z min=64.6376, Z max=67.9817
# Timestep 9020: P min=450.1969, P max=512.6697, Z min=65.1185, Z max=68.5833
# Timestep 9040: P min=457.0751, P max=518.6652, Z min=65.6468, Z max=69.2334
# Timestep 9060: P min=463.9616, P max=524.5941, Z min=66.2235, Z max=69.9328
# Timestep 9080: P min=470.8440, P max=530.4428, Z min=66.8497, Z max=70.6825
# Timestep 9100: P min=477.7090, P max=536.1969, Z min=67.5263, Z max=71.4833
# Timestep 9120: P min=484.5426, P max=541.8418, Z min=68.2546, Z max=72.3361
# Timestep 9140: P min=491.3297, P max=547.3619, Z min=69.0355, Z max=73.2417
# Timestep 9160: P min=498.0545, P max=552.7415, Z min=69.8701, Z max=74.2009
# Timestep 9180: P min=504.7004, P max=557.9641, Z min=70.7595, Z max=75.2144
# Timestep 9200: P min=511.2499, P max=563.0129, Z min=71.7047, Z max=76.2828
# Timestep 9220: P min=517.6844, P max=567.8709, Z min=72.7066, Z max=77.4067
# Timestep 9240: P min=523.9849, P max=572.5206, Z min=73.7662, Z max=78.5865
# Timestep 9260: P min=530.1314, P max=576.9443, Z min=74.8844, Z max=79.8226
# Timestep 9280: P min=536.1031, P max=581.1241, Z min=76.0618, Z max=81.1150
# Timestep 9300: P min=541.8787, P max=585.0423, Z min=77.2991, Z max=82.4639
# Timestep 9320: P min=547.4361, P max=588.6809, Z min=78.5968, Z max=83.8689
# Timestep 9340: P min=552.7529, P max=592.0225, Z min=79.9554, Z max=85.3296
# Timestep 9360: P min=557.8062, P max=595.0496, Z min=81.3748, Z max=86.8455
# Timestep 9380: P min=562.5728, P max=597.7453, Z min=82.8552, Z max=88.4157
# Timestep 9400: P min=567.0294, P max=600.0934, Z min=84.3963, Z max=90.0388
# Timestep 9420: P min=571.1527, P max=602.0781, Z min=85.9976, Z max=91.7135
# Timestep 9440: P min=574.9196, P max=603.6849, Z min=87.6582, Z max=93.4379
# Timestep 9460: P min=578.3073, P max=604.9000, Z min=89.3770, Z max=95.2098
# Timestep 9480: P min=581.2937, P max=605.7109, Z min=91.1527, Z max=97.0268
# Timestep 9500: P min=583.8573, P max=606.1066, Z min=92.9834, Z max=98.8857
# Timestep 9520: P min=585.9778, P max=606.0774, Z min=94.8668, Z max=100.7835
# Timestep 9540: P min=587.6361, P max=605.6154, Z min=96.8003, Z max=102.7162
# Timestep 9560: P min=588.8146, P max=604.7146, Z min=98.7809, Z max=104.6798
# Timestep 9580: P min=588.7169, P max=603.3708, Z min=100.8050, Z max=106.6696
# Timestep 9600: P min=586.9559, P max=602.0126, Z min=102.8686, Z max=108.6807
# Timestep 9620: P min=584.7277, P max=601.0690, Z min=104.9672, Z max=110.7077
# Timestep 9640: P min=582.0348, P max=599.6187, Z min=107.0958, Z max=112.7449
# Timestep 9660: P min=578.8820, P max=597.6589, Z min=109.0690, Z max=114.7860
# Timestep 9680: P min=575.2768, P max=595.1894, Z min=110.9600, Z max=116.8247
# Timestep 9700: P min=571.2292, P max=592.2128, Z min=112.8415, Z max=118.8542
# Timestep 9720: P min=566.7516, P max=588.7348, Z min=114.7072, Z max=120.8675
# Timestep 9740: P min=561.8593, P max=584.7639, Z min=116.5506, Z max=122.8574
# Timestep 9760: P min=556.5695, P max=580.3116, Z min=118.3650, Z max=124.8166
# Timestep 9780: P min=550.9020, P max=575.3923, Z min=120.1437, Z max=126.7376
# Timestep 9800: P min=544.8784, P max=570.0234, Z min=121.8799, Z max=128.8537
# Timestep 9820: P min=538.5223, P max=564.2247, Z min=123.5671, Z max=131.1781
# Timestep 9840: P min=531.8591, P max=558.0190, Z min=125.1985, Z max=133.4669
# Timestep 9860: P min=524.9154, P max=551.4310, Z min=126.7678, Z max=135.7109
# Timestep 9880: P min=517.7190, P max=544.4878, Z min=128.2688, Z max=137.9006
# Timestep 9900: P min=510.2987, P max=537.2182, Z min=129.6956, Z max=140.0268
# Timestep 9920: P min=502.6839, P max=529.6528, Z min=131.0426, Z max=142.0805
# Timestep 9940: P min=494.9041, P max=521.8231, Z min=132.3047, Z max=144.0529
# Timestep 9960: P min=486.9891, P max=513.7617, Z min=133.4770, Z max=145.9355
# Timestep 9980: P min=478.9685, P max=505.5017, Z min=134.5555, Z max=147.7203
