# %%
import numpy as np
import matplotlib.pyplot as plt


def stable_time_step(vx, Dx, Dz, dx, dz):
    dx2, dz2 = dx * dx, dz * dz
    max_diffusion = max(np.max(Dx), np.max(Dz), 1.0e-10)
    max_velocity = max(np.max(vx), 1.0e-10)
    diffusive_dt = dx2 * dz2 / (2 * max_diffusion * (dx2 + dz2))
    cfl_dt = dx / max_velocity
    dt = min(cfl_dt, diffusive_dt) * 0.5
    return min(dt, 0.002)  # MAKING THIS SMALLER WORKED


def euler_advection_diffusion_timestep(c0, vx, Dx, Dz, src, dt, dx, dz, inversion=True, upwind=True):
    nz, nx = c0.shape
    c = c0.copy()

    # Compute stability limits
    dt_advection = min(dx, dz) / np.max(np.abs(vx))
    dt_diffusion = min(dx**2, dz**2) / (2 * np.max([Dx.max(), Dz.max()]))
    dt_stable = min(dt_advection, dt_diffusion)
    
    if dt > dt_stable:
        print(f"Warning: dt={dt} exceeds stable timestep={dt_stable:.5f}. Adjusting dt.")
        dt = dt_stable
    
    # Storage for face-centered fluxes
    Fx = np.zeros((nz, nx + 1))
    Fz = np.zeros((nz + 1, nx))

    # Diffusive fluxes (per unit volume)
    Fx[:, 1:nx] = -Dx[:, 1:nx] * (c[:, 1:nx] - c[:, 0:nx-1]) / (dx * dx)
    Fz[1:nz, :] = -Dz[1:nz, :] * (c[1:nz, :] - c[0:nz-1, :]) / (dz * dz)

    # Advective fluxes
    if upwind:
        Fx[:, 1:nx] += np.where(vx[:, 1:nx] > 0,
                                vx[:, 1:nx] * c[:, 0:nx-1],
                                vx[:, 1:nx] * c[:, 1:nx]) / dx
    else:
        Fx[:, 1:nx] += vx[:, 1:nx] * (c[:, 0:nx-1] + c[:, 1:nx]) * 0.5 / dx

    # Update concentrations in interior cells
    c[0:nz, 0:nx] += dt * (
        -(Fx[0:nz, 1:nx+1] - Fx[0:nz, 0:nx])
        -(Fz[1:nz+1, 0:nx] - Fz[0:nz, 0:nx])
        + src[0:nz, 0:nx]
    )

    # Enforce non-negativity
    c = np.maximum(c, 0)

    return c


def create_grid(P0, Z0, domain_size, params):
    if P0.shape != Z0.shape:
        raise ValueError(f"P0 and Z0 must have the same shape. Got P0.shape={P0.shape}, Z0.shape={Z0.shape}")

    nz, nx = P0.shape
    dx = domain_size[0] / nx
    dz = domain_size[1] / nz

    vx = np.full((nz, nx + 1), params['current_velocity'])
    Dx = np.full((nz, nx + 1), params['diffusion'])
    Dz = np.full((nz + 1, nx), params['diffusion'])

    dt = stable_time_step(vx, Dx, Dz, dx, dz)
    print(f"Stable timestep: {dt:.5f}s")

    return {'nz': nz, 'nx': nx, 'dx': dx, 'dz': dz, 'vx': vx, 'Dx': Dx, 'Dz': Dz, 'dt': dt, 'P': P0.copy(), 'Z': Z0.copy()}


def lotka_volterra_sources(P, Z, params):
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    K = max(K, 1.0e-6)
    P = np.maximum(P, 1e-6)
    Z = np.maximum(Z, 1e-6)

    prey_growth = alpha * P * (1.0 - P / K)
    prey_death = -beta * P * Z
    predator_gain = delta * beta * P * Z
    predator_death = -gamma * Z

    src_prey = prey_growth + prey_death
    src_pred = predator_gain + predator_death

    # Add optional noise for debugging symmetry
   # noise = np.random.normal(0, 0.01, size=src_prey.shape)
   # src_prey += noise
   # src_pred += noise

    return src_prey, src_pred


def predator_prey_advection_diffusion_step(P, Z, vx, Dx, Dz, params, dt, dx, dz):
    src_prey, src_pred = lotka_volterra_sources(P, Z, params)

    P_updated = euler_advection_diffusion_timestep(P, vx, Dx, Dz, src_prey, dt, dx, dz)
    Z_updated = euler_advection_diffusion_timestep(Z, vx, Dx, Dz, src_pred, dt, dx, dz)

    return P_updated, Z_updated

def run_simulation_and_visualise():
    global grid
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    nx, nz = 5, 5  # Grid size
    P0 = np.full((nz, nx), gamma / (delta * beta) + 200) # + np.random.uniform(-20, 20, (nz, nx))
    Z0 = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )
    domain_size = (10, 10)
    grid = create_grid(P0, Z0, domain_size, params)

    eq_p = np.full((nz, nx), gamma / (delta * beta))
    eq_z = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )

    print(eq_p) # I wanted to see the equilibria conidionts
    print(eq_z)
    
    P = grid['P'].astype(np.float64)
    Z = grid['Z'].astype(np.float64)

    timesteps = 10000  # Adjust to a reasonable number for visualisation
    P_history = np.zeros((timesteps, nz, nx))
    Z_history = np.zeros((timesteps, nz, nx))

    # Store initial conditions
    P_history[0, :, :] = P
    Z_history[0, :, :] = Z

    for t in range(1, timesteps):
        P, Z = predator_prey_advection_diffusion_step(
            P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
        )
        P_history[t, :, :] = P
        Z_history[t, :, :] = Z

        # Debugging information
        if t % 20 == 0:
            print(f"Timestep {t}: P min={np.min(P):.4f}, P max={np.max(P):.4f}, Z min={np.min(Z):.4f}, Z max={np.max(Z):.4f}")

    # Visualisation of phase plots
    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    for i in range(nz):
        for j in range(nx):
            ax = axes[i, j]
            ax.plot(P_history[:, i, j], Z_history[:, i, j], label=f"Cell ({i}, {j})")
            ax.set_title(f"Phase Plot: Cell ({i}, {j})")
            ax.set_xlabel("Prey Density")
            ax.set_ylabel("Predator Density")
            ax.legend()
    plt.tight_layout()
    plt.show()


params = {
    'alpha': 1.0,
    'beta': 0.01,
    'delta': 0.25,
    'gamma': 1.0,
    'K': 1000000000000000000000000000000000000000000000000000000.0, # its high as I just wanted to include the code at this point rather than just think about parameters
    'current_velocity': 1.0,
    'diffusion': 0.01
}

run_simulation_and_visualise()
# Out:
# Stable timestep: 0.00200s
# [[400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]]
# [[100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]]
# Timestep 20: P min=588.1179, P max=611.5279, Z min=99.9435, Z max=104.1148
# Timestep 40: P min=576.4981, P max=621.9936, Z min=99.7698, Z max=108.4741
# Timestep 60: P min=565.1606, P max=631.2930, Z min=99.4822, Z max=113.0813
# Timestep 80: P min=554.1224, P max=639.3247, Z min=99.0848, Z max=117.9377
# Timestep 100: P min=543.3982, P max=645.9928, Z min=98.5817, Z max=123.0421
# Timestep 120: P min=533.0000, P max=651.2081, Z min=97.9777, Z max=128.3909
# Timestep 140: P min=522.9376, P max=654.8913, Z min=97.2780, Z max=133.9769
# Timestep 160: P min=513.2184, P max=656.9748, Z min=96.4880, Z max=139.7898
# Timestep 180: P min=503.8481, P max=657.4053, Z min=95.6132, Z max=145.8154
# Timestep 200: P min=494.8301, P max=656.1463, Z min=94.6594, Z max=152.0353
# Timestep 220: P min=486.1664, P max=653.1795, Z min=93.6325, Z max=158.4272
# Timestep 240: P min=477.8575, P max=648.5071, Z min=92.5383, Z max=164.9642
# Timestep 260: P min=469.9022, P max=642.1527, Z min=91.3827, Z max=171.6155
# Timestep 280: P min=462.2984, P max=634.1619, Z min=90.1715, Z max=178.3464
# Timestep 300: P min=455.0428, P max=624.6024, Z min=88.9104, Z max=185.1185
# Timestep 320: P min=448.1313, P max=613.5630, Z min=87.6051, Z max=191.8905
# Timestep 340: P min=441.5588, P max=601.1526, Z min=86.2609, Z max=198.6189
# Timestep 360: P min=435.3198, P max=587.4976, Z min=84.8830, Z max=205.2585
# Timestep 380: P min=429.4081, P max=572.7393, Z min=83.4767, Z max=211.7637
# Timestep 400: P min=423.8172, P max=557.0306, Z min=82.0466, Z max=218.0894
# Timestep 420: P min=418.5400, P max=540.5324, Z min=80.5973, Z max=224.1917
# Timestep 440: P min=413.5695, P max=523.4098, Z min=79.1332, Z max=230.0291
# Timestep 460: P min=408.8983, P max=505.8280, Z min=77.6585, Z max=235.5635
# Timestep 480: P min=404.5190, P max=487.9491, Z min=76.1769, Z max=240.7605
# Timestep 500: P min=400.4241, P max=469.9284, Z min=74.6921, Z max=245.5906
# Timestep 520: P min=396.6060, P max=459.6284, Z min=73.2074, Z max=250.0292
# Timestep 540: P min=393.0574, P max=453.2682, Z min=71.7259, Z max=254.0571
# Timestep 560: P min=389.7709, P max=447.1142, Z min=70.2506, Z max=257.6604
# Timestep 580: P min=386.7393, P max=441.1809, Z min=68.7840, Z max=260.8309
# Timestep 600: P min=382.3576, P max=435.4804, Z min=67.3286, Z max=263.5652
# Timestep 620: P min=366.0878, P max=430.0231, Z min=65.8866, Z max=265.8648
# Timestep 640: P min=350.4093, P max=424.8176, Z min=64.4599, Z max=267.7356
# Timestep 660: P min=335.3685, P max=419.8708, Z min=63.0505, Z max=269.1873
# Timestep 680: P min=320.9993, P max=415.1883, Z min=61.6598, Z max=270.2332
# Timestep 700: P min=307.3237, P max=410.7741, Z min=60.2894, Z max=270.8889
# Timestep 720: P min=294.3533, P max=406.6311, Z min=58.9405, Z max=271.1726
# Timestep 740: P min=282.0909, P max=402.7611, Z min=57.6142, Z max=271.1039
# Timestep 760: P min=270.5316, P max=399.1650, Z min=56.3115, Z max=270.7039
# Timestep 780: P min=259.6644, P max=395.8429, Z min=55.0332, Z max=269.9942
# Timestep 800: P min=249.4732, P max=392.7941, Z min=53.7800, Z max=268.9970
# Timestep 820: P min=239.9378, P max=390.0172, Z min=52.5525, Z max=267.7345
# Timestep 840: P min=231.0353, P max=387.5103, Z min=51.3512, Z max=266.2284
# Timestep 860: P min=222.7407, P max=385.2713, Z min=50.1765, Z max=264.5004
# Timestep 880: P min=215.0275, P max=383.2974, Z min=49.0285, Z max=262.5711
# Timestep 900: P min=207.8687, P max=381.5857, Z min=47.9076, Z max=260.4607
# Timestep 920: P min=201.2369, P max=380.1330, Z min=46.8139, Z max=258.1881
# Timestep 940: P min=195.1050, P max=378.9359, Z min=45.7473, Z max=255.7717
# Timestep 960: P min=189.4465, P max=377.9909, Z min=44.7079, Z max=253.2285
# Timestep 980: P min=184.2357, P max=377.2944, Z min=43.6956, Z max=250.5747
# Timestep 1000: P min=179.4477, P max=376.8428, Z min=42.7103, Z max=247.8253
# Timestep 1020: P min=175.0590, P max=376.6323, Z min=41.7517, Z max=244.9945
# Timestep 1040: P min=171.0470, P max=376.6592, Z min=40.8198, Z max=242.0953
# Timestep 1060: P min=167.3906, P max=376.9200, Z min=39.9142, Z max=239.1398
# Timestep 1080: P min=164.0699, P max=377.4109, Z min=39.0347, Z max=236.1393
# Timestep 1100: P min=161.0664, P max=378.4157, Z min=38.1809, Z max=233.1041
# Timestep 1120: P min=158.3626, P max=380.2689, Z min=37.3525, Z max=230.0438
# Timestep 1140: P min=155.9424, P max=382.2558, Z min=36.5492, Z max=226.9669
# Timestep 1160: P min=153.7910, P max=384.3746, Z min=35.7705, Z max=223.8816
# Timestep 1180: P min=151.8946, P max=386.6237, Z min=35.0162, Z max=220.7951
# Timestep 1200: P min=150.2405, P max=389.0015, Z min=34.2857, Z max=217.7141
# Timestep 1220: P min=148.8170, P max=391.5064, Z min=33.5788, Z max=214.6447
# Timestep 1240: P min=147.6136, P max=394.1370, Z min=32.8949, Z max=211.5925
# Timestep 1260: P min=146.6204, P max=396.8921, Z min=32.2337, Z max=208.5625
# Timestep 1280: P min=145.8285, P max=399.7705, Z min=31.5947, Z max=205.5592
# Timestep 1300: P min=145.2300, P max=402.7709, Z min=30.9776, Z max=202.5869
# Timestep 1320: P min=144.8174, P max=405.8923, Z min=30.3819, Z max=199.6492
# Timestep 1340: P min=144.5841, P max=409.1336, Z min=29.8071, Z max=196.7496
# Timestep 1360: P min=144.5242, P max=412.4941, Z min=29.2530, Z max=193.8911
# Timestep 1380: P min=144.6322, P max=415.9727, Z min=28.7190, Z max=191.0765
# Timestep 1400: P min=144.9034, P max=419.5686, Z min=28.2048, Z max=188.3084
# Timestep 1420: P min=145.3334, P max=423.2811, Z min=27.7100, Z max=185.5888
# Timestep 1440: P min=145.9184, P max=427.1095, Z min=27.2341, Z max=182.9199
# Timestep 1460: P min=146.6550, P max=431.0529, Z min=26.7769, Z max=180.3035
# Timestep 1480: P min=147.5402, P max=435.1108, Z min=26.3380, Z max=177.7411
# Timestep 1500: P min=148.5715, P max=439.2826, Z min=25.9169, Z max=175.2343
# Timestep 1520: P min=149.7464, P max=443.5675, Z min=25.5135, Z max=172.7843
# Timestep 1540: P min=151.0631, P max=447.9651, Z min=25.1272, Z max=170.3923
# Timestep 1560: P min=152.5197, P max=452.4748, Z min=24.7579, Z max=168.0594
# Timestep 1580: P min=154.1149, P max=457.0960, Z min=24.4052, Z max=165.7863
# Timestep 1600: P min=155.8474, P max=461.8281, Z min=24.0688, Z max=163.5741
# Timestep 1620: P min=157.7162, P max=466.6706, Z min=23.7485, Z max=161.4234
# Timestep 1640: P min=159.7204, P max=471.6229, Z min=23.4439, Z max=159.3350
# Timestep 1660: P min=161.8592, P max=477.3003, Z min=23.1549, Z max=157.3093
# Timestep 1680: P min=164.1320, P max=483.2141, Z min=22.8812, Z max=155.3470
# Timestep 1700: P min=166.5384, P max=489.2549, Z min=22.6226, Z max=153.4485
# Timestep 1720: P min=169.0778, P max=495.4178, Z min=22.3789, Z max=151.6143
# Timestep 1740: P min=171.7498, P max=501.6974, Z min=22.1499, Z max=149.8448
# Timestep 1760: P min=174.5541, P max=508.0883, Z min=21.9355, Z max=148.1404
# Timestep 1780: P min=177.4903, P max=514.5845, Z min=21.7355, Z max=146.5015
# Timestep 1800: P min=180.5579, P max=521.1799, Z min=21.5497, Z max=144.9284
# Timestep 1820: P min=183.7565, P max=527.8678, Z min=21.3781, Z max=143.4215
# Timestep 1840: P min=187.0856, P max=534.6413, Z min=21.2205, Z max=141.9810
# Timestep 1860: P min=190.5444, P max=541.4930, Z min=21.0770, Z max=140.6074
# Timestep 1880: P min=194.1322, P max=548.4151, Z min=20.9474, Z max=139.3010
# Timestep 1900: P min=197.8480, P max=555.3995, Z min=20.8316, Z max=138.0621
# Timestep 1920: P min=201.6908, P max=562.4374, Z min=20.7297, Z max=136.8911
# Timestep 1940: P min=205.6590, P max=569.5196, Z min=20.6418, Z max=135.7883
# Timestep 1960: P min=209.7512, P max=576.6365, Z min=20.5677, Z max=134.7542
# Timestep 1980: P min=213.9654, P max=583.7779, Z min=20.5075, Z max=133.7891
# Timestep 2000: P min=218.2994, P max=590.9331, Z min=20.4614, Z max=132.8935
# Timestep 2020: P min=222.7507, P max=598.0909, Z min=20.4294, Z max=132.0679
# Timestep 2040: P min=227.3163, P max=605.2395, Z min=20.4116, Z max=131.3127
# Timestep 2060: P min=231.9929, P max=612.3667, Z min=20.4082, Z max=130.6284
# Timestep 2080: P min=236.7767, P max=619.4596, Z min=20.4193, Z max=130.0157
# Timestep 2100: P min=241.6634, P max=626.5046, Z min=20.4451, Z max=129.4750
# Timestep 2120: P min=246.6483, P max=633.4880, Z min=20.4859, Z max=129.0069
# Timestep 2140: P min=251.7259, P max=640.3951, Z min=20.5419, Z max=128.6122
# Timestep 2160: P min=256.8904, P max=647.2111, Z min=20.6133, Z max=128.2914
# Timestep 2180: P min=262.1352, P max=653.9202, Z min=20.7004, Z max=128.0452
# Timestep 2200: P min=267.4532, P max=660.5066, Z min=20.8037, Z max=127.8743
# Timestep 2220: P min=272.8363, P max=666.9537, Z min=20.9234, Z max=127.7796
# Timestep 2240: P min=278.2762, P max=673.2447, Z min=21.0600, Z max=127.7616
# Timestep 2260: P min=283.7634, P max=679.3623, Z min=21.2138, Z max=127.8212
# Timestep 2280: P min=289.2879, P max=685.2890, Z min=21.3855, Z max=127.9591
# Timestep 2300: P min=294.8388, P max=691.0070, Z min=21.5753, Z max=128.1761
# Timestep 2320: P min=300.4046, P max=697.7022, Z min=21.7840, Z max=128.4729
# Timestep 2340: P min=305.9727, P max=705.5888, Z min=22.0120, Z max=128.8503
# Timestep 2360: P min=311.5300, P max=713.4965, Z min=22.2600, Z max=129.3090
# Timestep 2380: P min=317.0624, P max=721.4182, Z min=22.5287, Z max=129.8496
# Timestep 2400: P min=322.5552, P max=729.3462, Z min=22.8187, Z max=130.4727
# Timestep 2420: P min=327.9928, P max=737.2724, Z min=23.1308, Z max=131.1789
# Timestep 2440: P min=333.3589, P max=745.1882, Z min=23.4658, Z max=131.9686
# Timestep 2460: P min=338.6366, P max=753.0843, Z min=23.8244, Z max=132.8422
# Timestep 2480: P min=343.8084, P max=760.9511, Z min=24.2076, Z max=133.7999
# Timestep 2500: P min=348.8559, P max=768.7780, Z min=24.6163, Z max=134.8417
# Timestep 2520: P min=353.7607, P max=776.5542, Z min=25.0515, Z max=135.9677
# Timestep 2540: P min=358.5037, P max=784.2679, Z min=25.5140, Z max=137.1774
# Timestep 2560: P min=363.0656, P max=791.9071, Z min=26.0051, Z max=138.4706
# Timestep 2580: P min=367.4269, P max=799.4586, Z min=26.5257, Z max=139.8463
# Timestep 2600: P min=371.5681, P max=806.9088, Z min=27.0771, Z max=141.3036
# Timestep 2620: P min=375.4698, P max=814.2434, Z min=27.6603, Z max=142.8413
# Timestep 2640: P min=379.1130, P max=821.4473, Z min=28.2766, Z max=144.4577
# Timestep 2660: P min=382.4788, P max=828.5047, Z min=28.9272, Z max=146.1508
# Timestep 2680: P min=385.5493, P max=835.3991, Z min=29.6133, Z max=147.9184
# Timestep 2700: P min=388.3071, P max=842.1131, Z min=30.3363, Z max=149.7577
# Timestep 2720: P min=390.7360, P max=848.6289, Z min=31.0975, Z max=151.6655
# Timestep 2740: P min=392.8209, P max=854.9277, Z min=31.8981, Z max=153.6384
# Timestep 2760: P min=394.5481, P max=860.9901, Z min=32.7395, Z max=155.6722
# Timestep 2780: P min=395.9054, P max=866.7961, Z min=33.6229, Z max=157.7625
# Timestep 2800: P min=396.8825, P max=872.3251, Z min=34.5496, Z max=159.9042
# Timestep 2820: P min=397.4709, P max=877.5558, Z min=35.5208, Z max=162.0921
# Timestep 2840: P min=397.6641, P max=882.4667, Z min=36.5377, Z max=164.3200
# Timestep 2860: P min=397.4582, P max=887.0355, Z min=37.6014, Z max=166.5818
# Timestep 2880: P min=396.8510, P max=891.2398, Z min=38.7129, Z max=168.8705
# Timestep 2900: P min=395.8433, P max=895.0569, Z min=39.8731, Z max=171.1790
# Timestep 2920: P min=394.4380, P max=898.4642, Z min=41.0828, Z max=173.4997
# Timestep 2940: P min=392.6406, P max=901.4388, Z min=42.3424, Z max=175.8248
# Timestep 2960: P min=390.4590, P max=903.9582, Z min=43.6525, Z max=178.1459
# Timestep 2980: P min=387.9036, P max=906.0003, Z min=45.0132, Z max=180.4547
# Timestep 3000: P min=384.9872, P max=907.5434, Z min=46.4244, Z max=182.7427
# Timestep 3020: P min=381.7246, P max=908.5667, Z min=47.8858, Z max=185.0010
# Timestep 3040: P min=378.1328, P max=909.0503, Z min=49.3966, Z max=187.2211
# Timestep 3060: P min=374.2308, P max=908.9754, Z min=50.9560, Z max=189.3942
# Timestep 3080: P min=370.0392, P max=908.3249, Z min=52.5625, Z max=191.5118
# Timestep 3100: P min=365.5799, P max=907.0831, Z min=54.2142, Z max=193.5656
# Timestep 3120: P min=360.8763, P max=905.2366, Z min=55.9090, Z max=195.5476
# Timestep 3140: P min=355.9526, P max=902.7738, Z min=57.6442, Z max=197.4499
# Timestep 3160: P min=350.8338, P max=899.6860, Z min=59.4164, Z max=199.2654
# Timestep 3180: P min=345.5451, P max=895.9669, Z min=61.2221, Z max=200.9871
# Timestep 3200: P min=340.1123, P max=891.6132, Z min=63.0569, Z max=202.6089
# Timestep 3220: P min=334.5607, P max=886.6247, Z min=64.9162, Z max=204.1250
# Timestep 3240: P min=328.9154, P max=881.0047, Z min=66.7946, Z max=205.5303
# Timestep 3260: P min=323.2012, P max=874.7598, Z min=68.6864, Z max=206.8204
# Timestep 3280: P min=317.4419, P max=867.9002, Z min=70.5853, Z max=207.9916
# Timestep 3300: P min=311.6605, P max=860.4397, Z min=72.4846, Z max=209.0408
# Timestep 3320: P min=305.8788, P max=852.3958, Z min=74.3771, Z max=209.9656
# Timestep 3340: P min=300.1177, P max=843.7897, Z min=76.2553, Z max=210.7645
# Timestep 3360: P min=294.3965, P max=834.6460, Z min=78.1113, Z max=211.4363
# Timestep 3380: P min=288.7333, P max=824.9926, Z min=79.9372, Z max=211.9809
# Timestep 3400: P min=283.1447, P max=814.8608, Z min=81.7247, Z max=212.3984
# Timestep 3420: P min=277.6460, P max=804.2846, Z min=83.4654, Z max=212.6898
# Timestep 3440: P min=272.2509, P max=793.3008, Z min=85.1513, Z max=212.8566
# Timestep 3460: P min=266.9717, P max=781.9484, Z min=86.7740, Z max=212.9008
# Timestep 3480: P min=261.8193, P max=770.2681, Z min=88.3257, Z max=212.8249
# Timestep 3500: P min=256.8033, P max=758.3023, Z min=89.7987, Z max=212.6317
# Timestep 3520: P min=251.9319, P max=746.0944, Z min=91.1858, Z max=212.3247
# Timestep 3540: P min=247.2121, P max=733.6885, Z min=92.4803, Z max=211.9074
# Timestep 3560: P min=242.6498, P max=721.1285, Z min=93.6760, Z max=211.3839
# Timestep 3580: P min=238.2496, P max=708.4585, Z min=94.7672, Z max=210.7583
# Timestep 3600: P min=234.0153, P max=695.7215, Z min=95.7493, Z max=210.0351
# Timestep 3620: P min=229.9498, P max=682.9598, Z min=96.6182, Z max=209.2188
# Timestep 3640: P min=226.0550, P max=670.2141, Z min=97.3704, Z max=208.3142
# Timestep 3660: P min=222.3322, P max=657.5232, Z min=98.0036, Z max=207.3261
# Timestep 3680: P min=218.7819, P max=644.9241, Z min=98.5161, Z max=206.2594
# Timestep 3700: P min=215.4040, P max=632.4516, Z min=98.9070, Z max=205.1190
# Timestep 3720: P min=212.1980, P max=620.1378, Z min=99.1762, Z max=203.9097
# Timestep 3740: P min=209.1628, P max=608.0125, Z min=99.3245, Z max=202.6366
# Timestep 3760: P min=206.2971, P max=596.1027, Z min=99.3534, Z max=201.3043
# Timestep 3780: P min=203.5992, P max=584.4329, Z min=99.2650, Z max=199.9176
# Timestep 3800: P min=201.0669, P max=573.0246, Z min=99.0622, Z max=198.4813
# Timestep 3820: P min=198.6981, P max=561.8969, Z min=98.7482, Z max=196.9998
# Timestep 3840: P min=196.4903, P max=551.0661, Z min=98.3270, Z max=195.4777
# Timestep 3860: P min=194.4412, P max=540.5462, Z min=97.8030, Z max=193.9193
# Timestep 3880: P min=192.5479, P max=530.3487, Z min=97.1809, Z max=192.3287
# Timestep 3900: P min=190.8078, P max=520.4828, Z min=96.4658, Z max=190.7101
# Timestep 3920: P min=189.2182, P max=510.9556, Z min=95.6629, Z max=189.0673
# Timestep 3940: P min=187.7764, P max=501.7723, Z min=94.7779, Z max=187.4041
# Timestep 3960: P min=186.4796, P max=492.9363, Z min=93.8164, Z max=185.7241
# Timestep 3980: P min=185.3252, P max=484.4492, Z min=92.7841, Z max=184.0309
# Timestep 4000: P min=184.3105, P max=476.3113, Z min=91.6868, Z max=182.3276
# Timestep 4020: P min=183.4331, P max=468.5215, Z min=90.5302, Z max=180.6175
# Timestep 4040: P min=182.6903, P max=461.0776, Z min=89.3201, Z max=178.9036
# Timestep 4060: P min=182.0798, P max=453.9764, Z min=88.0620, Z max=177.1888
# Timestep 4080: P min=181.5992, P max=447.2137, Z min=86.7613, Z max=175.4757
# Timestep 4100: P min=181.2465, P max=440.7846, Z min=85.4234, Z max=173.7670
# Timestep 4120: P min=181.0194, P max=434.6837, Z min=84.0534, Z max=172.0652
# Timestep 4140: P min=180.9159, P max=428.9049, Z min=82.6562, Z max=170.3725
# Timestep 4160: P min=180.9343, P max=423.4418, Z min=81.2365, Z max=168.6912
# Timestep 4180: P min=181.0726, P max=418.2877, Z min=79.7988, Z max=167.0233
# Timestep 4200: P min=181.3292, P max=413.4355, Z min=78.3472, Z max=165.3708
# Timestep 4220: P min=181.7025, P max=408.8782, Z min=76.8858, Z max=163.7356
# Timestep 4240: P min=182.1910, P max=404.6084, Z min=75.4184, Z max=162.1194
# Timestep 4260: P min=182.7934, P max=400.6189, Z min=73.9484, Z max=160.5238
# Timestep 4280: P min=183.5083, P max=396.9024, Z min=72.4792, Z max=158.9504
# Timestep 4300: P min=184.3347, P max=393.4516, Z min=71.0136, Z max=157.4007
# Timestep 4320: P min=185.2713, P max=390.2595, Z min=69.5546, Z max=155.8760
# Timestep 4340: P min=186.3172, P max=387.3188, Z min=68.1047, Z max=154.3777
# Timestep 4360: P min=187.4713, P max=384.6229, Z min=66.6662, Z max=152.9069
# Timestep 4380: P min=188.7329, P max=382.1649, Z min=65.2414, Z max=151.4648
# Timestep 4400: P min=190.1012, P max=379.9382, Z min=63.8320, Z max=150.0525
# Timestep 4420: P min=191.5753, P max=377.9366, Z min=62.4399, Z max=148.6710
# Timestep 4440: P min=193.1546, P max=376.1539, Z min=61.0666, Z max=147.3212
# Timestep 4460: P min=194.8384, P max=374.5842, Z min=59.7136, Z max=146.0041
# Timestep 4480: P min=196.6261, P max=373.2217, Z min=58.3820, Z max=144.7206
# Timestep 4500: P min=198.5171, P max=372.0609, Z min=57.0729, Z max=143.4715
# Timestep 4520: P min=200.5108, P max=371.0966, Z min=55.7873, Z max=142.2574
# Timestep 4540: P min=202.6067, P max=370.3238, Z min=54.5259, Z max=141.0793
# Timestep 4560: P min=204.8043, P max=369.7375, Z min=53.2895, Z max=139.9377
# Timestep 4580: P min=207.1029, P max=369.3332, Z min=52.0787, Z max=138.8334
# Timestep 4600: P min=209.5020, P max=369.1064, Z min=50.8937, Z max=137.7671
# Timestep 4620: P min=212.0010, P max=369.0531, Z min=49.7351, Z max=136.7392
# Timestep 4640: P min=214.5993, P max=369.1692, Z min=48.6031, Z max=135.7505
# Timestep 4660: P min=217.2961, P max=369.4509, Z min=47.4978, Z max=134.8016
# Timestep 4680: P min=220.0909, P max=369.8946, Z min=46.4194, Z max=133.8929
# Timestep 4700: P min=222.9827, P max=370.4969, Z min=45.3679, Z max=133.0251
# Timestep 4720: P min=225.9707, P max=371.2546, Z min=44.3433, Z max=132.1988
# Timestep 4740: P min=229.0539, P max=372.1646, Z min=43.3455, Z max=131.4144
# Timestep 4760: P min=232.2313, P max=373.2241, Z min=42.3744, Z max=130.6726
# Timestep 4780: P min=235.5017, P max=374.4303, Z min=41.4298, Z max=129.9738
# Timestep 4800: P min=238.8637, P max=375.7807, Z min=40.5115, Z max=129.3186
# Timestep 4820: P min=242.3160, P max=377.2728, Z min=39.6193, Z max=128.7075
# Timestep 4840: P min=245.8569, P max=378.9043, Z min=38.7528, Z max=128.1412
# Timestep 4860: P min=249.4847, P max=380.6731, Z min=37.9118, Z max=127.6200
# Timestep 4880: P min=253.1974, P max=382.5772, Z min=37.0959, Z max=127.1446
# Timestep 4900: P min=256.9928, P max=384.6147, Z min=36.3048, Z max=126.7156
# Timestep 4920: P min=260.8687, P max=387.8523, Z min=35.5381, Z max=126.3335
# Timestep 4940: P min=264.8223, P max=392.1303, Z min=34.7955, Z max=125.9989
# Timestep 4960: P min=268.8510, P max=396.5431, Z min=34.0764, Z max=125.7123
# Timestep 4980: P min=272.9515, P max=401.0897, Z min=33.3806, Z max=125.4744
# Timestep 5000: P min=277.1206, P max=405.7690, Z min=32.7077, Z max=125.2859
# Timestep 5020: P min=281.3546, P max=410.5796, Z min=32.0572, Z max=125.1472
# Timestep 5040: P min=285.6494, P max=415.5202, Z min=31.4286, Z max=125.0591
# Timestep 5060: P min=290.0010, P max=420.5892, Z min=30.8217, Z max=125.0222
# Timestep 5080: P min=294.4047, P max=425.7852, Z min=30.2360, Z max=125.0372
# Timestep 5100: P min=298.8554, P max=431.1064, Z min=29.6710, Z max=125.1046
# Timestep 5120: P min=303.3480, P max=436.5508, Z min=29.1265, Z max=125.2252
# Timestep 5140: P min=307.8768, P max=442.1165, Z min=28.6019, Z max=125.3997
# Timestep 5160: P min=312.4356, P max=447.8012, Z min=28.0969, Z max=125.6287
# Timestep 5180: P min=317.0181, P max=453.6026, Z min=27.6111, Z max=125.9130
# Timestep 5200: P min=321.6175, P max=459.5180, Z min=27.1441, Z max=126.2531
# Timestep 5220: P min=326.2264, P max=465.5447, Z min=26.6956, Z max=126.6497
# Timestep 5240: P min=330.8372, P max=471.6797, Z min=26.2652, Z max=127.1036
# Timestep 5260: P min=335.4419, P max=477.9196, Z min=25.8526, Z max=127.6154
# Timestep 5280: P min=340.0320, P max=484.2609, Z min=25.4575, Z max=128.1857
# Timestep 5300: P min=344.5985, P max=490.7000, Z min=25.0794, Z max=128.8151
# Timestep 5320: P min=349.1323, P max=497.2326, Z min=24.7181, Z max=129.5042
# Timestep 5340: P min=353.6236, P max=503.8545, Z min=24.3734, Z max=130.2536
# Timestep 5360: P min=358.0624, P max=510.5609, Z min=24.0449, Z max=131.0636
# Timestep 5380: P min=362.4383, P max=517.3468, Z min=23.7324, Z max=131.9349
# Timestep 5400: P min=366.7404, P max=524.2068, Z min=23.4355, Z max=132.8676
# Timestep 5420: P min=370.9579, P max=531.1353, Z min=23.1542, Z max=133.8623
# Timestep 5440: P min=375.0792, P max=538.1260, Z min=22.8881, Z max=134.9191
# Timestep 5460: P min=379.0929, P max=545.1724, Z min=22.6371, Z max=136.0380
# Timestep 5480: P min=382.9870, P max=552.2677, Z min=22.4009, Z max=137.2193
# Timestep 5500: P min=386.7498, P max=559.4044, Z min=22.1795, Z max=138.4628
# Timestep 5520: P min=390.3691, P max=566.5748, Z min=21.9725, Z max=139.7683
# Timestep 5540: P min=393.8328, P max=573.7705, Z min=21.7800, Z max=141.1354
# Timestep 5560: P min=397.1288, P max=580.9829, Z min=21.6018, Z max=142.5637
# Timestep 5580: P min=400.2452, P max=588.2027, Z min=21.4377, Z max=144.0525
# Timestep 5600: P min=403.1700, P max=595.4202, Z min=21.2878, Z max=145.6011
# Timestep 5620: P min=405.8917, P max=602.6252, Z min=21.1519, Z max=147.2083
# Timestep 5640: P min=408.3988, P max=609.8069, Z min=21.0299, Z max=148.8729
# Timestep 5660: P min=410.6805, P max=616.9542, Z min=20.9219, Z max=150.5936
# Timestep 5680: P min=412.7264, P max=624.0552, Z min=20.8279, Z max=152.3687
# Timestep 5700: P min=414.5264, P max=631.0977, Z min=20.7479, Z max=154.1962
# Timestep 5720: P min=416.0714, P max=638.0690, Z min=20.6819, Z max=156.0741
# Timestep 5740: P min=417.3529, P max=644.9558, Z min=20.6299, Z max=157.9999
# Timestep 5760: P min=418.3630, P max=651.7443, Z min=20.5921, Z max=159.9710
# Timestep 5780: P min=419.0951, P max=658.4204, Z min=20.5686, Z max=161.9844
# Timestep 5800: P min=419.5432, P max=664.9694, Z min=20.5594, Z max=164.0371
# Timestep 5820: P min=419.7027, P max=671.3762, Z min=20.5648, Z max=166.1256
# Timestep 5840: P min=419.5697, P max=677.6255, Z min=20.5850, Z max=168.2461
# Timestep 5860: P min=419.1419, P max=683.7015, Z min=20.6200, Z max=170.3948
# Timestep 5880: P min=418.4178, P max=689.5881, Z min=20.6702, Z max=172.5673
# Timestep 5900: P min=417.3975, P max=695.2692, Z min=20.7359, Z max=174.7593
# Timestep 5920: P min=416.0822, P max=700.7283, Z min=20.8172, Z max=176.9661
# Timestep 5940: P min=414.4744, P max=705.9489, Z min=20.9146, Z max=179.1828
# Timestep 5960: P min=412.5779, P max=710.9146, Z min=21.0284, Z max=181.4043
# Timestep 5980: P min=410.3978, P max=715.6090, Z min=21.1590, Z max=183.6254
# Timestep 6000: P min=407.9404, P max=720.0158, Z min=21.3067, Z max=185.8408
# Timestep 6020: P min=405.2132, P max=724.1192, Z min=21.4721, Z max=188.0449
# Timestep 6040: P min=402.2251, P max=727.9037, Z min=21.6556, Z max=190.2322
# Timestep 6060: P min=398.9858, P max=731.3543, Z min=21.8577, Z max=192.3970
# Timestep 6080: P min=395.5062, P max=734.4567, Z min=22.0791, Z max=194.5337
# Timestep 6100: P min=391.7981, P max=737.1973, Z min=22.3202, Z max=196.6367
# Timestep 6120: P min=387.8740, P max=739.5635, Z min=22.5818, Z max=198.7004
# Timestep 6140: P min=383.7475, P max=741.5437, Z min=22.8644, Z max=200.7193
# Timestep 6160: P min=379.4325, P max=743.1276, Z min=23.1689, Z max=202.6880
# Timestep 6180: P min=374.9437, P max=744.3061, Z min=23.4960, Z max=204.6011
# Timestep 6200: P min=370.2960, P max=749.1183, Z min=23.8465, Z max=206.4538
# Timestep 6220: P min=365.5048, P max=756.9402, Z min=24.2212, Z max=208.2410
# Timestep 6240: P min=360.5857, P max=764.7248, Z min=24.6210, Z max=209.9582
# Timestep 6260: P min=355.5542, P max=772.4614, Z min=25.0469, Z max=211.6010
# Timestep 6280: P min=350.4259, P max=780.1386, Z min=25.4998, Z max=213.1653
# Timestep 6300: P min=345.2165, P max=787.7445, Z min=25.9807, Z max=214.6474
# Timestep 6320: P min=339.9412, P max=795.2663, Z min=26.4907, Z max=216.0437
# Timestep 6340: P min=334.6149, P max=802.6908, Z min=27.0309, Z max=217.3511
# Timestep 6360: P min=329.2525, P max=810.0040, Z min=27.6024, Z max=218.5668
# Timestep 6380: P min=323.8679, P max=817.1911, Z min=28.2064, Z max=219.6885
# Timestep 6400: P min=318.4751, P max=824.2366, Z min=28.8440, Z max=220.7140
# Timestep 6420: P min=313.0869, P max=831.1245, Z min=29.5166, Z max=221.6416
# Timestep 6440: P min=307.7161, P max=837.8380, Z min=30.2253, Z max=222.4700
# Timestep 6460: P min=302.3745, P max=844.3593, Z min=30.9714, Z max=223.1981
# Timestep 6480: P min=297.0732, P max=850.6704, Z min=31.7563, Z max=223.8253
# Timestep 6500: P min=291.8229, P max=856.7523, Z min=32.5810, Z max=224.3514
# Timestep 6520: P min=286.6333, P max=862.5853, Z min=33.4470, Z max=224.7763
# Timestep 6540: P min=281.5135, P max=868.1495, Z min=34.3554, Z max=225.1004
# Timestep 6560: P min=276.4719, P max=873.4239, Z min=35.3074, Z max=225.3243
# Timestep 6580: P min=271.5162, P max=878.3875, Z min=36.3043, Z max=225.4489
# Timestep 6600: P min=266.6534, P max=883.0186, Z min=37.3470, Z max=225.4756
# Timestep 6620: P min=261.8898, P max=887.2951, Z min=38.4365, Z max=225.4058
# Timestep 6640: P min=257.2309, P max=891.1950, Z min=39.5738, Z max=225.2411
# Timestep 6660: P min=252.6820, P max=894.6957, Z min=40.7596, Z max=224.9836
# Timestep 6680: P min=248.2472, P max=897.7751, Z min=41.9945, Z max=224.6354
# Timestep 6700: P min=243.9305, P max=900.4109, Z min=43.2790, Z max=224.1988
# Timestep 6720: P min=239.7351, P max=902.5812, Z min=44.6132, Z max=223.6763
# Timestep 6740: P min=235.6638, P max=904.2647, Z min=45.9971, Z max=223.0707
# Timestep 6760: P min=231.7187, P max=905.4407, Z min=47.4304, Z max=222.3846
# Timestep 6780: P min=227.9018, P max=906.0894, Z min=48.9126, Z max=221.6210
# Timestep 6800: P min=224.2143, P max=906.1921, Z min=50.4427, Z max=220.7829
# Timestep 6820: P min=220.6572, P max=905.7315, Z min=52.0195, Z max=219.8735
# Timestep 6840: P min=217.2313, P max=904.6919, Z min=53.6412, Z max=218.8957
# Timestep 6860: P min=213.9366, P max=903.0594, Z min=55.3059, Z max=217.8529
# Timestep 6880: P min=210.7733, P max=900.8222, Z min=57.0108, Z max=216.7482
# Timestep 6900: P min=207.7410, P max=897.9709, Z min=58.7531, Z max=215.5851
# Timestep 6920: P min=204.8393, P max=894.4985, Z min=60.5292, Z max=214.3666
# Timestep 6940: P min=202.0675, P max=890.4010, Z min=62.3351, Z max=213.0962
# Timestep 6960: P min=199.4245, P max=885.6773, Z min=64.1662, Z max=211.7770
# Timestep 6980: P min=196.9093, P max=880.3295, Z min=66.0177, Z max=210.4123
# Timestep 7000: P min=194.5208, P max=874.3631, Z min=67.8839, Z max=209.0054
# Timestep 7020: P min=192.2576, P max=867.7870, Z min=69.7588, Z max=207.5594
# Timestep 7040: P min=190.1181, P max=860.6136, Z min=71.6360, Z max=206.0774
# Timestep 7060: P min=188.1010, P max=852.8590, Z min=73.5086, Z max=204.5626
# Timestep 7080: P min=186.2047, P max=844.5427, Z min=75.3693, Z max=203.0179
# Timestep 7100: P min=184.4275, P max=835.6877, Z min=77.2106, Z max=201.4463
# Timestep 7120: P min=182.7677, P max=826.3204, Z min=79.0246, Z max=199.8507
# Timestep 7140: P min=181.2237, P max=816.4704, Z min=80.8033, Z max=198.2339
# Timestep 7160: P min=179.7938, P max=806.1701, Z min=82.5387, Z max=196.5986
# Timestep 7180: P min=178.4763, P max=795.4547, Z min=84.2225, Z max=194.9475
# Timestep 7200: P min=177.2694, P max=784.3616, Z min=85.8469, Z max=193.2833
# Timestep 7220: P min=176.1716, P max=772.9303, Z min=87.4039, Z max=191.6083
# Timestep 7240: P min=175.1812, P max=761.2019, Z min=88.8859, Z max=189.9251
# Timestep 7260: P min=174.2965, P max=749.2185, Z min=90.2858, Z max=188.2358
# Timestep 7280: P min=173.5161, P max=737.0230, Z min=91.5968, Z max=186.5429
# Timestep 7300: P min=172.8383, P max=724.6589, Z min=92.8125, Z max=184.8484
# Timestep 7320: P min=172.2616, P max=712.1693, Z min=93.9274, Z max=183.1545
# Timestep 7340: P min=171.7847, P max=699.5968, Z min=94.9365, Z max=181.4631
# Timestep 7360: P min=171.4060, P max=686.9833, Z min=95.8355, Z max=179.7761
# Timestep 7380: P min=171.1243, P max=674.3692, Z min=96.6208, Z max=178.0953
# Timestep 7400: P min=170.9383, P max=661.7936, Z min=97.2898, Z max=176.4226
# Timestep 7420: P min=170.8467, P max=649.2934, Z min=97.8404, Z max=174.7596
# Timestep 7440: P min=170.8483, P max=636.9036, Z min=98.2716, Z max=173.1078
# Timestep 7460: P min=170.9420, P max=624.6570, Z min=98.5830, Z max=171.4688
# Timestep 7480: P min=171.1267, P max=612.5837, Z min=98.7751, Z max=169.8441
# Timestep 7500: P min=171.4014, P max=600.7115, Z min=98.8489, Z max=168.2349
# Timestep 7520: P min=171.7650, P max=589.0653, Z min=98.8063, Z max=166.6427
# Timestep 7540: P min=172.2168, P max=577.6678, Z min=98.6498, Z max=165.0685
# Timestep 7560: P min=172.7556, P max=566.5385, Z min=98.3826, Z max=163.5137
# Timestep 7580: P min=173.3809, P max=555.6949, Z min=98.0081, Z max=161.9793
# Timestep 7600: P min=174.0916, P max=545.1517, Z min=97.5306, Z max=160.4662
# Timestep 7620: P min=174.8872, P max=534.9213, Z min=96.9545, Z max=158.9757
# Timestep 7640: P min=175.7669, P max=525.0136, Z min=96.2846, Z max=157.5084
# Timestep 7660: P min=176.7300, P max=515.4369, Z min=95.5261, Z max=156.0654
# Timestep 7680: P min=177.7759, P max=506.1969, Z min=94.6844, Z max=154.6474
# Timestep 7700: P min=178.9039, P max=497.2980, Z min=93.7648, Z max=153.2553
# Timestep 7720: P min=180.1136, P max=488.7425, Z min=92.7730, Z max=151.8897
# Timestep 7740: P min=181.4044, P max=480.5314, Z min=91.7147, Z max=150.5513
# Timestep 7760: P min=182.7757, P max=472.6643, Z min=90.5955, Z max=149.2409
# Timestep 7780: P min=184.2271, P max=465.1397, Z min=89.4210, Z max=147.9589
# Timestep 7800: P min=185.7581, P max=457.9549, Z min=88.1968, Z max=146.7060
# Timestep 7820: P min=187.3682, P max=451.1062, Z min=86.9283, Z max=145.4826
# Timestep 7840: P min=189.0569, P max=444.5894, Z min=85.6206, Z max=144.2894
# Timestep 7860: P min=190.8238, P max=438.3992, Z min=84.2790, Z max=143.1268
# Timestep 7880: P min=192.6685, P max=432.5302, Z min=82.9084, Z max=141.9951
# Timestep 7900: P min=194.5904, P max=426.9763, Z min=81.5134, Z max=140.8950
# Timestep 7920: P min=196.5892, P max=421.7310, Z min=80.0987, Z max=139.8266
# Timestep 7940: P min=198.6643, P max=416.7876, Z min=78.6683, Z max=138.7905
# Timestep 7960: P min=200.8153, P max=412.1393, Z min=77.2264, Z max=137.7870
# Timestep 7980: P min=203.0416, P max=407.7790, Z min=75.7768, Z max=136.8164
# Timestep 8000: P min=205.3428, P max=403.6995, Z min=74.3230, Z max=135.8790
# Timestep 8020: P min=207.7182, P max=399.8938, Z min=72.8684, Z max=134.9752
# Timestep 8040: P min=210.1673, P max=396.3547, Z min=71.4160, Z max=134.1053
# Timestep 8060: P min=212.6894, P max=393.0753, Z min=69.9687, Z max=133.2696
# Timestep 8080: P min=215.2839, P max=390.0485, Z min=68.5291, Z max=132.4683
# Timestep 8100: P min=217.9499, P max=387.2675, Z min=67.0996, Z max=131.7017
# Timestep 8120: P min=220.6867, P max=384.7257, Z min=65.6826, Z max=130.9702
# Timestep 8140: P min=223.4934, P max=382.4166, Z min=64.2798, Z max=130.2739
# Timestep 8160: P min=226.3690, P max=380.3338, Z min=62.8933, Z max=129.6131
# Timestep 8180: P min=229.3127, P max=378.4712, Z min=61.5245, Z max=128.9881
# Timestep 8200: P min=232.3232, P max=376.8229, Z min=60.1750, Z max=128.3992
# Timestep 8220: P min=235.3993, P max=375.3831, Z min=58.8461, Z max=127.8466
# Timestep 8240: P min=238.5399, P max=374.1464, Z min=57.5388, Z max=127.3307
# Timestep 8260: P min=241.7435, P max=373.1075, Z min=56.2542, Z max=126.8516
# Timestep 8280: P min=245.0085, P max=372.2612, Z min=54.9932, Z max=126.4096
# Timestep 8300: P min=248.3334, P max=371.6028, Z min=53.7564, Z max=126.0051
# Timestep 8320: P min=251.7165, P max=371.1275, Z min=52.5446, Z max=125.6382
# Timestep 8340: P min=255.1557, P max=370.8310, Z min=51.3581, Z max=125.3094
# Timestep 8360: P min=258.6492, P max=370.7090, Z min=50.1974, Z max=125.0188
# Timestep 8380: P min=262.1947, P max=370.7576, Z min=49.0628, Z max=124.7668
# Timestep 8400: P min=265.7899, P max=370.9727, Z min=47.9545, Z max=124.5537
# Timestep 8420: P min=269.4324, P max=371.3510, Z min=46.8728, Z max=124.3799
# Timestep 8440: P min=273.1194, P max=371.8888, Z min=45.8176, Z max=124.2455
# Timestep 8460: P min=276.8482, P max=372.5829, Z min=44.7889, Z max=124.1510
# Timestep 8480: P min=280.6157, P max=373.4302, Z min=43.7868, Z max=124.0966
# Timestep 8500: P min=284.4187, P max=374.4278, Z min=42.8111, Z max=124.0828
# Timestep 8520: P min=288.2538, P max=375.5729, Z min=41.8618, Z max=124.1098
# Timestep 8540: P min=292.1174, P max=376.8628, Z min=40.9385, Z max=124.1781
# Timestep 8560: P min=296.0058, P max=378.2952, Z min=40.0411, Z max=124.2878
# Timestep 8580: P min=299.9149, P max=379.8677, Z min=39.1693, Z max=124.4395
# Timestep 8600: P min=303.8404, P max=381.5781, Z min=38.3229, Z max=124.6334
# Timestep 8620: P min=307.7780, P max=383.4243, Z min=37.5014, Z max=124.8698
# Timestep 8640: P min=311.7230, P max=386.2808, Z min=36.7047, Z max=125.1492
# Timestep 8660: P min=315.6705, P max=390.2538, Z min=35.9323, Z max=125.4719
# Timestep 8680: P min=319.6154, P max=394.3616, Z min=35.1839, Z max=125.8381
# Timestep 8700: P min=323.5524, P max=398.6034, Z min=34.4591, Z max=126.2482
# Timestep 8720: P min=327.4759, P max=402.9778, Z min=33.7576, Z max=126.7026
# Timestep 8740: P min=331.3803, P max=407.4839, Z min=33.0788, Z max=127.2014
# Timestep 8760: P min=335.2596, P max=412.1202, Z min=32.4225, Z max=127.7450
# Timestep 8780: P min=339.1076, P max=416.8855, Z min=31.7882, Z max=128.3337
# Timestep 8800: P min=342.9180, P max=421.7783, Z min=31.1755, Z max=128.9676
# Timestep 8820: P min=346.6842, P max=426.7969, Z min=30.5841, Z max=129.6469
# Timestep 8840: P min=350.3997, P max=431.9396, Z min=30.0134, Z max=130.3718
# Timestep 8860: P min=354.0575, P max=437.2046, Z min=29.4632, Z max=131.1424
# Timestep 8880: P min=357.6506, P max=442.5899, Z min=28.9331, Z max=131.9588
# Timestep 8900: P min=361.1719, P max=448.0932, Z min=28.4225, Z max=132.8210
# Timestep 8920: P min=364.6143, P max=453.7122, Z min=27.9313, Z max=133.7290
# Timestep 8940: P min=367.9704, P max=459.4443, Z min=27.4589, Z max=134.6827
# Timestep 8960: P min=371.2329, P max=465.2868, Z min=27.0050, Z max=135.6819
# Timestep 8980: P min=374.3945, P max=471.2368, Z min=26.5694, Z max=136.7265
# Timestep 9000: P min=377.4476, P max=477.2910, Z min=26.1516, Z max=137.8161
# Timestep 9020: P min=380.3851, P max=483.4460, Z min=25.7512, Z max=138.9504
# Timestep 9040: P min=383.1995, P max=489.6981, Z min=25.3681, Z max=140.1289
# Timestep 9060: P min=385.8838, P max=496.0433, Z min=25.0019, Z max=141.3510
# Timestep 9080: P min=388.4308, P max=502.4774, Z min=24.6522, Z max=142.6161
# Timestep 9100: P min=390.8336, P max=508.9957, Z min=24.3189, Z max=143.9235
# Timestep 9120: P min=393.0856, P max=515.5935, Z min=24.0016, Z max=145.2722
# Timestep 9140: P min=395.1803, P max=522.2655, Z min=23.7001, Z max=146.6613
# Timestep 9160: P min=397.1115, P max=529.0062, Z min=23.4142, Z max=148.0898
# Timestep 9180: P min=398.8733, P max=535.8095, Z min=23.1435, Z max=149.5563
# Timestep 9200: P min=400.4604, P max=542.6693, Z min=22.8881, Z max=151.0597
# Timestep 9220: P min=401.8674, P max=549.5787, Z min=22.6475, Z max=152.5983
# Timestep 9240: P min=403.0899, P max=556.5308, Z min=22.4217, Z max=154.1706
# Timestep 9260: P min=404.1235, P max=563.5178, Z min=22.2105, Z max=155.7750
# Timestep 9280: P min=404.9646, P max=570.5320, Z min=22.0138, Z max=157.4095
# Timestep 9300: P min=405.6099, P max=577.5648, Z min=21.8314, Z max=159.0721
# Timestep 9320: P min=406.0568, P max=584.6073, Z min=21.6633, Z max=160.7608
# Timestep 9340: P min=406.3032, P max=591.6503, Z min=21.5093, Z max=162.4734
# Timestep 9360: P min=406.3478, P max=598.6839, Z min=21.3694, Z max=164.2074
# Timestep 9380: P min=406.1896, P max=605.6977, Z min=21.2435, Z max=165.9604
# Timestep 9400: P min=405.8283, P max=612.6811, Z min=21.1316, Z max=167.7298
# Timestep 9420: P min=405.2645, P max=619.6226, Z min=21.0338, Z max=169.5129
# Timestep 9440: P min=404.4991, P max=626.5105, Z min=20.9499, Z max=171.3070
# Timestep 9460: P min=403.5337, P max=633.3327, Z min=20.8800, Z max=173.1091
# Timestep 9480: P min=402.3708, P max=640.0762, Z min=20.8243, Z max=174.9163
# Timestep 9500: P min=401.0130, P max=646.7280, Z min=20.7827, Z max=176.7256
# Timestep 9520: P min=399.4640, P max=653.2745, Z min=20.7554, Z max=178.5339
# Timestep 9540: P min=397.7277, P max=659.7016, Z min=20.7425, Z max=180.3380
# Timestep 9560: P min=395.8088, P max=665.9948, Z min=20.7441, Z max=182.1348
# Timestep 9580: P min=393.7123, P max=672.1394, Z min=20.7604, Z max=183.9210
# Timestep 9600: P min=391.4437, P max=678.1202, Z min=20.7917, Z max=185.6936
# Timestep 9620: P min=389.0092, P max=683.9220, Z min=20.8380, Z max=187.4492
# Timestep 9640: P min=386.4151, P max=689.5290, Z min=20.8998, Z max=189.1847
# Timestep 9660: P min=383.6682, P max=694.9255, Z min=20.9772, Z max=190.8969
# Timestep 9680: P min=380.7756, P max=700.0958, Z min=21.0706, Z max=192.5828
# Timestep 9700: P min=377.7446, P max=705.0238, Z min=21.1803, Z max=194.2392
# Timestep 9720: P min=374.5828, P max=709.6940, Z min=21.3067, Z max=195.8631
# Timestep 9740: P min=371.2979, P max=714.0905, Z min=21.4502, Z max=197.4515
# Timestep 9760: P min=367.8980, P max=718.1981, Z min=21.6113, Z max=199.0018
# Timestep 9780: P min=364.3909, P max=722.0017, Z min=21.7903, Z max=200.5110
# Timestep 9800: P min=360.7849, P max=725.4868, Z min=21.9879, Z max=201.9765
# Timestep 9820: P min=357.0879, P max=728.6395, Z min=22.2044, Z max=203.3958
# Timestep 9840: P min=353.3082, P max=731.4465, Z min=22.4407, Z max=204.7664
# Timestep 9860: P min=349.4537, P max=733.8955, Z min=22.6972, Z max=206.0860
# Timestep 9880: P min=345.5324, P max=735.9750, Z min=22.9746, Z max=207.3524
# Timestep 9900: P min=341.5523, P max=737.6746, Z min=23.2736, Z max=208.5636
# Timestep 9920: P min=337.5211, P max=738.9852, Z min=23.5949, Z max=209.7175
# Timestep 9940: P min=333.4464, P max=745.9971, Z min=23.9394, Z max=210.8125
# Timestep 9960: P min=329.3358, P max=753.7591, Z min=24.3078, Z max=211.8468
# Timestep 9980: P min=325.1966, P max=761.4854, Z min=24.7011, Z max=212.8189

# %%
def generate_perturbed_initial_conditions(n_members, x_span, y_span, nx, nz):
    gen = lambda span: np.random.uniform(span[0], span[1], (nz, nx, n_members))
    P0_ensemble = gen(x_span)  # Prey initial conditions
    Z0_ensemble = gen(y_span)  # Predator initial conditions
    return P0_ensemble, Z0_ensemble

def run_ensemble_simulation(grid, params, timesteps, P0_ensemble, Z0_ensemble):
    n_members = P0_ensemble.shape[-1]
    P_history_ensemble = []
    Z_history_ensemble = []

    for i in range(n_members):
        P, Z = P0_ensemble[:, :, i], Z0_ensemble[:, :, i]
        P_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        Z_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        P_history[0, :, :] = P
        Z_history[0, :, :] = Z
        
        for t in range(1, timesteps):
            P, Z = predator_prey_advection_diffusion_step(
                P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
            )
            P_history[t, :, :] = P
            Z_history[t, :, :] = Z

        P_history_ensemble.append(P_history)
        Z_history_ensemble.append(Z_history)

    return np.array(P_history_ensemble), np.array(Z_history_ensemble)

def plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx, nz):
    n_members = P_history_ensemble.shape[0]  # Number of ensemble members
    cmap = plt.cm.RdYlBu(np.linspace(0, 1, n_members))  # Colour map for ensemble runs

    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    
    for i in range(nz):  # Rows
        for j in range(nx):  # Columns
            ax = axes[i, j]
            
            # Overlay trajectories for each ensemble member
            for k in range(n_members):
                P_traj = P_history_ensemble[k, :, i, j]  # Prey trajectory for cell (i, j)
                Z_traj = Z_history_ensemble[k, :, i, j]  # Predator trajectory for cell (i, j)
                ax.plot(P_traj, Z_traj, color=cmap[k], lw=0.5, label=f"Run {k+1}" if k == 0 else "")  # Label only once
            
            # Formatting
            ax.set_title(f"Cell ({i}, {j})")
            if i == nz - 1:
                ax.set_xlabel("Prey Density")
            if j == 0:
                ax.set_ylabel("Predator Density")
            ax.grid(True)

    plt.tight_layout()
    plt.show()

# Parameters
n_members = 12 # Number of graphs plotted in phase
x_span, y_span = (375, 425), (95, 105) # Starting conditions

# Generate perturbed initial conditions
P0_ensemble, Z0_ensemble = generate_perturbed_initial_conditions(n_members, x_span, y_span, nx=5, nz=5)

# Simulate for all ensemble members
P_history_ensemble, Z_history_ensemble = run_ensemble_simulation(grid, params, timesteps=10000, P0_ensemble=P0_ensemble, Z0_ensemble=Z0_ensemble)

# Plot the results
plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx=5, nz=5)
