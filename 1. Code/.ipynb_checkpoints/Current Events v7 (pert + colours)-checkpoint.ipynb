# %%
import numpy as np
import matplotlib.pyplot as plt


def stable_time_step(vx, Dx, Dz, dx, dz):
    dx2, dz2 = dx * dx, dz * dz
    max_diffusion = max(np.max(Dx), np.max(Dz), 1.0e-10)
    max_velocity = max(np.max(vx), 1.0e-10)
    diffusive_dt = dx2 * dz2 / (2 * max_diffusion * (dx2 + dz2))
    cfl_dt = dx / max_velocity
    dt = min(cfl_dt, diffusive_dt) * 0.5
    return min(dt, 0.002)  # MAKING THIS SMALLER WORKED


def euler_advection_diffusion_timestep(c0, vx, Dx, Dz, src, dt, dx, dz, inversion=True, upwind=True):
    nz, nx = c0.shape
    c = c0.copy()

    # Compute stability limits
    dt_advection = min(dx, dz) / np.max(np.abs(vx))
    dt_diffusion = min(dx**2, dz**2) / (2 * np.max([Dx.max(), Dz.max()]))
    dt_stable = min(dt_advection, dt_diffusion)
    
    if dt > dt_stable:
        print(f"Warning: dt={dt} exceeds stable timestep={dt_stable:.5f}. Adjusting dt.")
        dt = dt_stable
    
    # Storage for face-centered fluxes
    Fx = np.zeros((nz, nx + 1))
    Fz = np.zeros((nz + 1, nx))

    # Diffusive fluxes (per unit volume)
    Fx[:, 1:nx] = -Dx[:, 1:nx] * (c[:, 1:nx] - c[:, 0:nx-1]) / (dx * dx)
    Fz[1:nz, :] = -Dz[1:nz, :] * (c[1:nz, :] - c[0:nz-1, :]) / (dz * dz)

    # Advective fluxes
    if upwind:
        Fx[:, 1:nx] += np.where(vx[:, 1:nx] > 0,
                                vx[:, 1:nx] * c[:, 0:nx-1],
                                vx[:, 1:nx] * c[:, 1:nx]) / dx
    else:
        Fx[:, 1:nx] += vx[:, 1:nx] * (c[:, 0:nx-1] + c[:, 1:nx]) * 0.5 / dx

    # Update concentrations in interior cells
    c[0:nz, 0:nx] += dt * (
        -(Fx[0:nz, 1:nx+1] - Fx[0:nz, 0:nx])
        -(Fz[1:nz+1, 0:nx] - Fz[0:nz, 0:nx])
        + src[0:nz, 0:nx]
    )

    # Enforce non-negativity
    c = np.maximum(c, 0)

    return c


def create_grid(P0, Z0, domain_size, params):
    if P0.shape != Z0.shape:
        raise ValueError(f"P0 and Z0 must have the same shape. Got P0.shape={P0.shape}, Z0.shape={Z0.shape}")

    nz, nx = P0.shape
    dx = domain_size[0] / nx
    dz = domain_size[1] / nz

    vx = np.full((nz, nx + 1), params['current_velocity'])
    Dx = np.full((nz, nx + 1), params['diffusion'])
    Dz = np.full((nz + 1, nx), params['diffusion'])

    dt = stable_time_step(vx, Dx, Dz, dx, dz)
    print(f"Stable timestep: {dt:.5f}s")

    return {'nz': nz, 'nx': nx, 'dx': dx, 'dz': dz, 'vx': vx, 'Dx': Dx, 'Dz': Dz, 'dt': dt, 'P': P0.copy(), 'Z': Z0.copy()}


def lotka_volterra_sources(P, Z, params):
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    K = max(K, 1.0e-6)
    P = np.maximum(P, 1e-6)
    Z = np.maximum(Z, 1e-6)

    prey_growth = alpha * P * (1.0 - P / K)
    prey_death = -beta * P * Z
    predator_gain = delta * beta * P * Z
    predator_death = -gamma * Z

    src_prey = prey_growth + prey_death
    src_pred = predator_gain + predator_death

    # Add optional noise for debugging symmetry
   # noise = np.random.normal(0, 0.01, size=src_prey.shape)
   # src_prey += noise
   # src_pred += noise

    return src_prey, src_pred


def predator_prey_advection_diffusion_step(P, Z, vx, Dx, Dz, params, dt, dx, dz):
    src_prey, src_pred = lotka_volterra_sources(P, Z, params)

    P_updated = euler_advection_diffusion_timestep(P, vx, Dx, Dz, src_prey, dt, dx, dz)
    Z_updated = euler_advection_diffusion_timestep(Z, vx, Dx, Dz, src_pred, dt, dx, dz)

    return P_updated, Z_updated

def run_simulation_and_visualise():
    global grid
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    nx, nz = 5, 5  # Grid size
    P0 = np.full((nz, nx), gamma / (delta * beta) + 200) # + np.random.uniform(-20, 20, (nz, nx))
    Z0 = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )
    domain_size = (10, 10)
    grid = create_grid(P0, Z0, domain_size, params)

    eq_p = np.full((nz, nx), gamma / (delta * beta))
    eq_z = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )

    print(eq_p) # I wanted to see the equilibria conidionts
    print(eq_z)
    
    P = grid['P'].astype(np.float64)
    Z = grid['Z'].astype(np.float64)

    timesteps = 10000  # Adjust to a reasonable number for visualisation
    P_history = np.zeros((timesteps, nz, nx))
    Z_history = np.zeros((timesteps, nz, nx))

    # Store initial conditions
    P_history[0, :, :] = P
    Z_history[0, :, :] = Z

    for t in range(1, timesteps):
        P, Z = predator_prey_advection_diffusion_step(
            P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
        )
        P_history[t, :, :] = P
        Z_history[t, :, :] = Z

        # Debugging information
        if t % 20 == 0:
            print(f"Timestep {t}: P min={np.min(P):.4f}, P max={np.max(P):.4f}, Z min={np.min(Z):.4f}, Z max={np.max(Z):.4f}")

    # Visualisation of phase plots
    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    for i in range(nz):
        for j in range(nx):
            ax = axes[i, j]
            ax.plot(P_history[:, i, j], Z_history[:, i, j], label=f"Cell ({i}, {j})")
            ax.set_title(f"Phase Plot: Cell ({i}, {j})")
            ax.set_xlabel("Prey Density")
            ax.set_ylabel("Predator Density")
            ax.legend()
    plt.tight_layout()
    plt.show()


params = {
    'alpha': 1.0,
    'beta': 0.01,
    'delta': 0.25,
    'gamma': 1.0,
    'K': 1000000000000000000000000000000000000000000000000000000.0, # its high as I just wanted to include the code at this point rather than just think about parameters
    'current_velocity': 0.01,
    'diffusion': 0.01
}

run_simulation_and_visualise()
# Out:
# Stable timestep: 0.00200s
# [[400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]]
# [[100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]]
# Timestep 20: P min=599.6531, P max=599.8883, Z min=101.9975, Z max=102.0394
# Timestep 40: P min=598.8238, P max=599.2831, Z min=104.0288, Z max=104.1167
# Timestep 60: P min=597.5065, P max=598.1773, Z min=106.0894, Z max=106.2274
# Timestep 80: P min=595.6980, P max=596.5662, Z min=108.1741, Z max=108.3664
# Timestep 100: P min=593.3977, P max=594.4479, Z min=110.2772, Z max=110.5279
# Timestep 120: P min=590.6076, P max=591.8231, Z min=112.3928, Z max=112.7060
# Timestep 140: P min=587.3325, P max=588.6954, Z min=114.5144, Z max=114.8941
# Timestep 160: P min=583.5799, P max=585.0712, Z min=116.6352, Z max=117.0853
# Timestep 180: P min=579.3601, P max=580.9601, Z min=118.7481, Z max=119.2723
# Timestep 200: P min=574.6863, P max=576.3743, Z min=120.8457, Z max=121.4475
# Timestep 220: P min=569.5742, P max=571.3292, Z min=122.9204, Z max=123.6031
# Timestep 240: P min=564.0422, P max=565.8428, Z min=124.9644, Z max=125.7308
# Timestep 260: P min=558.1113, P max=559.9357, Z min=126.9697, Z max=127.8225
# Timestep 280: P min=551.8043, P max=553.6311, Z min=128.9284, Z max=129.8698
# Timestep 300: P min=545.1467, P max=546.9545, Z min=130.8327, Z max=131.8644
# Timestep 320: P min=538.1652, P max=539.9333, Z min=132.6748, Z max=133.7982
# Timestep 340: P min=530.8885, P max=532.5967, Z min=134.4470, Z max=135.6630
# Timestep 360: P min=523.3464, P max=524.9753, Z min=136.1421, Z max=137.4511
# Timestep 380: P min=515.5696, P max=517.1009, Z min=137.7531, Z max=139.1550
# Timestep 400: P min=507.5895, P max=509.0060, Z min=139.2736, Z max=140.7676
# Timestep 420: P min=499.4380, P max=500.7237, Z min=140.6974, Z max=142.2825
# Timestep 440: P min=491.1468, P max=492.2871, Z min=142.0190, Z max=143.6936
# Timestep 460: P min=482.7475, P max=483.7294, Z min=143.2335, Z max=144.9955
# Timestep 480: P min=474.2711, P max=475.0829, Z min=144.3365, Z max=146.1834
# Timestep 500: P min=465.7481, P max=466.3797, Z min=145.3246, Z max=147.2533
# Timestep 520: P min=457.2075, P max=457.6503, Z min=146.1946, Z max=148.2017
# Timestep 540: P min=448.6774, P max=448.9244, Z min=146.9444, Z max=149.0262
# Timestep 560: P min=440.1845, P max=440.2301, Z min=147.5723, Z max=149.7247
# Timestep 580: P min=431.5938, P max=431.7538, Z min=148.0775, Z max=150.2962
# Timestep 600: P min=423.0405, P max=423.4088, Z min=148.4599, Z max=150.7402
# Timestep 620: P min=414.5931, P max=415.1713, Z min=148.7198, Z max=151.0570
# Timestep 640: P min=406.2726, P max=407.0610, Z min=148.8584, Z max=151.2475
# Timestep 660: P min=398.0982, P max=399.0961, Z min=148.8774, Z max=151.3134
# Timestep 680: P min=390.0871, P max=391.2929, Z min=148.7789, Z max=151.2567
# Timestep 700: P min=382.2548, P max=383.6657, Z min=148.5657, Z max=151.0802
# Timestep 720: P min=374.6145, P max=376.2273, Z min=148.2411, Z max=150.7872
# Timestep 740: P min=367.1780, P max=368.9888, Z min=147.8085, Z max=150.3812
# Timestep 760: P min=359.9551, P max=361.9593, Z min=147.2720, Z max=149.8662
# Timestep 780: P min=352.9543, P max=355.1468, Z min=146.6359, Z max=149.2468
# Timestep 800: P min=346.1820, P max=348.5577, Z min=145.9045, Z max=148.5275
# Timestep 820: P min=339.6438, P max=342.1969, Z min=145.0828, Z max=147.7131
# Timestep 840: P min=333.3435, P max=336.0683, Z min=144.1754, Z max=146.8089
# Timestep 860: P min=327.2839, P max=330.1744, Z min=143.1876, Z max=145.8199
# Timestep 880: P min=321.4666, P max=324.5169, Z min=142.1243, Z max=144.7515
# Timestep 900: P min=315.8924, P max=319.0965, Z min=140.9906, Z max=143.6089
# Timestep 920: P min=310.5610, P max=313.9130, Z min=139.7918, Z max=142.3976
# Timestep 940: P min=305.4715, P max=308.9655, Z min=138.5328, Z max=141.1229
# Timestep 960: P min=300.6221, P max=304.2525, Z min=137.2188, Z max=139.7899
# Timestep 980: P min=296.0107, P max=299.7719, Z min=135.8546, Z max=138.4040
# Timestep 1000: P min=291.6345, P max=295.5212, Z min=134.4452, Z max=136.9701
# Timestep 1020: P min=287.4904, P max=291.4975, Z min=132.9953, Z max=135.4932
# Timestep 1040: P min=283.5749, P max=287.6974, Z min=131.5095, Z max=133.9781
# Timestep 1060: P min=279.8842, P max=284.1176, Z min=129.9922, Z max=132.4296
# Timestep 1080: P min=276.4145, P max=280.7542, Z min=128.4478, Z max=130.8519
# Timestep 1100: P min=273.1615, P max=277.6035, Z min=126.8802, Z max=129.2495
# Timestep 1120: P min=270.1212, P max=274.6614, Z min=125.2935, Z max=127.6265
# Timestep 1140: P min=267.2891, P max=271.9239, Z min=123.6915, Z max=125.9868
# Timestep 1160: P min=264.6610, P max=269.3869, Z min=122.0777, Z max=124.3341
# Timestep 1180: P min=262.2327, P max=267.0465, Z min=120.4554, Z max=122.6720
# Timestep 1200: P min=259.9999, P max=264.8986, Z min=118.8280, Z max=121.0039
# Timestep 1220: P min=257.9584, P max=262.9393, Z min=117.1984, Z max=119.3328
# Timestep 1240: P min=256.1042, P max=261.1648, Z min=115.5696, Z max=117.6619
# Timestep 1260: P min=254.4333, P max=259.5711, Z min=113.9441, Z max=115.9938
# Timestep 1280: P min=252.9418, P max=258.1548, Z min=112.3245, Z max=114.3313
# Timestep 1300: P min=251.6260, P max=256.9122, Z min=110.7131, Z max=112.6767
# Timestep 1320: P min=250.4824, P max=255.8400, Z min=109.1122, Z max=111.0323
# Timestep 1340: P min=249.5076, P max=254.9349, Z min=107.5238, Z max=109.4003
# Timestep 1360: P min=248.6982, P max=254.1938, Z min=105.9497, Z max=107.7826
# Timestep 1380: P min=248.0511, P max=253.6138, Z min=104.3917, Z max=106.1811
# Timestep 1400: P min=247.5635, P max=253.1920, Z min=102.8515, Z max=104.5974
# Timestep 1420: P min=247.2326, P max=252.9257, Z min=101.3304, Z max=103.0331
# Timestep 1440: P min=247.0557, P max=252.8126, Z min=99.8299, Z max=101.4895
# Timestep 1460: P min=247.0303, P max=252.8501, Z min=98.3512, Z max=99.9680
# Timestep 1480: P min=247.1543, P max=253.0362, Z min=96.8954, Z max=98.4698
# Timestep 1500: P min=247.4255, P max=253.3688, Z min=95.4637, Z max=96.9959
# Timestep 1520: P min=247.8418, P max=253.8460, Z min=94.0569, Z max=95.5474
# Timestep 1540: P min=248.4015, P max=254.4659, Z min=92.6758, Z max=94.1250
# Timestep 1560: P min=249.1028, P max=255.2270, Z min=91.3214, Z max=92.7296
# Timestep 1580: P min=249.9443, P max=256.1278, Z min=89.9941, Z max=91.3620
# Timestep 1600: P min=250.9245, P max=257.1668, Z min=88.6948, Z max=90.0227
# Timestep 1620: P min=252.0421, P max=258.3429, Z min=87.4238, Z max=88.7123
# Timestep 1640: P min=253.2960, P max=259.6549, Z min=86.1818, Z max=87.4313
# Timestep 1660: P min=254.6851, P max=261.1017, Z min=84.9691, Z max=86.1802
# Timestep 1680: P min=256.2085, P max=262.6825, Z min=83.7861, Z max=84.9594
# Timestep 1700: P min=257.8654, P max=264.3963, Z min=82.6332, Z max=83.7691
# Timestep 1720: P min=259.6550, P max=266.2426, Z min=81.5107, Z max=82.6098
# Timestep 1740: P min=261.5767, P max=268.2205, Z min=80.4188, Z max=81.4816
# Timestep 1760: P min=263.6300, P max=270.3296, Z min=79.3577, Z max=80.3848
# Timestep 1780: P min=265.8144, P max=272.5692, Z min=78.3276, Z max=79.3195
# Timestep 1800: P min=268.1294, P max=274.9390, Z min=77.3287, Z max=78.2860
# Timestep 1820: P min=270.5748, P max=277.4385, Z min=76.3611, Z max=77.2843
# Timestep 1840: P min=273.1501, P max=280.0675, Z min=75.4249, Z max=76.3145
# Timestep 1860: P min=275.8553, P max=282.8254, Z min=74.5202, Z max=75.3768
# Timestep 1880: P min=278.6899, P max=285.7122, Z min=73.6472, Z max=74.4713
# Timestep 1900: P min=281.6539, P max=288.7274, Z min=72.8059, Z max=73.5980
# Timestep 1920: P min=284.7471, P max=291.8708, Z min=71.9964, Z max=72.7569
# Timestep 1940: P min=287.9694, P max=295.1422, Z min=71.2186, Z max=71.9482
# Timestep 1960: P min=291.3204, P max=298.5413, Z min=70.4728, Z max=71.1718
# Timestep 1980: P min=294.8001, P max=302.0677, Z min=69.7589, Z max=70.4278
# Timestep 2000: P min=298.4083, P max=305.7211, Z min=69.0771, Z max=69.7163
# Timestep 2020: P min=302.1447, P max=309.5012, Z min=68.4273, Z max=69.0374
# Timestep 2040: P min=306.0090, P max=313.4076, Z min=67.8097, Z max=68.3910
# Timestep 2060: P min=310.0008, P max=317.4396, Z min=67.2243, Z max=67.7773
# Timestep 2080: P min=314.1199, P max=321.5968, Z min=66.6712, Z max=67.1964
# Timestep 2100: P min=318.3656, P max=325.8785, Z min=66.1506, Z max=66.6483
# Timestep 2120: P min=322.7374, P max=330.2839, Z min=65.6626, Z max=66.1331
# Timestep 2140: P min=327.2345, P max=334.8121, Z min=65.2073, Z max=65.6511
# Timestep 2160: P min=331.8561, P max=339.4620, Z min=64.7848, Z max=65.2022
# Timestep 2180: P min=336.6012, P max=344.2325, Z min=64.3954, Z max=64.7868
# Timestep 2200: P min=341.4687, P max=349.1221, Z min=64.0393, Z max=64.4049
# Timestep 2220: P min=346.4572, P max=354.1294, Z min=63.7166, Z max=64.0569
# Timestep 2240: P min=351.5652, P max=359.2525, Z min=63.4277, Z max=63.7429
# Timestep 2260: P min=356.7910, P max=364.4895, Z min=63.1728, Z max=63.4632
# Timestep 2280: P min=362.1325, P max=369.8381, Z min=62.9522, Z max=63.2181
# Timestep 2300: P min=367.5876, P max=375.2958, Z min=62.7663, Z max=63.0080
# Timestep 2320: P min=373.1537, P max=380.8599, Z min=62.6154, Z max=62.8331
# Timestep 2340: P min=378.8279, P max=386.5271, Z min=62.4999, Z max=62.6940
# Timestep 2360: P min=384.6072, P max=392.2941, Z min=62.4203, Z max=62.5910
# Timestep 2380: P min=390.4879, P max=398.1571, Z min=62.3771, Z max=62.5246
# Timestep 2400: P min=396.4663, P max=404.1119, Z min=62.3707, Z max=62.4953
# Timestep 2420: P min=402.5381, P max=410.1539, Z min=62.4018, Z max=62.5037
# Timestep 2440: P min=408.6985, P max=416.2781, Z min=62.4708, Z max=62.5503
# Timestep 2460: P min=414.9423, P max=422.4790, Z min=62.5785, Z max=62.6358
# Timestep 2480: P min=421.2640, P max=428.7506, Z min=62.7254, Z max=62.7608
# Timestep 2500: P min=427.6573, P max=435.0865, Z min=62.9067, Z max=62.9338
# Timestep 2520: P min=434.1157, P max=441.4797, Z min=63.1232, Z max=63.1513
# Timestep 2540: P min=440.6317, P max=447.9225, Z min=63.3802, Z max=63.4103
# Timestep 2560: P min=447.1975, P max=454.4068, Z min=63.6708, Z max=63.7205
# Timestep 2580: P min=453.8048, P max=460.9239, Z min=64.0048, Z max=64.0751
# Timestep 2600: P min=460.4442, P max=467.4643, Z min=64.3832, Z max=64.4737
# Timestep 2620: P min=467.1061, P max=474.0179, Z min=64.8070, Z max=64.9173
# Timestep 2640: P min=473.7800, P max=480.5741, Z min=65.2770, Z max=65.4067
# Timestep 2660: P min=480.4546, P max=487.1212, Z min=65.7943, Z max=65.9431
# Timestep 2680: P min=487.1181, P max=493.6473, Z min=66.3600, Z max=66.5273
# Timestep 2700: P min=493.7576, P max=500.1394, Z min=66.9750, Z max=67.1604
# Timestep 2720: P min=500.3598, P max=506.5839, Z min=67.6405, Z max=67.8433
# Timestep 2740: P min=506.9104, P max=512.9664, Z min=68.3576, Z max=68.5772
# Timestep 2760: P min=513.3945, P max=519.2719, Z min=69.1273, Z max=69.3630
# Timestep 2780: P min=519.7962, P max=525.4845, Z min=69.9507, Z max=70.2017
# Timestep 2800: P min=526.0990, P max=531.5878, Z min=70.8289, Z max=71.0944
# Timestep 2820: P min=532.2857, P max=537.5645, Z min=71.7629, Z max=72.0419
# Timestep 2840: P min=538.3382, P max=543.3969, Z min=72.7538, Z max=73.0451
# Timestep 2860: P min=544.2380, P max=549.0663, Z min=73.8024, Z max=74.1050
# Timestep 2880: P min=549.9656, P max=554.5539, Z min=74.9098, Z max=75.2221
# Timestep 2900: P min=555.5013, P max=559.8401, Z min=76.0765, Z max=76.3973
# Timestep 2920: P min=560.8245, P max=564.9049, Z min=77.3035, Z max=77.6311
# Timestep 2940: P min=565.9145, P max=569.7281, Z min=78.5911, Z max=78.9238
# Timestep 2960: P min=570.7501, P max=574.2891, Z min=79.9399, Z max=80.2757
# Timestep 2980: P min=575.3099, P max=578.5673, Z min=81.3501, Z max=81.6869
# Timestep 3000: P min=579.5725, P max=582.5419, Z min=82.8218, Z max=83.1573
# Timestep 3020: P min=583.5163, P max=586.1926, Z min=84.3547, Z max=84.6864
# Timestep 3040: P min=587.1201, P max=589.4991, Z min=85.9485, Z max=86.2738
# Timestep 3060: P min=590.3630, P max=592.4416, Z min=87.6024, Z max=87.9184
# Timestep 3080: P min=593.2246, P max=595.0009, Z min=89.3155, Z max=89.6192
# Timestep 3100: P min=595.6852, P max=597.1588, Z min=91.0864, Z max=91.3744
# Timestep 3120: P min=597.7260, P max=598.8980, Z min=92.9134, Z max=93.1823
# Timestep 3140: P min=599.3296, P max=600.2023, Z min=94.7944, Z max=95.0405
# Timestep 3160: P min=600.4795, P max=601.0570, Z min=96.7270, Z max=96.9464
# Timestep 3180: P min=601.1611, P max=601.4492, Z min=98.7081, Z max=98.8968
# Timestep 3200: P min=601.2943, P max=601.4464, Z min=100.7343, Z max=100.8881
# Timestep 3220: P min=600.8028, P max=601.0698, Z min=102.8018, Z max=102.9162
# Timestep 3240: P min=599.7481, P max=600.2772, Z min=104.9061, Z max=104.9769
# Timestep 3260: P min=598.1987, P max=598.9774, Z min=107.0336, Z max=107.0874
# Timestep 3280: P min=596.1524, P max=597.1667, Z min=109.1709, Z max=109.2236
# Timestep 3300: P min=593.6099, P max=594.8440, Z min=111.3014, Z max=111.3894
# Timestep 3320: P min=590.5744, P max=592.0110, Z min=113.4377, Z max=113.5879
# Timestep 3340: P min=587.0519, P max=588.6724, Z min=115.5773, Z max=115.7941
# Timestep 3360: P min=583.0513, P max=584.8359, Z min=117.7131, Z max=118.0011
# Timestep 3380: P min=578.5844, P max=580.5122, Z min=119.8378, Z max=120.2012
# Timestep 3400: P min=573.6656, P max=575.7147, Z min=121.9438, Z max=122.3867
# Timestep 3420: P min=568.3122, P max=570.4601, Z min=124.0233, Z max=124.5494
# Timestep 3440: P min=562.5440, P max=564.7675, Z min=126.0683, Z max=126.6812
# Timestep 3460: P min=556.3832, P max=558.6589, Z min=128.0707, Z max=128.7737
# Timestep 3480: P min=549.8541, P max=552.1587, Z min=130.0226, Z max=130.8183
# Timestep 3500: P min=542.9832, P max=545.2933, Z min=131.9160, Z max=132.8068
# Timestep 3520: P min=535.7985, P max=538.0913, Z min=133.7430, Z max=134.7309
# Timestep 3540: P min=528.3297, P max=530.5828, Z min=135.4962, Z max=136.5824
# Timestep 3560: P min=520.6075, P max=522.7994, Z min=137.1683, Z max=138.3537
# Timestep 3580: P min=512.6633, P max=514.7734, Z min=138.7524, Z max=140.0374
# Timestep 3600: P min=504.5293, P max=506.5382, Z min=140.2421, Z max=141.6264
# Timestep 3620: P min=496.2376, P max=498.1272, Z min=141.6315, Z max=143.1143
# Timestep 3640: P min=487.8206, P max=489.5740, Z min=142.9152, Z max=144.4954
# Timestep 3660: P min=479.3098, P max=480.9119, Z min=144.0887, Z max=145.7643
# Timestep 3680: P min=470.7366, P max=472.1736, Z min=145.1478, Z max=146.9164
# Timestep 3700: P min=462.1310, P max=463.3909, Z min=146.0891, Z max=147.9481
# Timestep 3720: P min=453.5221, P max=454.5944, Z min=146.9101, Z max=148.8560
# Timestep 3740: P min=444.9376, P max=445.8135, Z min=147.6087, Z max=149.6380
# Timestep 3760: P min=436.4037, P max=437.0759, Z min=148.1838, Z max=150.2924
# Timestep 3780: P min=427.9451, P max=428.4078, Z min=148.6347, Z max=150.8182
# Timestep 3800: P min=419.5827, P max=419.8335, Z min=148.9616, Z max=151.2154
# Timestep 3820: P min=411.2389, P max=411.4409, Z min=149.1653, Z max=151.4846
# Timestep 3840: P min=403.0328, P max=403.2401, Z min=149.2473, Z max=151.6268
# Timestep 3860: P min=394.8881, P max=395.2927, Z min=149.2093, Z max=151.6441
# Timestep 3880: P min=386.8940, P max=387.5165, Z min=149.0541, Z max=151.5388
# Timestep 3900: P min=379.0863, P max=379.9252, Z min=148.7846, Z max=151.3138
# Timestep 3920: P min=371.4780, P max=372.5307, Z min=148.4043, Z max=150.9727
# Timestep 3940: P min=364.0799, P max=365.3432, Z min=147.9169, Z max=150.5192
# Timestep 3960: P min=356.9014, P max=358.3713, Z min=147.3267, Z max=149.9577
# Timestep 3980: P min=349.9501, P max=351.6222, Z min=146.6380, Z max=149.2926
# Timestep 4000: P min=343.2321, P max=345.1016, Z min=145.8557, Z max=148.5287
# Timestep 4020: P min=336.7521, P max=338.8137, Z min=144.9846, Z max=147.6712
# Timestep 4040: P min=330.5136, P max=332.7618, Z min=144.0297, Z max=146.7252
# Timestep 4060: P min=324.5187, P max=326.9478, Z min=142.9960, Z max=145.6960
# Timestep 4080: P min=318.7687, P max=321.3730, Z min=141.8889, Z max=144.5889
# Timestep 4100: P min=313.2638, P max=316.0374, Z min=140.7134, Z max=143.4094
# Timestep 4120: P min=308.0034, P max=310.9405, Z min=139.4748, Z max=142.1629
# Timestep 4140: P min=302.9862, P max=306.0809, Z min=138.1782, Z max=140.8547
# Timestep 4160: P min=298.2100, P max=301.4567, Z min=136.8286, Z max=139.4900
# Timestep 4180: P min=293.6725, P max=297.0657, Z min=135.4310, Z max=138.0742
# Timestep 4200: P min=289.3706, P max=292.9048, Z min=133.9903, Z max=136.6122
# Timestep 4220: P min=285.3009, P max=288.9709, Z min=132.5112, Z max=135.1091
# Timestep 4240: P min=281.4598, P max=285.2606, Z min=130.9982, Z max=133.5695
# Timestep 4260: P min=277.8433, P max=281.7701, Z min=129.4558, Z max=131.9982
# Timestep 4280: P min=274.4473, P max=278.4956, Z min=127.8882, Z max=130.3995
# Timestep 4300: P min=271.2676, P max=275.4330, Z min=126.2995, Z max=128.7777
# Timestep 4320: P min=268.2998, P max=272.5782, Z min=124.6935, Z max=127.1370
# Timestep 4340: P min=265.5396, P max=269.9272, Z min=123.0740, Z max=125.4811
# Timestep 4360: P min=262.9827, P max=267.4758, Z min=121.4445, Z max=123.8138
# Timestep 4380: P min=260.6247, P max=265.2200, Z min=119.8082, Z max=122.1385
# Timestep 4400: P min=258.4613, P max=263.1556, Z min=118.1684, Z max=120.4586
# Timestep 4420: P min=256.4883, P max=261.2787, Z min=116.5280, Z max=118.7772
# Timestep 4440: P min=254.7017, P max=259.5854, Z min=114.8898, Z max=117.0972
# Timestep 4460: P min=253.0975, P max=258.0720, Z min=113.2564, Z max=115.4213
# Timestep 4480: P min=251.6718, P max=256.7348, Z min=111.6303, Z max=113.7521
# Timestep 4500: P min=250.4209, P max=255.5703, Z min=110.0137, Z max=112.0919
# Timestep 4520: P min=249.3413, P max=254.5751, Z min=108.4087, Z max=110.4431
# Timestep 4540: P min=248.4296, P max=253.7461, Z min=106.8174, Z max=108.8077
# Timestep 4560: P min=247.6825, P max=253.0801, Z min=105.2415, Z max=107.1875
# Timestep 4580: P min=247.0970, P max=252.5742, Z min=103.6828, Z max=105.5844
# Timestep 4600: P min=246.6701, P max=252.2256, Z min=102.1427, Z max=103.9999
# Timestep 4620: P min=246.3993, P max=252.0318, Z min=100.6227, Z max=102.4356
# Timestep 4640: P min=246.2817, P max=251.9903, Z min=99.1242, Z max=100.8929
# Timestep 4660: P min=246.3152, P max=252.0988, Z min=97.6482, Z max=99.3729
# Timestep 4680: P min=246.4974, P max=252.3551, Z min=96.1960, Z max=97.8769
# Timestep 4700: P min=246.8262, P max=252.7573, Z min=94.7684, Z max=96.4058
# Timestep 4720: P min=247.2997, P max=253.3035, Z min=93.3664, Z max=94.9606
# Timestep 4740: P min=247.9161, P max=253.9920, Z min=91.9908, Z max=93.5421
# Timestep 4760: P min=248.6739, P max=254.8212, Z min=90.6424, Z max=92.1511
# Timestep 4780: P min=249.5714, P max=255.7896, Z min=89.3217, Z max=90.7883
# Timestep 4800: P min=250.6073, P max=256.8961, Z min=88.0293, Z max=89.4543
# Timestep 4820: P min=251.7805, P max=258.1392, Z min=86.7659, Z max=88.1496
# Timestep 4840: P min=253.0897, P max=259.5181, Z min=85.5317, Z max=86.8747
# Timestep 4860: P min=254.5340, P max=261.0316, Z min=84.3273, Z max=85.6301
# Timestep 4880: P min=256.1125, P max=262.6789, Z min=83.1529, Z max=84.4159
# Timestep 4900: P min=257.8245, P max=264.4593, Z min=82.0090, Z max=83.2327
# Timestep 4920: P min=259.6691, P max=266.3720, Z min=80.8957, Z max=82.0807
# Timestep 4940: P min=261.6460, P max=268.4164, Z min=79.8133, Z max=80.9600
# Timestep 4960: P min=263.7544, P max=270.5920, Z min=78.7620, Z max=79.8710
# Timestep 4980: P min=265.9940, P max=272.8983, Z min=77.7419, Z max=78.8137
# Timestep 5000: P min=268.3645, P max=275.3349, Z min=76.7532, Z max=77.7883
# Timestep 5020: P min=270.8655, P max=277.9014, Z min=75.7961, Z max=76.7950
# Timestep 5040: P min=273.4966, P max=280.5975, Z min=74.8705, Z max=75.8338
# Timestep 5060: P min=276.2578, P max=283.4229, Z min=73.9767, Z max=74.9048
# Timestep 5080: P min=279.1489, P max=286.3774, Z min=73.1147, Z max=74.0081
# Timestep 5100: P min=282.1696, P max=289.4606, Z min=72.2845, Z max=73.1437
# Timestep 5120: P min=285.3197, P max=292.6724, Z min=71.4862, Z max=72.3118
# Timestep 5140: P min=288.5993, P max=296.0125, Z min=70.7199, Z max=71.5123
# Timestep 5160: P min=292.0081, P max=299.4806, Z min=69.9856, Z max=70.7452
# Timestep 5180: P min=295.5459, P max=303.0765, Z min=69.2834, Z max=70.0107
# Timestep 5200: P min=299.2125, P max=306.7998, Z min=68.6134, Z max=69.3088
# Timestep 5220: P min=303.0078, P max=310.6501, Z min=67.9755, Z max=68.6395
# Timestep 5240: P min=306.9314, P max=314.6270, Z min=67.3699, Z max=68.0030
# Timestep 5260: P min=310.9830, P max=318.7300, Z min=66.7967, Z max=67.3991
# Timestep 5280: P min=315.1621, P max=322.9586, Z min=66.2560, Z max=66.8282
# Timestep 5300: P min=319.4683, P max=327.3120, Z min=65.7478, Z max=66.2902
# Timestep 5320: P min=323.9010, P max=331.7893, Z min=65.2723, Z max=65.7852
# Timestep 5340: P min=328.4594, P max=336.3898, Z min=64.8297, Z max=65.3135
# Timestep 5360: P min=333.1426, P max=341.1123, Z min=64.4201, Z max=64.8751
# Timestep 5380: P min=337.9497, P max=345.9555, Z min=64.0437, Z max=64.4702
# Timestep 5400: P min=342.8794, P max=350.9181, Z min=63.7007, Z max=64.0990
# Timestep 5420: P min=347.9304, P max=355.9984, Z min=63.3913, Z max=63.7618
# Timestep 5440: P min=353.1010, P max=361.1946, Z min=63.1159, Z max=63.4588
# Timestep 5460: P min=358.3896, P max=366.5046, Z min=62.8746, Z max=63.1902
# Timestep 5480: P min=363.7940, P max=371.9261, Z min=62.6679, Z max=62.9565
# Timestep 5500: P min=369.3120, P max=377.4565, Z min=62.4961, Z max=62.7578
# Timestep 5520: P min=374.9408, P max=383.0929, Z min=62.3596, Z max=62.5946
# Timestep 5540: P min=380.6777, P max=388.8321, Z min=62.2587, Z max=62.4674
# Timestep 5560: P min=386.5193, P max=394.6704, Z min=62.1940, Z max=62.3765
# Timestep 5580: P min=392.4621, P max=400.6040, Z min=62.1659, Z max=62.3224
# Timestep 5600: P min=398.5020, P max=406.6285, Z min=62.1750, Z max=62.3057
# Timestep 5620: P min=404.6347, P max=412.7392, Z min=62.2218, Z max=62.3269
# Timestep 5640: P min=410.8552, P max=418.9308, Z min=62.3069, Z max=62.3867
# Timestep 5660: P min=417.1583, P max=425.1978, Z min=62.4310, Z max=62.4855
# Timestep 5680: P min=423.5381, P max=431.5338, Z min=62.5850, Z max=62.6360
# Timestep 5700: P min=429.9884, P max=437.9322, Z min=62.7758, Z max=62.8290
# Timestep 5720: P min=436.5021, P max=444.3858, Z min=63.0079, Z max=63.0632
# Timestep 5740: P min=443.0718, P max=450.8867, Z min=63.2820, Z max=63.3395
# Timestep 5760: P min=449.6896, P max=457.4265, Z min=63.5929, Z max=63.6617
# Timestep 5780: P min=456.3465, P max=463.9960, Z min=63.9426, Z max=64.0355
# Timestep 5800: P min=463.0333, P max=470.5857, Z min=64.3371, Z max=64.4538
# Timestep 5820: P min=469.7399, P max=477.1851, Z min=64.7775, Z max=64.9176
# Timestep 5840: P min=476.4556, P max=483.7830, Z min=65.2646, Z max=65.4279
# Timestep 5860: P min=483.1687, P max=490.3678, Z min=65.7995, Z max=65.9857
# Timestep 5880: P min=489.8671, P max=496.9268, Z min=66.3834, Z max=66.5920
# Timestep 5900: P min=496.5378, P max=503.4468, Z min=67.0171, Z max=67.2479
# Timestep 5920: P min=503.1669, P max=509.9138, Z min=67.7020, Z max=67.9543
# Timestep 5940: P min=509.7399, P max=516.3130, Z min=68.4389, Z max=68.7123
# Timestep 5960: P min=516.2414, P max=522.6289, Z min=69.2292, Z max=69.5229
# Timestep 5980: P min=522.6553, P max=528.8454, Z min=70.0738, Z max=70.3872
# Timestep 6000: P min=528.9647, P max=534.9453, Z min=70.9739, Z max=71.3061
# Timestep 6020: P min=535.1518, P max=540.9113, Z min=71.9304, Z max=72.2806
# Timestep 6040: P min=541.1984, P max=546.7248, Z min=72.9445, Z max=73.3117
# Timestep 6060: P min=547.0854, P max=552.3672, Z min=74.0170, Z max=74.4000
# Timestep 6080: P min=552.7931, P max=557.8188, Z min=75.1488, Z max=75.5464
# Timestep 6100: P min=558.3012, P max=563.0599, Z min=76.3408, Z max=76.7516
# Timestep 6120: P min=563.5890, P max=568.0701, Z min=77.5936, Z max=78.0159
# Timestep 6140: P min=568.6353, P max=572.8287, Z min=78.9077, Z max=79.3399
# Timestep 6160: P min=573.4187, P max=577.3150, Z min=80.2836, Z max=80.7236
# Timestep 6180: P min=577.9175, P max=581.5079, Z min=81.7214, Z max=82.1672
# Timestep 6200: P min=582.1099, P max=585.3867, Z min=83.2212, Z max=83.6705
# Timestep 6220: P min=585.9742, P max=588.9307, Z min=84.7827, Z max=85.2329
# Timestep 6240: P min=589.4891, P max=592.1194, Z min=86.4054, Z max=86.8537
# Timestep 6260: P min=592.6336, P max=594.9331, Z min=88.0886, Z max=88.5321
# Timestep 6280: P min=595.3871, P max=597.3528, Z min=89.8311, Z max=90.2666
# Timestep 6300: P min=597.7300, P max=599.3602, Z min=91.6316, Z max=92.0555
# Timestep 6320: P min=599.6438, P max=600.9382, Z min=93.4881, Z max=93.8968
# Timestep 6340: P min=601.1110, P max=602.0710, Z min=95.3984, Z max=95.7880
# Timestep 6360: P min=602.1156, P max=602.7445, Z min=97.3599, Z max=97.7262
# Timestep 6380: P min=602.6432, P max=602.9468, Z min=99.3695, Z max=99.7082
# Timestep 6400: P min=602.5313, P max=602.8369, Z min=101.4236, Z max=101.7301
# Timestep 6420: P min=601.8929, P max=602.2313, Z min=103.5180, Z max=103.7876
# Timestep 6440: P min=600.6236, P max=601.2505, Z min=105.6483, Z max=105.8762
# Timestep 6460: P min=598.8534, P max=599.7677, Z min=107.8094, Z max=107.9904
# Timestep 6480: P min=596.5812, P max=597.7685, Z min=109.9956, Z max=110.1311
# Timestep 6500: P min=593.8087, P max=595.2528, Z min=112.1950, Z max=112.3070
# Timestep 6520: P min=590.5402, P max=592.2233, Z min=114.3837, Z max=114.4927
# Timestep 6540: P min=586.7831, P max=588.6857, Z min=116.5758, Z max=116.6812
# Timestep 6560: P min=582.5476, P max=584.6487, Z min=118.7357, Z max=118.8654
# Timestep 6580: P min=577.8468, P max=580.1243, Z min=120.8715, Z max=121.0780
# Timestep 6600: P min=572.6964, P max=575.1270, Z min=122.9852, Z max=123.2735
# Timestep 6620: P min=567.1152, P max=569.6747, Z min=125.0690, Z max=125.4434
# Timestep 6640: P min=561.1241, P max=563.7877, Z min=127.1146, Z max=127.5793
# Timestep 6660: P min=554.7467, P max=557.4891, Z min=129.1140, Z max=129.6727
# Timestep 6680: P min=548.0086, P max=550.8044, Z min=131.0591, Z max=131.7151
# Timestep 6700: P min=540.9373, P max=543.7612, Z min=132.9417, Z max=133.6980
# Timestep 6720: P min=533.5620, P max=536.3888, Z min=134.7542, Z max=135.6131
# Timestep 6740: P min=525.9133, P max=528.7185, Z min=136.4890, Z max=137.4524
# Timestep 6760: P min=518.0226, P max=520.7824, Z min=138.1388, Z max=139.2080
# Timestep 6780: P min=509.9222, P max=512.6138, Z min=139.6969, Z max=140.8727
# Timestep 6800: P min=501.6447, P max=504.2465, Z min=141.1571, Z max=142.4396
# Timestep 6820: P min=493.2228, P max=495.7145, Z min=142.5136, Z max=143.9023
# Timestep 6840: P min=484.6890, P max=487.0516, Z min=143.7612, Z max=145.2551
# Timestep 6860: P min=476.0751, P max=478.2914, Z min=144.8955, Z max=146.4930
# Timestep 6880: P min=467.4124, P max=469.4666, Z min=145.9127, Z max=147.6117
# Timestep 6900: P min=458.7309, P max=460.6090, Z min=146.8097, Z max=148.6075
# Timestep 6920: P min=450.0595, P max=451.7492, Z min=147.5841, Z max=149.4775
# Timestep 6940: P min=441.4254, P max=442.9163, Z min=148.2342, Z max=150.2196
# Timestep 6960: P min=432.8547, P max=434.1377, Z min=148.7592, Z max=150.8325
# Timestep 6980: P min=424.3712, P max=425.4393, Z min=149.1587, Z max=151.3155
# Timestep 7000: P min=415.9973, P max=416.8448, Z min=149.4333, Z max=151.6689
# Timestep 7020: P min=407.7535, P max=408.3762, Z min=149.5839, Z max=151.8934
# Timestep 7040: P min=399.6026, P max=400.0534, Z min=149.6124, Z max=151.9904
# Timestep 7060: P min=391.5698, P max=391.9684, Z min=149.5209, Z max=151.9622
# Timestep 7080: P min=383.7172, P max=384.0942, Z min=149.3123, Z max=151.8113
# Timestep 7100: P min=376.0582, P max=376.4210, Z min=148.9898, Z max=151.5409
# Timestep 7120: P min=368.5505, P max=369.0681, Z min=148.5572, Z max=151.1548
# Timestep 7140: P min=361.1874, P max=361.9288, Z min=148.0183, Z max=150.6569
# Timestep 7160: P min=354.0493, P max=355.0111, Z min=147.3777, Z max=150.0517
# Timestep 7180: P min=347.1432, P max=348.3215, Z min=146.6400, Z max=149.3439
# Timestep 7200: P min=340.4748, P max=341.8649, Z min=145.8100, Z max=148.5384
# Timestep 7220: P min=334.0481, P max=335.6451, Z min=144.8927, Z max=147.6405
# Timestep 7240: P min=327.8661, P max=329.6647, Z min=143.8932, Z max=146.6554
# Timestep 7260: P min=321.9305, P max=323.9253, Z min=142.8168, Z max=145.5885
# Timestep 7280: P min=316.2421, P max=318.4273, Z min=141.6687, Z max=144.4453
# Timestep 7300: P min=310.8008, P max=313.1706, Z min=140.4542, Z max=143.2312
# Timestep 7320: P min=305.6054, P max=308.1541, Z min=139.1785, Z max=141.9516
# Timestep 7340: P min=300.6544, P max=303.3761, Z min=137.8467, Z max=140.6120
# Timestep 7360: P min=295.9454, P max=298.8344, Z min=136.4640, Z max=139.2177
# Timestep 7380: P min=291.4757, P max=294.5262, Z min=135.0352, Z max=137.7739
# Timestep 7400: P min=287.2419, P max=290.4486, Z min=133.5653, Z max=136.2855
# Timestep 7420: P min=283.2405, P max=286.5980, Z min=132.0590, Z max=134.7577
# Timestep 7440: P min=279.4676, P max=282.9708, Z min=130.5207, Z max=133.1951
# Timestep 7460: P min=275.9191, P max=279.5630, Z min=128.9549, Z max=131.6024
# Timestep 7480: P min=272.5908, P max=276.3707, Z min=127.3657, Z max=129.9839
# Timestep 7500: P min=269.4784, P max=273.3897, Z min=125.7572, Z max=128.3438
# Timestep 7520: P min=266.5773, P max=270.6158, Z min=124.1332, Z max=126.6863
# Timestep 7540: P min=263.8832, P max=268.0448, Z min=122.4974, Z max=125.0151
# Timestep 7560: P min=261.3916, P max=265.6726, Z min=120.8532, Z max=123.3339
# Timestep 7580: P min=259.0982, P max=263.4949, Z min=119.2038, Z max=121.6462
# Timestep 7600: P min=256.9987, P max=261.5078, Z min=117.5524, Z max=119.9551
# Timestep 7620: P min=255.0887, P max=259.7072, Z min=115.9019, Z max=118.2637
# Timestep 7640: P min=253.3643, P max=258.0892, Z min=114.2549, Z max=116.5749
# Timestep 7660: P min=251.8215, P max=256.6501, Z min=112.6141, Z max=114.8915
# Timestep 7680: P min=250.4563, P max=255.3862, Z min=110.9818, Z max=113.2158
# Timestep 7700: P min=249.2652, P max=254.2940, Z min=109.3602, Z max=111.5502
# Timestep 7720: P min=248.2446, P max=253.3703, Z min=107.7514, Z max=109.8969
# Timestep 7740: P min=247.3911, P max=252.6117, Z min=106.1573, Z max=108.2580
# Timestep 7760: P min=246.7015, P max=252.0153, Z min=104.5796, Z max=106.6352
# Timestep 7780: P min=246.1727, P max=251.5782, Z min=103.0200, Z max=105.0303
# Timestep 7800: P min=245.8020, P max=251.2976, Z min=101.4800, Z max=103.4448
# Timestep 7820: P min=245.5866, P max=251.1711, Z min=99.9609, Z max=101.8803
# Timestep 7840: P min=245.5240, P max=251.1961, Z min=98.4641, Z max=100.3380
# Timestep 7860: P min=245.6118, P max=251.3705, Z min=96.9905, Z max=98.8191
# Timestep 7880: P min=245.8478, P max=251.6922, Z min=95.5414, Z max=97.3248
# Timestep 7900: P min=246.2300, P max=252.1591, Z min=94.1176, Z max=95.8560
# Timestep 7920: P min=246.7565, P max=252.7696, Z min=92.7200, Z max=94.4137
# Timestep 7940: P min=247.4255, P max=253.5220, Z min=91.3493, Z max=92.9985
# Timestep 7960: P min=248.2355, P max=254.4146, Z min=90.0063, Z max=91.6114
# Timestep 7980: P min=249.1850, P max=255.4463, Z min=88.6915, Z max=90.2528
# Timestep 8000: P min=250.2727, P max=256.6155, Z min=87.4056, Z max=88.9234
# Timestep 8020: P min=251.4974, P max=257.9214, Z min=86.1489, Z max=87.6238
# Timestep 8040: P min=252.8581, P max=259.3627, Z min=84.9219, Z max=86.3542
# Timestep 8060: P min=254.3537, P max=260.9385, Z min=83.7250, Z max=85.1152
# Timestep 8080: P min=255.9835, P max=262.6481, Z min=82.5586, Z max=83.9071
# Timestep 8100: P min=257.7468, P max=264.4907, Z min=81.4228, Z max=82.7301
# Timestep 8120: P min=259.6427, P max=266.4657, Z min=80.3179, Z max=81.5846
# Timestep 8140: P min=261.6709, P max=268.5724, Z min=79.2442, Z max=80.4707
# Timestep 8160: P min=263.8308, P max=270.8104, Z min=78.2019, Z max=79.3886
# Timestep 8180: P min=266.1221, P max=273.1793, Z min=77.1910, Z max=78.3385
# Timestep 8200: P min=268.5443, P max=275.6786, Z min=76.2117, Z max=77.3204
# Timestep 8220: P min=271.0973, P max=278.3081, Z min=75.2641, Z max=76.3346
# Timestep 8240: P min=273.7807, P max=281.0674, Z min=74.3483, Z max=75.3811
# Timestep 8260: P min=276.5945, P max=283.9563, Z min=73.4644, Z max=74.4600
# Timestep 8280: P min=279.5383, P max=286.9745, Z min=72.6124, Z max=73.5713
# Timestep 8300: P min=282.6121, P max=290.1219, Z min=71.7925, Z max=72.7150
# Timestep 8320: P min=285.8158, P max=293.3981, Z min=71.0045, Z max=71.8913
# Timestep 8340: P min=289.1492, P max=296.8031, Z min=70.2487, Z max=71.1001
# Timestep 8360: P min=292.6122, P max=300.3364, Z min=69.5250, Z max=70.3415
# Timestep 8380: P min=296.2046, P max=303.9979, Z min=68.8336, Z max=69.6156
# Timestep 8400: P min=299.9264, P max=307.7872, Z min=68.1743, Z max=68.9224
# Timestep 8420: P min=303.7771, P max=311.7040, Z min=67.5475, Z max=68.2619
# Timestep 8440: P min=307.7566, P max=315.7477, Z min=66.9530, Z max=67.6342
# Timestep 8460: P min=311.8646, P max=319.9180, Z min=66.3910, Z max=67.0393
# Timestep 8480: P min=316.1005, P max=324.2142, Z min=65.8615, Z max=66.4775
# Timestep 8500: P min=320.4639, P max=328.6356, Z min=65.3648, Z max=65.9486
# Timestep 8520: P min=324.9542, P max=333.1814, Z min=64.9009, Z max=65.4530
# Timestep 8540: P min=329.5706, P max=337.8505, Z min=64.4700, Z max=64.9906
# Timestep 8560: P min=334.3123, P max=342.6420, Z min=64.0722, Z max=64.5618
# Timestep 8580: P min=339.1781, P max=347.5545, Z min=63.7078, Z max=64.1665
# Timestep 8600: P min=344.1669, P max=352.5865, Z min=63.3770, Z max=63.8051
# Timestep 8620: P min=349.2772, P max=357.7364, Z min=63.0799, Z max=63.4778
# Timestep 8640: P min=354.5075, P max=363.0023, Z min=62.8170, Z max=63.1848
# Timestep 8660: P min=359.8559, P max=368.3820, Z min=62.5884, Z max=62.9264
# Timestep 8680: P min=365.3202, P max=373.8731, Z min=62.3946, Z max=62.7030
# Timestep 8700: P min=370.8982, P max=379.4730, Z min=62.2358, Z max=62.5148
# Timestep 8720: P min=376.5871, P max=385.1786, Z min=62.1126, Z max=62.3624
# Timestep 8740: P min=382.3839, P max=390.9866, Z min=62.0252, Z max=62.2460
# Timestep 8760: P min=388.2853, P max=396.8932, Z min=61.9743, Z max=62.1662
# Timestep 8780: P min=394.2875, P max=402.8946, Z min=61.9603, Z max=62.1235
# Timestep 8800: P min=400.3866, P max=408.9860, Z min=61.9837, Z max=62.1183
# Timestep 8820: P min=406.5778, P max=415.1627, Z min=62.0452, Z max=62.1514
# Timestep 8840: P min=412.8563, P max=421.4192, Z min=62.1454, Z max=62.2232
# Timestep 8860: P min=419.2165, P max=427.7497, Z min=62.2741, Z max=62.3465
# Timestep 8880: P min=425.6525, P max=434.1478, Z min=62.4381, Z max=62.5139
# Timestep 8900: P min=432.1578, P max=440.6067, Z min=62.6429, Z max=62.7223
# Timestep 8920: P min=438.7253, P max=447.1187, Z min=62.8894, Z max=62.9723
# Timestep 8940: P min=445.3474, P max=453.6758, Z min=63.1783, Z max=63.2648
# Timestep 8960: P min=452.0157, P max=460.2694, Z min=63.5087, Z max=63.6007
# Timestep 8980: P min=458.7213, P max=466.8900, Z min=63.8730, Z max=63.9901
# Timestep 9000: P min=465.4546, P max=473.5277, Z min=64.2825, Z max=64.4270
# Timestep 9020: P min=472.2053, P max=480.1717, Z min=64.7382, Z max=64.9098
# Timestep 9040: P min=478.9623, P max=486.8106, Z min=65.2413, Z max=65.4398
# Timestep 9060: P min=485.7138, P max=493.4324, Z min=65.7926, Z max=66.0178
# Timestep 9080: P min=492.4474, P max=500.0240, Z min=66.3934, Z max=66.6449
# Timestep 9100: P min=499.1496, P max=506.5719, Z min=67.0447, Z max=67.3221
# Timestep 9120: P min=505.8063, P max=513.0616, Z min=67.7475, Z max=68.0506
# Timestep 9140: P min=512.4027, P max=519.4781, Z min=68.5032, Z max=68.8314
# Timestep 9160: P min=518.9230, P max=525.8053, Z min=69.3127, Z max=69.6655
# Timestep 9180: P min=525.3508, P max=532.0267, Z min=70.1772, Z max=70.5540
# Timestep 9200: P min=531.6687, P max=538.1250, Z min=71.0977, Z max=71.4979
# Timestep 9220: P min=537.8587, P max=544.0820, Z min=72.0754, Z max=72.4980
# Timestep 9240: P min=543.9022, P max=549.8791, Z min=73.1113, Z max=73.5554
# Timestep 9260: P min=549.7796, P max=555.4970, Z min=74.2063, Z max=74.6708
# Timestep 9280: P min=555.4710, P max=560.9159, Z min=75.3613, Z max=75.8450
# Timestep 9300: P min=560.9557, P max=566.1154, Z min=76.5770, Z max=77.0786
# Timestep 9320: P min=566.2126, P max=571.0750, Z min=77.8543, Z max=78.3721
# Timestep 9340: P min=571.2202, P max=575.7735, Z min=79.1934, Z max=79.7258
# Timestep 9360: P min=575.9568, P max=580.1900, Z min=80.5949, Z max=81.1399
# Timestep 9380: P min=580.4004, P max=584.3031, Z min=82.0589, Z max=82.6143
# Timestep 9400: P min=584.5290, P max=588.0919, Z min=83.5854, Z max=84.1489
# Timestep 9420: P min=588.3208, P max=591.5355, Z min=85.1740, Z max=85.7430
# Timestep 9440: P min=591.7541, P max=594.6134, Z min=86.8243, Z max=87.3958
# Timestep 9460: P min=594.8079, P max=597.3058, Z min=88.5353, Z max=89.1064
# Timestep 9480: P min=597.4616, P max=599.5937, Z min=90.3058, Z max=90.8731
# Timestep 9500: P min=599.6957, P max=601.4590, Z min=92.1344, Z max=92.6941
# Timestep 9520: P min=601.4916, P max=602.8849, Z min=94.0191, Z max=94.5673
# Timestep 9540: P min=602.8321, P max=603.8558, Z min=95.9574, Z max=96.4901
# Timestep 9560: P min=603.7014, P max=604.3579, Z min=97.9467, Z max=98.4593
# Timestep 9580: P min=604.0442, P max=604.4596, Z min=99.9835, Z max=100.4715
# Timestep 9600: P min=603.7255, P max=604.1871, Z min=102.0643, Z max=102.5226
# Timestep 9620: P min=602.9041, P max=603.4114, Z min=104.1846, Z max=104.6082
# Timestep 9640: P min=601.4696, P max=602.2176, Z min=106.3398, Z max=106.7234
# Timestep 9660: P min=599.4908, P max=600.5636, Z min=108.5247, Z max=108.8627
# Timestep 9680: P min=597.0051, P max=598.3879, Z min=110.7333, Z max=111.0203
# Timestep 9700: P min=594.0153, P max=595.6913, Z min=112.9596, Z max=113.1899
# Timestep 9720: P min=590.5269, P max=592.4775, Z min=115.1967, Z max=115.3894
# Timestep 9740: P min=586.5485, P max=588.7532, Z min=117.4229, Z max=117.5938
# Timestep 9760: P min=582.0914, P max=584.5282, Z min=119.6263, Z max=119.7911
# Timestep 9780: P min=577.1701, P max=579.8154, Z min=121.8155, Z max=121.9736
# Timestep 9800: P min=571.8017, P max=574.6306, Z min=123.9682, Z max=124.1331
# Timestep 9820: P min=566.0059, P max=568.9926, Z min=126.0560, Z max=126.2827
# Timestep 9840: P min=559.8053, P max=562.9230, Z min=128.1024, Z max=128.4231
# Timestep 9860: P min=553.2244, P max=556.4459, Z min=130.0989, Z max=130.5180
# Timestep 9880: P min=546.2900, P max=549.5878, Z min=132.0374, Z max=132.5588
# Timestep 9900: P min=539.0307, P max=542.3773, Z min=133.9099, Z max=134.5370
# Timestep 9920: P min=531.4768, P max=534.8448, Z min=135.7086, Z max=136.4442
# Timestep 9940: P min=523.6595, P max=527.0222, Z min=137.4259, Z max=138.2724
# Timestep 9960: P min=515.6112, P max=518.9426, Z min=139.0547, Z max=140.0138
# Timestep 9980: P min=507.3648, P max=510.6397, Z min=140.5882, Z max=141.6612

# %%
def generate_perturbed_initial_conditions(n_members, x_span, y_span, nx, nz):
    gen = lambda span: np.random.uniform(span[0], span[1], (nz, nx, n_members))
    P0_ensemble = gen(x_span)  # Prey initial conditions
    Z0_ensemble = gen(y_span)  # Predator initial conditions
    return P0_ensemble, Z0_ensemble

def run_ensemble_simulation(grid, params, timesteps, P0_ensemble, Z0_ensemble):
    n_members = P0_ensemble.shape[-1]
    P_history_ensemble = []
    Z_history_ensemble = []

    for i in range(n_members):
        P, Z = P0_ensemble[:, :, i], Z0_ensemble[:, :, i]
        P_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        Z_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        P_history[0, :, :] = P
        Z_history[0, :, :] = Z
        
        for t in range(1, timesteps):
            P, Z = predator_prey_advection_diffusion_step(
                P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
            )
            P_history[t, :, :] = P
            Z_history[t, :, :] = Z

        P_history_ensemble.append(P_history)
        Z_history_ensemble.append(Z_history)

    return np.array(P_history_ensemble), np.array(Z_history_ensemble)

def plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx, nz):
    n_members = P_history_ensemble.shape[0]  # Number of ensemble members
    cmap = plt.cm.RdYlBu(np.linspace(0, 1, n_members))  # Colour map for ensemble runs

    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    
    for i in range(nz):  # Rows
        for j in range(nx):  # Columns
            ax = axes[i, j]
            
            # Overlay trajectories for each ensemble member
            for k in range(n_members):
                P_traj = P_history_ensemble[k, :, i, j]  # Prey trajectory for cell (i, j)
                Z_traj = Z_history_ensemble[k, :, i, j]  # Predator trajectory for cell (i, j)
                ax.plot(P_traj, Z_traj, color=cmap[k], lw=0.5, label=f"Run {k+1}" if k == 0 else "")  # Label only once
            
            # Formatting
            ax.set_title(f"Cell ({i}, {j})")
            if i == nz - 1:
                ax.set_xlabel("Prey Density")
            if j == 0:
                ax.set_ylabel("Predator Density")
            ax.grid(True)

    plt.tight_layout()
    plt.show()

# Parameters
n_members = 2 # Number of graphs plotted in phase
x_span, y_span = (375, 425), (95, 105) # Starting conditions

# Generate perturbed initial conditions
P0_ensemble, Z0_ensemble = generate_perturbed_initial_conditions(n_members, x_span, y_span, nx=5, nz=5)

# Simulate for all ensemble members
P_history_ensemble, Z_history_ensemble = run_ensemble_simulation(grid, params, timesteps=4000, P0_ensemble=P0_ensemble, Z0_ensemble=Z0_ensemble)

# Plot the results
plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx=5, nz=5)
