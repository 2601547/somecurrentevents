# %%
import numpy as np
import matplotlib.pyplot as plt


def stable_time_step(vx, Dx, Dz, dx, dz):
    dx2, dz2 = dx * dx, dz * dz
    max_diffusion = max(np.max(Dx), np.max(Dz), 1.0e-10)
    max_velocity = max(np.max(vx), 1.0e-10)
    diffusive_dt = dx2 * dz2 / (2 * max_diffusion * (dx2 + dz2))
    cfl_dt = dx / max_velocity
    dt = min(cfl_dt, diffusive_dt) * 0.5
    return min(dt, 0.002)  # MAKING THIS SMALLER WORKED


def euler_advection_diffusion_timestep(c0, vx, Dx, Dz, src, dt, dx, dz, inversion=True, upwind=True):
    nz, nx = c0.shape
    c = c0.copy()

    # Compute stability limits
    dt_advection = min(dx, dz) / np.max(np.abs(vx))
    dt_diffusion = min(dx**2, dz**2) / (2 * np.max([Dx.max(), Dz.max()]))
    dt_stable = min(dt_advection, dt_diffusion)
    
    if dt > dt_stable:
        print(f"Warning: dt={dt} exceeds stable timestep={dt_stable:.5f}. Adjusting dt.")
        dt = dt_stable
    
    # Storage for face-centered fluxes
    Fx = np.zeros((nz, nx + 1))
    Fz = np.zeros((nz + 1, nx))

    # Diffusive fluxes (per unit volume)
    Fx[:, 1:nx] = -Dx[:, 1:nx] * (c[:, 1:nx] - c[:, 0:nx-1]) / (dx * dx)
    Fz[1:nz, :] = -Dz[1:nz, :] * (c[1:nz, :] - c[0:nz-1, :]) / (dz * dz)

    # Advective fluxes
    if upwind:
        Fx[:, 1:nx] += np.where(vx[:, 1:nx] > 0,
                                vx[:, 1:nx] * c[:, 0:nx-1],
                                vx[:, 1:nx] * c[:, 1:nx]) / dx
    else:
        Fx[:, 1:nx] += vx[:, 1:nx] * (c[:, 0:nx-1] + c[:, 1:nx]) * 0.5 / dx

    # Update concentrations in interior cells
    c[0:nz, 0:nx] += dt * (
        -(Fx[0:nz, 1:nx+1] - Fx[0:nz, 0:nx])
        -(Fz[1:nz+1, 0:nx] - Fz[0:nz, 0:nx])
        + src[0:nz, 0:nx]
    )

    # Enforce non-negativity
    c = np.maximum(c, 0)

    return c


def create_grid(P0, Z0, domain_size, params):
    if P0.shape != Z0.shape:
        raise ValueError(f"P0 and Z0 must have the same shape. Got P0.shape={P0.shape}, Z0.shape={Z0.shape}")

    nz, nx = P0.shape
    dx = domain_size[0] / nx
    dz = domain_size[1] / nz

    vx = np.full((nz, nx + 1), params['current_velocity'])
    Dx = np.full((nz, nx + 1), params['diffusion'])
    Dz = np.full((nz + 1, nx), params['diffusion'])

    dt = stable_time_step(vx, Dx, Dz, dx, dz)
    print(f"Stable timestep: {dt:.5f}s")

    return {'nz': nz, 'nx': nx, 'dx': dx, 'dz': dz, 'vx': vx, 'Dx': Dx, 'Dz': Dz, 'dt': dt, 'P': P0.copy(), 'Z': Z0.copy()}


def lotka_volterra_sources(P, Z, params):
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    K = max(K, 1.0e-6)
    P = np.maximum(P, 1e-6)
    Z = np.maximum(Z, 1e-6)

    prey_growth = alpha * P * (1.0 - P / K)
    prey_death = -beta * P * Z
    predator_gain = delta * beta * P * Z
    predator_death = -gamma * Z

    src_prey = prey_growth + prey_death
    src_pred = predator_gain + predator_death

    # Add optional noise for debugging symmetry
   # noise = np.random.normal(0, 0.01, size=src_prey.shape)
   # src_prey += noise
   # src_pred += noise

    return src_prey, src_pred


def predator_prey_advection_diffusion_step(P, Z, vx, Dx, Dz, params, dt, dx, dz):
    src_prey, src_pred = lotka_volterra_sources(P, Z, params)

    P_updated = euler_advection_diffusion_timestep(P, vx, Dx, Dz, src_prey, dt, dx, dz)
    Z_updated = euler_advection_diffusion_timestep(Z, vx, Dx, Dz, src_pred, dt, dx, dz)

    return P_updated, Z_updated

def run_simulation_and_visualise():
    global grid
    alpha, beta, delta, gamma, K = params['alpha'], params['beta'], params['delta'], params['gamma'], params['K']
    nx, nz = 5, 5  # Grid size
    P0 = np.full((nz, nx), gamma / (delta * beta) + 200) # + np.random.uniform(-20, 20, (nz, nx))
    Z0 = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )
    domain_size = (10, 10)
    grid = create_grid(P0, Z0, domain_size, params)

    eq_p = np.full((nz, nx), gamma / (delta * beta))
    eq_z = np.full((nz, nx), (alpha / beta) * (1 - (gamma / (delta * beta * K))) )

    print(eq_p) # I wanted to see the equilibria conidionts
    print(eq_z)
    
    P = grid['P'].astype(np.float64)
    Z = grid['Z'].astype(np.float64)

    timesteps = 10000  # Adjust to a reasonable number for visualisation
    P_history = np.zeros((timesteps, nz, nx))
    Z_history = np.zeros((timesteps, nz, nx))

    # Store initial conditions
    P_history[0, :, :] = P
    Z_history[0, :, :] = Z

    for t in range(1, timesteps):
        P, Z = predator_prey_advection_diffusion_step(
            P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
        )
        P_history[t, :, :] = P
        Z_history[t, :, :] = Z

        # Debugging information
        if t % 20 == 0:
            print(f"Timestep {t}: P min={np.min(P):.4f}, P max={np.max(P):.4f}, Z min={np.min(Z):.4f}, Z max={np.max(Z):.4f}")

    # Visualisation of phase plots
    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    for i in range(nz):
        for j in range(nx):
            ax = axes[i, j]
            ax.plot(P_history[:, i, j], Z_history[:, i, j], label=f"Cell ({i}, {j})")
            ax.set_title(f"Phase Plot: Cell ({i}, {j})")
            ax.set_xlabel("Prey Density")
            ax.set_ylabel("Predator Density")
            ax.legend()
    plt.tight_layout()
    plt.show()


params = {
    'alpha': 1.0,
    'beta': 0.01,
    'delta': 0.25,
    'gamma': 1.0,
    'K': 1000000000000000000000000000000000000000000000000000000.0, # its high as I just wanted to include the code at this point rather than just think about parameters
    'current_velocity': 1.1,
    'diffusion': 0.01
}

run_simulation_and_visualise()
# Out:
# Stable timestep: 0.00200s
# [[400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]
#  [400. 400. 400. 400. 400.]]
# [[100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]
#  [100. 100. 100. 100. 100.]]
# Timestep 20: P min=586.9643, P max=612.7033, Z min=99.7382, Z max=104.3245
# Timestep 40: P min=574.2873, P max=624.2848, Z min=99.3494, Z max=108.9149
# Timestep 60: P min=561.9857, P max=634.6279, Z min=98.8387, Z max=113.7760
# Timestep 80: P min=550.0735, P max=643.6191, Z min=98.2118, Z max=118.9102
# Timestep 100: P min=538.5613, P max=651.1499, Z min=97.4747, Z max=124.3174
# Timestep 120: P min=527.4571, P max=657.1194, Z min=96.6340, Z max=129.9946
# Timestep 140: P min=516.7662, P max=661.4373, Z min=95.6963, Z max=135.9351
# Timestep 160: P min=506.4917, P max=664.0262, Z min=94.6685, Z max=142.1284
# Timestep 180: P min=496.6344, P max=664.8249, Z min=93.5577, Z max=148.5596
# Timestep 200: P min=487.1932, P max=663.7908, Z min=92.3708, Z max=155.2094
# Timestep 220: P min=478.1656, P max=660.9024, Z min=91.1150, Z max=162.0533
# Timestep 240: P min=469.5473, P max=656.1611, Z min=89.7972, Z max=169.0624
# Timestep 260: P min=461.3330, P max=649.5930, Z min=88.4241, Z max=176.2025
# Timestep 280: P min=453.5162, P max=641.2494, Z min=87.0024, Z max=183.4352
# Timestep 300: P min=446.0895, P max=631.2067, Z min=85.5386, Z max=190.7178
# Timestep 320: P min=439.0450, P max=619.5658, Z min=84.0386, Z max=198.0043
# Timestep 340: P min=432.3739, P max=606.4500, Z min=82.5086, Z max=205.2460
# Timestep 360: P min=426.0672, P max=592.0027, Z min=80.9540, Z max=212.3923
# Timestep 380: P min=420.1154, P max=576.3837, Z min=79.3802, Z max=219.3924
# Timestep 400: P min=414.5090, P max=559.7655, Z min=77.7922, Z max=226.1958
# Timestep 420: P min=409.2382, P max=542.3290, Z min=76.1948, Z max=232.7537
# Timestep 440: P min=404.2932, P max=524.2587, Z min=74.5921, Z max=239.0203
# Timestep 460: P min=399.6643, P max=505.7386, Z min=72.9884, Z max=244.9536
# Timestep 480: P min=395.3417, P max=486.9476, Z min=71.3874, Z max=250.5163
# Timestep 500: P min=391.3160, P max=468.0560, Z min=69.7926, Z max=255.6764
# Timestep 520: P min=387.5777, P max=459.6983, Z min=68.2070, Z max=260.4079
# Timestep 540: P min=384.1177, P max=453.0231, Z min=66.6337, Z max=264.6910
# Timestep 560: P min=380.9272, P max=447.1746, Z min=65.0751, Z max=268.5120
# Timestep 580: P min=377.9974, P max=441.5661, Z min=63.5337, Z max=271.8632
# Timestep 600: P min=375.3200, P max=436.2081, Z min=62.0117, Z max=274.7428
# Timestep 620: P min=360.3785, P max=431.1094, Z min=60.5107, Z max=277.1542
# Timestep 640: P min=344.3281, P max=426.2770, Z min=59.0326, Z max=279.1056
# Timestep 660: P min=328.9900, P max=421.7163, Z min=57.5787, Z max=280.6092
# Timestep 680: P min=314.3939, P max=417.4315, Z min=56.1504, Z max=281.6809
# Timestep 700: P min=300.5570, P max=413.4254, Z min=54.7486, Z max=282.3392
# Timestep 720: P min=287.4854, P max=409.6996, Z min=53.3744, Z max=282.6050
# Timestep 740: P min=275.1763, P max=406.2549, Z min=52.0285, Z max=282.5007
# Timestep 760: P min=263.6190, P max=403.0912, Z min=50.7114, Z max=282.0499
# Timestep 780: P min=252.7966, P max=400.2075, Z min=49.4237, Z max=281.2766
# Timestep 800: P min=242.6875, P max=397.6024, Z min=48.1658, Z max=280.2053
# Timestep 820: P min=233.2664, P max=395.2738, Z min=46.9378, Z max=278.8601
# Timestep 840: P min=224.5054, P max=393.2193, Z min=45.7399, Z max=277.2648
# Timestep 860: P min=216.3752, P max=391.4360, Z min=44.5723, Z max=275.4423
# Timestep 880: P min=208.8453, P max=389.9208, Z min=43.4348, Z max=273.4150
# Timestep 900: P min=201.8850, P max=388.6703, Z min=42.3275, Z max=271.2042
# Timestep 920: P min=195.4639, P max=387.6810, Z min=41.2500, Z max=268.8299
# Timestep 940: P min=189.5522, P max=386.9492, Z min=40.2023, Z max=266.3113
# Timestep 960: P min=184.1210, P max=386.4712, Z min=39.1839, Z max=263.6662
# Timestep 980: P min=179.1426, P max=386.2431, Z min=38.1947, Z max=260.9115
# Timestep 1000: P min=174.5904, P max=386.2611, Z min=37.2342, Z max=258.0628
# Timestep 1020: P min=170.4396, P max=386.5214, Z min=36.3021, Z max=255.1345
# Timestep 1040: P min=166.6664, P max=387.0203, Z min=35.3979, Z max=252.1402
# Timestep 1060: P min=163.2489, P max=387.7539, Z min=34.5211, Z max=249.0922
# Timestep 1080: P min=160.1664, P max=388.7186, Z min=33.6714, Z max=246.0019
# Timestep 1100: P min=157.3997, P max=389.9108, Z min=32.8481, Z max=242.8799
# Timestep 1120: P min=154.9312, P max=391.3269, Z min=32.0509, Z max=239.7359
# Timestep 1140: P min=152.7444, P max=392.9634, Z min=31.2791, Z max=236.5785
# Timestep 1160: P min=150.8244, P max=394.8169, Z min=30.5323, Z max=233.4160
# Timestep 1180: P min=149.1571, P max=396.8841, Z min=29.8099, Z max=230.2557
# Timestep 1200: P min=147.7300, P max=399.1618, Z min=29.1114, Z max=227.1042
# Timestep 1220: P min=146.5316, P max=401.6467, Z min=28.4362, Z max=223.9678
# Timestep 1240: P min=145.5511, P max=404.3359, Z min=27.7839, Z max=220.8520
# Timestep 1260: P min=144.7792, P max=407.2261, Z min=27.1538, Z max=217.7618
# Timestep 1280: P min=144.2069, P max=410.3145, Z min=26.5455, Z max=214.7018
# Timestep 1300: P min=143.8265, P max=413.5981, Z min=25.9584, Z max=211.6763
# Timestep 1320: P min=143.6309, P max=417.0739, Z min=25.3920, Z max=208.6888
# Timestep 1340: P min=143.6137, P max=420.7390, Z min=24.8458, Z max=205.7430
# Timestep 1360: P min=143.7690, P max=424.5906, Z min=24.3193, Z max=202.8418
# Timestep 1380: P min=144.0919, P max=428.6258, Z min=23.8121, Z max=199.9881
# Timestep 1400: P min=144.5776, P max=432.8417, Z min=23.3235, Z max=197.1843
# Timestep 1420: P min=145.2221, P max=437.2354, Z min=22.8532, Z max=194.4328
# Timestep 1440: P min=146.0219, P max=441.8038, Z min=22.4008, Z max=191.7355
# Timestep 1460: P min=146.9736, P max=446.5441, Z min=21.9656, Z max=189.0944
# Timestep 1480: P min=148.0746, P max=451.4531, Z min=21.5474, Z max=186.5111
# Timestep 1500: P min=149.3223, P max=456.5276, Z min=21.1457, Z max=183.9871
# Timestep 1520: P min=150.7147, P max=461.7645, Z min=20.7602, Z max=181.5237
# Timestep 1540: P min=152.2499, P max=467.1603, Z min=20.3903, Z max=179.1223
# Timestep 1560: P min=153.9262, P max=472.7115, Z min=20.0357, Z max=176.7838
# Timestep 1580: P min=155.7423, P max=478.4145, Z min=19.6962, Z max=174.5093
# Timestep 1600: P min=157.6970, P max=484.2655, Z min=19.3712, Z max=172.2997
# Timestep 1620: P min=159.7892, P max=490.2605, Z min=19.0606, Z max=170.1558
# Timestep 1640: P min=162.0180, P max=496.3953, Z min=18.7639, Z max=168.0784
# Timestep 1660: P min=164.3827, P max=502.6655, Z min=18.4809, Z max=166.0682
# Timestep 1680: P min=166.8825, P max=509.0665, Z min=18.2112, Z max=164.1258
# Timestep 1700: P min=169.5166, P max=515.5933, Z min=17.9546, Z max=162.2517
# Timestep 1720: P min=172.2845, P max=522.2408, Z min=17.7109, Z max=160.4467
# Timestep 1740: P min=175.1855, P max=529.0036, Z min=17.4798, Z max=158.7111
# Timestep 1760: P min=178.2189, P max=535.8757, Z min=17.2611, Z max=157.0455
# Timestep 1780: P min=181.3838, P max=542.8513, Z min=17.0545, Z max=155.4504
# Timestep 1800: P min=184.6794, P max=549.9237, Z min=16.8599, Z max=153.9263
# Timestep 1820: P min=188.1048, P max=557.0861, Z min=16.6770, Z max=152.4736
# Timestep 1840: P min=191.6588, P max=564.3312, Z min=16.5057, Z max=151.0927
# Timestep 1860: P min=195.3401, P max=571.6516, Z min=16.3459, Z max=149.7842
# Timestep 1880: P min=199.1471, P max=579.0389, Z min=16.1975, Z max=148.5485
# Timestep 1900: P min=203.0780, P max=586.4848, Z min=16.0602, Z max=147.3862
# Timestep 1920: P min=207.1309, P max=593.9802, Z min=15.9340, Z max=146.2976
# Timestep 1940: P min=211.3032, P max=601.5156, Z min=15.8189, Z max=145.2833
# Timestep 1960: P min=215.5924, P max=609.0809, Z min=15.7147, Z max=144.3439
# Timestep 1980: P min=219.9952, P max=616.6658, Z min=15.6214, Z max=143.4798
# Timestep 2000: P min=224.5082, P max=624.2590, Z min=15.5389, Z max=142.6917
# Timestep 2020: P min=229.1274, P max=631.8491, Z min=15.4673, Z max=141.9802
# Timestep 2040: P min=233.8484, P max=639.4238, Z min=15.4066, Z max=141.3458
# Timestep 2060: P min=238.6661, P max=646.9705, Z min=15.3567, Z max=140.7893
# Timestep 2080: P min=243.5750, P max=654.4758, Z min=15.3177, Z max=140.3112
# Timestep 2100: P min=248.5691, P max=661.9260, Z min=15.2897, Z max=139.9123
# Timestep 2120: P min=253.6415, P max=669.3066, Z min=15.2728, Z max=139.5932
# Timestep 2140: P min=258.7848, P max=676.6027, Z min=15.2670, Z max=139.3547
# Timestep 2160: P min=263.9911, P max=683.7988, Z min=15.2725, Z max=139.1975
# Timestep 2180: P min=269.2513, P max=690.8789, Z min=15.2893, Z max=139.1223
# Timestep 2200: P min=274.5561, P max=697.8266, Z min=15.3178, Z max=139.1299
# Timestep 2220: P min=279.8951, P max=704.6248, Z min=15.3581, Z max=139.2211
# Timestep 2240: P min=285.2573, P max=711.2563, Z min=15.4103, Z max=139.3965
# Timestep 2260: P min=290.6308, P max=717.7033, Z min=15.4748, Z max=139.6569
# Timestep 2280: P min=296.0029, P max=723.9479, Z min=15.5517, Z max=140.0029
# Timestep 2300: P min=301.3603, P max=729.9716, Z min=15.6415, Z max=140.4352
# Timestep 2320: P min=306.6888, P max=735.7562, Z min=15.7443, Z max=140.9544
# Timestep 2340: P min=311.9733, P max=741.2831, Z min=15.8607, Z max=141.5610
# Timestep 2360: P min=317.1982, P max=746.5337, Z min=15.9909, Z max=142.2553
# Timestep 2380: P min=322.3472, P max=751.4897, Z min=16.1353, Z max=143.0379
# Timestep 2400: P min=327.4031, P max=756.1329, Z min=16.2945, Z max=143.9087
# Timestep 2420: P min=332.3483, P max=760.4455, Z min=16.4689, Z max=144.8680
# Timestep 2440: P min=337.1647, P max=764.4103, Z min=16.6591, Z max=145.9157
# Timestep 2460: P min=341.8338, P max=768.0104, Z min=16.8655, Z max=147.0513
# Timestep 2480: P min=346.3366, P max=771.2300, Z min=17.0888, Z max=148.2746
# Timestep 2500: P min=350.6540, P max=774.0540, Z min=17.3297, Z max=149.5846
# Timestep 2520: P min=354.7668, P max=776.4687, Z min=17.5888, Z max=150.9805
# Timestep 2540: P min=358.6558, P max=778.4612, Z min=17.8668, Z max=152.4610
# Timestep 2560: P min=362.3022, P max=785.5064, Z min=18.1646, Z max=154.0244
# Timestep 2580: P min=365.6871, P max=793.9329, Z min=18.4829, Z max=155.6689
# Timestep 2600: P min=368.7927, P max=802.3438, Z min=18.8227, Z max=157.3920
# Timestep 2620: P min=371.6016, P max=810.7294, Z min=19.1848, Z max=159.1912
# Timestep 2640: P min=374.0972, P max=819.0796, Z min=19.5703, Z max=161.0633
# Timestep 2660: P min=376.2643, P max=827.3837, Z min=19.9801, Z max=163.0047
# Timestep 2680: P min=378.0887, P max=835.6302, Z min=20.4153, Z max=165.0114
# Timestep 2700: P min=379.5579, P max=843.8068, Z min=20.8772, Z max=167.0790
# Timestep 2720: P min=380.6608, P max=851.9008, Z min=21.3668, Z max=169.2026
# Timestep 2740: P min=381.3885, P max=859.8983, Z min=21.8854, Z max=171.3766
# Timestep 2760: P min=381.7337, P max=867.7850, Z min=22.4344, Z max=173.5952
# Timestep 2780: P min=381.6914, P max=875.5456, Z min=23.0151, Z max=175.8521
# Timestep 2800: P min=381.2589, P max=883.1640, Z min=23.6288, Z max=178.1405
# Timestep 2820: P min=380.4358, P max=890.6232, Z min=24.2771, Z max=180.4530
# Timestep 2840: P min=379.2239, P max=897.9055, Z min=24.9615, Z max=182.7822
# Timestep 2860: P min=377.6278, P max=904.9921, Z min=25.6835, Z max=185.1201
# Timestep 2880: P min=375.6542, P max=911.8635, Z min=26.4446, Z max=187.4583
# Timestep 2900: P min=373.3124, P max=918.4994, Z min=27.2465, Z max=189.7885
# Timestep 2920: P min=370.6139, P max=924.8785, Z min=28.0908, Z max=192.1019
# Timestep 2940: P min=367.5726, P max=930.9786, Z min=28.9791, Z max=194.3896
# Timestep 2960: P min=364.2043, P max=936.7771, Z min=29.9130, Z max=196.6429
# Timestep 2980: P min=360.5268, P max=942.2501, Z min=30.8943, Z max=198.8529
# Timestep 3000: P min=356.5598, P max=947.3735, Z min=31.9243, Z max=201.0108
# Timestep 3020: P min=352.3241, P max=952.1223, Z min=33.0048, Z max=203.1081
# Timestep 3040: P min=347.8422, P max=956.4712, Z min=34.1370, Z max=205.1365
# Timestep 3060: P min=343.1376, P max=960.3943, Z min=35.3223, Z max=207.0880
# Timestep 3080: P min=338.2342, P max=963.8655, Z min=36.5620, Z max=208.9551
# Timestep 3100: P min=333.1568, P max=966.8587, Z min=37.8572, Z max=210.7305
# Timestep 3120: P min=327.9303, P max=969.3477, Z min=39.2085, Z max=212.4077
# Timestep 3140: P min=322.5796, P max=971.3065, Z min=40.6169, Z max=213.9806
# Timestep 3160: P min=317.1295, P max=972.7098, Z min=42.0825, Z max=215.4439
# Timestep 3180: P min=311.6042, P max=973.5328, Z min=43.6054, Z max=216.7928
# Timestep 3200: P min=306.0272, P max=973.7518, Z min=45.1855, Z max=218.0232
# Timestep 3220: P min=300.4214, P max=973.3442, Z min=46.8220, Z max=219.1316
# Timestep 3240: P min=294.8084, P max=972.2892, Z min=48.5138, Z max=220.1155
# Timestep 3260: P min=289.2090, P max=970.5676, Z min=50.2594, Z max=220.9728
# Timestep 3280: P min=283.6424, P max=968.1625, Z min=52.0567, Z max=221.7022
# Timestep 3300: P min=278.1267, P max=965.0595, Z min=53.9031, Z max=222.3032
# Timestep 3320: P min=272.6786, P max=961.2473, Z min=55.7953, Z max=222.7756
# Timestep 3340: P min=267.3134, P max=956.7173, Z min=57.7294, Z max=223.1203
# Timestep 3360: P min=262.0449, P max=951.4647, Z min=59.7010, Z max=223.3383
# Timestep 3380: P min=256.8856, P max=945.4885, Z min=61.7050, Z max=223.4316
# Timestep 3400: P min=251.8464, P max=938.7915, Z min=63.7355, Z max=223.4023
# Timestep 3420: P min=246.9371, P max=931.3809, Z min=65.7861, Z max=223.2533
# Timestep 3440: P min=242.1661, P max=923.2681, Z min=67.8496, Z max=222.9877
# Timestep 3460: P min=237.5405, P max=914.4692, Z min=69.9184, Z max=222.6090
# Timestep 3480: P min=233.0663, P max=905.0047, Z min=71.9843, Z max=222.1211
# Timestep 3500: P min=228.7483, P max=894.8996, Z min=74.0385, Z max=221.5281
# Timestep 3520: P min=224.5904, P max=884.1834, Z min=76.0717, Z max=220.8345
# Timestep 3540: P min=220.5956, P max=872.8896, Z min=78.0746, Z max=220.0446
# Timestep 3560: P min=216.7659, P max=861.0558, Z min=80.0374, Z max=219.1633
# Timestep 3580: P min=213.1027, P max=848.7233, Z min=81.9502, Z max=218.1954
# Timestep 3600: P min=209.6065, P max=835.9364, Z min=83.8031, Z max=217.1457
# Timestep 3620: P min=206.2775, P max=822.7426, Z min=85.5865, Z max=216.0192
# Timestep 3640: P min=203.1150, P max=809.1911, Z min=87.2908, Z max=214.8208
# Timestep 3660: P min=200.1180, P max=795.3334, Z min=88.9069, Z max=213.5555
# Timestep 3680: P min=197.2853, P max=781.2218, Z min=90.4262, Z max=212.2281
# Timestep 3700: P min=194.6149, P max=766.9093, Z min=91.8405, Z max=210.8435
# Timestep 3720: P min=192.1050, P max=752.4490, Z min=93.1428, Z max=209.4064
# Timestep 3740: P min=189.7531, P max=737.8933, Z min=94.3263, Z max=207.9215
# Timestep 3760: P min=187.5569, P max=723.2938, Z min=95.3855, Z max=206.3933
# Timestep 3780: P min=185.5137, P max=708.7000, Z min=96.3157, Z max=204.8263
# Timestep 3800: P min=183.6208, P max=694.1600, Z min=97.1132, Z max=203.2247
# Timestep 3820: P min=181.8754, P max=679.7190, Z min=97.7753, Z max=201.5926
# Timestep 3840: P min=180.2747, P max=665.4196, Z min=98.3003, Z max=199.9342
# Timestep 3860: P min=178.8157, P max=651.3016, Z min=98.6876, Z max=198.2532
# Timestep 3880: P min=177.4957, P max=637.4013, Z min=98.9375, Z max=196.5534
# Timestep 3900: P min=176.3117, P max=623.7519, Z min=99.0514, Z max=194.8383
# Timestep 3920: P min=175.2610, P max=610.3829, Z min=99.0312, Z max=193.1113
# Timestep 3940: P min=174.3408, P max=597.3206, Z min=98.8802, Z max=191.3757
# Timestep 3960: P min=173.5484, P max=584.5878, Z min=98.6019, Z max=189.6344
# Timestep 3980: P min=172.8811, P max=572.2040, Z min=98.2007, Z max=187.8906
# Timestep 4000: P min=172.3365, P max=560.1855, Z min=97.6818, Z max=186.1469
# Timestep 4020: P min=171.9120, P max=548.5457, Z min=97.0506, Z max=184.4059
# Timestep 4040: P min=171.6054, P max=537.2949, Z min=96.3129, Z max=182.6703
# Timestep 4060: P min=171.4143, P max=526.4408, Z min=95.4752, Z max=180.9423
# Timestep 4080: P min=171.3366, P max=515.9886, Z min=94.5437, Z max=179.2241
# Timestep 4100: P min=171.3702, P max=505.9415, Z min=93.5254, Z max=177.5179
# Timestep 4120: P min=171.5131, P max=496.3004, Z min=92.4268, Z max=175.8257
# Timestep 4140: P min=171.7635, P max=487.0644, Z min=91.2548, Z max=174.1492
# Timestep 4160: P min=172.1196, P max=478.2312, Z min=90.0162, Z max=172.4903
# Timestep 4180: P min=172.5798, P max=469.7968, Z min=88.7177, Z max=170.8505
# Timestep 4200: P min=173.1424, P max=461.7563, Z min=87.3658, Z max=169.2314
# Timestep 4220: P min=173.8059, P max=454.1036, Z min=85.9669, Z max=167.6344
# Timestep 4240: P min=174.5690, P max=446.8317, Z min=84.5273, Z max=166.0609
# Timestep 4260: P min=175.4303, P max=439.9331, Z min=83.0528, Z max=164.5120
# Timestep 4280: P min=176.3886, P max=433.3994, Z min=81.5492, Z max=162.9890
# Timestep 4300: P min=177.4427, P max=427.2222, Z min=80.0219, Z max=161.4929
# Timestep 4320: P min=178.5916, P max=421.3923, Z min=78.4760, Z max=160.0248
# Timestep 4340: P min=179.8342, P max=415.9007, Z min=76.9164, Z max=158.5856
# Timestep 4360: P min=181.1695, P max=410.7381, Z min=75.3477, Z max=157.1761
# Timestep 4380: P min=182.5967, P max=405.8950, Z min=73.7739, Z max=155.7973
# Timestep 4400: P min=184.1148, P max=401.3621, Z min=72.1992, Z max=154.4498
# Timestep 4420: P min=185.7231, P max=397.1302, Z min=70.6272, Z max=153.1344
# Timestep 4440: P min=187.4208, P max=393.1900, Z min=69.0611, Z max=151.8517
# Timestep 4460: P min=189.2072, P max=389.5326, Z min=67.5042, Z max=150.6024
# Timestep 4480: P min=191.0816, P max=386.1491, Z min=65.9591, Z max=149.3870
# Timestep 4500: P min=193.0432, P max=383.0310, Z min=64.4284, Z max=148.2062
# Timestep 4520: P min=195.0915, P max=380.1700, Z min=62.9145, Z max=147.0604
# Timestep 4540: P min=197.2257, P max=377.5578, Z min=61.4194, Z max=145.9501
# Timestep 4560: P min=199.4452, P max=375.1868, Z min=59.9449, Z max=144.8758
# Timestep 4580: P min=201.7493, P max=373.0493, Z min=58.4927, Z max=143.8380
# Timestep 4600: P min=204.1374, P max=371.1382, Z min=57.0641, Z max=142.8370
# Timestep 4620: P min=206.6088, P max=369.4465, Z min=55.6604, Z max=141.8733
# Timestep 4640: P min=209.1627, P max=367.9676, Z min=54.2827, Z max=140.9472
# Timestep 4660: P min=211.7984, P max=366.6949, Z min=52.9319, Z max=140.0592
# Timestep 4680: P min=214.5151, P max=365.6225, Z min=51.6087, Z max=139.2096
# Timestep 4700: P min=217.3120, P max=364.7446, Z min=50.3137, Z max=138.3989
# Timestep 4720: P min=220.1881, P max=364.0555, Z min=49.0474, Z max=137.6272
# Timestep 4740: P min=223.1425, P max=363.5501, Z min=47.8102, Z max=136.8951
# Timestep 4760: P min=226.1741, P max=363.2233, Z min=46.6023, Z max=136.2029
# Timestep 4780: P min=229.2819, P max=363.0703, Z min=45.4239, Z max=135.5509
# Timestep 4800: P min=232.4645, P max=363.0867, Z min=44.2751, Z max=134.9396
# Timestep 4820: P min=235.7207, P max=363.2682, Z min=43.1558, Z max=134.3692
# Timestep 4840: P min=239.0490, P max=363.6107, Z min=42.0660, Z max=133.8401
# Timestep 4860: P min=242.4478, P max=364.1104, Z min=41.0055, Z max=133.3528
# Timestep 4880: P min=245.9155, P max=364.7637, Z min=39.9741, Z max=132.9075
# Timestep 4900: P min=249.4502, P max=365.5671, Z min=38.9715, Z max=132.5048
# Timestep 4920: P min=253.0499, P max=366.5174, Z min=37.9975, Z max=132.1450
# Timestep 4940: P min=256.7125, P max=367.6117, Z min=37.0517, Z max=131.8286
# Timestep 4960: P min=260.4356, P max=370.9264, Z min=36.1338, Z max=131.5558
# Timestep 4980: P min=264.2166, P max=374.4915, Z min=35.2432, Z max=131.3273
# Timestep 5000: P min=268.0530, P max=378.2049, Z min=34.3796, Z max=131.1434
# Timestep 5020: P min=271.9417, P max=382.0656, Z min=33.5426, Z max=131.0045
# Timestep 5040: P min=275.8797, P max=386.0729, Z min=32.7315, Z max=130.9113
# Timestep 5060: P min=279.8635, P max=390.2258, Z min=31.9461, Z max=130.8640
# Timestep 5080: P min=283.8897, P max=394.5234, Z min=31.1857, Z max=130.8633
# Timestep 5100: P min=287.9543, P max=398.9648, Z min=30.4498, Z max=130.9096
# Timestep 5120: P min=292.0533, P max=403.5490, Z min=29.7380, Z max=131.0034
# Timestep 5140: P min=296.1823, P max=408.2748, Z min=29.0497, Z max=131.1452
# Timestep 5160: P min=300.3367, P max=413.1411, Z min=28.3843, Z max=131.3356
# Timestep 5180: P min=304.5117, P max=418.1467, Z min=27.7415, Z max=131.5750
# Timestep 5200: P min=308.7020, P max=423.2902, Z min=27.1206, Z max=131.8640
# Timestep 5220: P min=312.9022, P max=428.5703, Z min=26.5211, Z max=132.2031
# Timestep 5240: P min=317.1066, P max=433.9854, Z min=25.9426, Z max=132.5928
# Timestep 5260: P min=321.3092, P max=439.5339, Z min=25.3845, Z max=133.0336
# Timestep 5280: P min=325.5036, P max=445.2141, Z min=24.8464, Z max=133.5260
# Timestep 5300: P min=329.6832, P max=451.0239, Z min=24.3277, Z max=134.0706
# Timestep 5320: P min=333.8412, P max=456.9613, Z min=23.8280, Z max=134.6676
# Timestep 5340: P min=337.9704, P max=463.0241, Z min=23.3467, Z max=135.3177
# Timestep 5360: P min=342.0633, P max=469.2099, Z min=22.8836, Z max=136.0212
# Timestep 5380: P min=346.1122, P max=475.5160, Z min=22.4380, Z max=136.7785
# Timestep 5400: P min=350.1093, P max=481.9397, Z min=22.0096, Z max=137.5899
# Timestep 5420: P min=354.0462, P max=488.4778, Z min=21.5980, Z max=138.4558
# Timestep 5440: P min=357.9147, P max=495.1271, Z min=21.2028, Z max=139.3763
# Timestep 5460: P min=361.7060, P max=501.8841, Z min=20.8234, Z max=140.3517
# Timestep 5480: P min=365.4115, P max=508.7449, Z min=20.4597, Z max=141.3822
# Timestep 5500: P min=369.0222, P max=515.7055, Z min=20.1112, Z max=142.4677
# Timestep 5520: P min=372.5291, P max=522.7615, Z min=19.7775, Z max=143.6082
# Timestep 5540: P min=375.9230, P max=529.9082, Z min=19.4584, Z max=144.8036
# Timestep 5560: P min=379.1948, P max=537.1405, Z min=19.1534, Z max=146.0538
# Timestep 5580: P min=382.3354, P max=544.4531, Z min=18.8624, Z max=147.3584
# Timestep 5600: P min=385.3355, P max=551.8401, Z min=18.5849, Z max=148.7169
# Timestep 5620: P min=388.1861, P max=559.2954, Z min=18.3208, Z max=150.1289
# Timestep 5640: P min=390.8782, P max=566.8126, Z min=18.0697, Z max=151.5936
# Timestep 5660: P min=393.4032, P max=574.3845, Z min=17.8315, Z max=153.1103
# Timestep 5680: P min=395.7524, P max=582.0038, Z min=17.6058, Z max=154.6779
# Timestep 5700: P min=397.9176, P max=589.6626, Z min=17.3924, Z max=156.2955
# Timestep 5720: P min=399.8908, P max=597.3526, Z min=17.1912, Z max=157.9616
# Timestep 5740: P min=401.6646, P max=605.0649, Z min=17.0020, Z max=159.6748
# Timestep 5760: P min=403.2318, P max=612.7903, Z min=16.8245, Z max=161.4336
# Timestep 5780: P min=404.5858, P max=620.5189, Z min=16.6587, Z max=163.2361
# Timestep 5800: P min=405.7206, P max=628.2403, Z min=16.5044, Z max=165.0804
# Timestep 5820: P min=406.6307, P max=635.9436, Z min=16.3615, Z max=166.9642
# Timestep 5840: P min=407.3112, P max=643.6175, Z min=16.2298, Z max=168.8853
# Timestep 5860: P min=407.7581, P max=651.2499, Z min=16.1093, Z max=170.8411
# Timestep 5880: P min=407.9680, P max=658.8283, Z min=15.9999, Z max=172.8289
# Timestep 5900: P min=407.9381, P max=666.3396, Z min=15.9015, Z max=174.8457
# Timestep 5920: P min=407.6668, P max=673.7703, Z min=15.8142, Z max=176.8885
# Timestep 5940: P min=407.1530, P max=681.1062, Z min=15.7378, Z max=178.9539
# Timestep 5960: P min=406.3965, P max=688.3327, Z min=15.6723, Z max=181.0387
# Timestep 5980: P min=405.3980, P max=695.4346, Z min=15.6179, Z max=183.1391
# Timestep 6000: P min=404.1590, P max=702.3963, Z min=15.5745, Z max=185.2514
# Timestep 6020: P min=402.6820, P max=709.2018, Z min=15.5421, Z max=187.3718
# Timestep 6040: P min=400.9702, P max=715.8347, Z min=15.5210, Z max=189.4962
# Timestep 6060: P min=399.0276, P max=722.2782, Z min=15.5110, Z max=191.6206
# Timestep 6080: P min=396.8592, P max=728.5152, Z min=15.5124, Z max=193.7406
# Timestep 6100: P min=394.4706, P max=734.5284, Z min=15.5253, Z max=195.8522
# Timestep 6120: P min=391.8682, P max=740.3005, Z min=15.5498, Z max=197.9508
# Timestep 6140: P min=389.0591, P max=745.8138, Z min=15.5862, Z max=200.0323
# Timestep 6160: P min=386.0511, P max=751.0508, Z min=15.6346, Z max=202.0920
# Timestep 6180: P min=382.8524, P max=755.9943, Z min=15.6952, Z max=204.1258
# Timestep 6200: P min=379.4721, P max=760.6270, Z min=15.7684, Z max=206.1291
# Timestep 6220: P min=375.9195, P max=764.9322, Z min=15.8544, Z max=208.0978
# Timestep 6240: P min=372.2043, P max=768.8935, Z min=15.9535, Z max=210.0274
# Timestep 6260: P min=368.3368, P max=772.4951, Z min=16.0661, Z max=211.9139
# Timestep 6280: P min=364.3275, P max=775.7222, Z min=16.1925, Z max=213.7531
# Timestep 6300: P min=360.1871, P max=778.5606, Z min=16.3331, Z max=215.5410
# Timestep 6320: P min=355.9264, P max=780.9973, Z min=16.4884, Z max=217.2739
# Timestep 6340: P min=351.5566, P max=783.0206, Z min=16.6588, Z max=218.9479
# Timestep 6360: P min=347.0887, P max=784.6198, Z min=16.8449, Z max=220.5596
# Timestep 6380: P min=342.5339, P max=785.7861, Z min=17.0472, Z max=222.1055
# Timestep 6400: P min=337.9033, P max=786.5122, Z min=17.2662, Z max=223.5826
# Timestep 6420: P min=333.2077, P max=786.7924, Z min=17.5026, Z max=224.9878
# Timestep 6440: P min=328.4582, P max=786.6232, Z min=17.7571, Z max=226.3183
# Timestep 6460: P min=323.6654, P max=786.0030, Z min=18.0304, Z max=227.5717
# Timestep 6480: P min=318.8398, P max=784.9322, Z min=18.3231, Z max=228.7454
# Timestep 6500: P min=313.9916, P max=789.1714, Z min=18.6361, Z max=229.8374
# Timestep 6520: P min=309.1308, P max=797.4843, Z min=18.9703, Z max=230.8459
# Timestep 6540: P min=304.2670, P max=805.7728, Z min=19.3266, Z max=231.7692
# Timestep 6560: P min=299.4097, P max=814.0269, Z min=19.7058, Z max=232.6058
# Timestep 6580: P min=294.5678, P max=822.2360, Z min=20.1089, Z max=233.3547
# Timestep 6600: P min=289.7499, P max=830.3891, Z min=20.5371, Z max=234.0148
# Timestep 6620: P min=284.9643, P max=838.4741, Z min=20.9914, Z max=234.5855
# Timestep 6640: P min=280.2187, P max=846.4786, Z min=21.4730, Z max=235.0663
# Timestep 6660: P min=275.5208, P max=854.3893, Z min=21.9830, Z max=235.4570
# Timestep 6680: P min=270.8774, P max=862.1920, Z min=22.5227, Z max=235.7576
# Timestep 6700: P min=266.2953, P max=869.8719, Z min=23.0934, Z max=235.9684
# Timestep 6720: P min=261.7806, P max=877.4135, Z min=23.6965, Z max=236.0898
# Timestep 6740: P min=257.3390, P max=884.8002, Z min=24.3334, Z max=236.1225
# Timestep 6760: P min=252.9760, P max=892.0148, Z min=25.0054, Z max=236.0673
# Timestep 6780: P min=248.6965, P max=899.0391, Z min=25.7141, Z max=235.9253
# Timestep 6800: P min=244.5050, P max=905.8543, Z min=26.4611, Z max=235.6979
# Timestep 6820: P min=240.4056, P max=912.4406, Z min=27.2477, Z max=235.3864
# Timestep 6840: P min=236.4021, P max=918.7774, Z min=28.0756, Z max=234.9925
# Timestep 6860: P min=232.4978, P max=924.8433, Z min=28.9464, Z max=234.5180
# Timestep 6880: P min=228.6956, P max=930.6163, Z min=29.8616, Z max=233.9648
# Timestep 6900: P min=224.9982, P max=936.0734, Z min=30.8227, Z max=233.3349
# Timestep 6920: P min=221.4078, P max=941.1911, Z min=31.8312, Z max=232.6307
# Timestep 6940: P min=217.9264, P max=945.9455, Z min=32.8887, Z max=231.8544
# Timestep 6960: P min=214.5555, P max=950.3118, Z min=33.9964, Z max=231.0085
# Timestep 6980: P min=211.2965, P max=954.2652, Z min=35.1557, Z max=230.0954
# Timestep 7000: P min=208.1503, P max=957.7803, Z min=36.3678, Z max=229.1179
# Timestep 7020: P min=205.1179, P max=960.8318, Z min=37.6336, Z max=228.0785
# Timestep 7040: P min=202.1996, P max=963.3943, Z min=38.9540, Z max=226.9800
# Timestep 7060: P min=199.3957, P max=965.4428, Z min=40.3296, Z max=225.8253
# Timestep 7080: P min=196.7064, P max=966.9524, Z min=41.7608, Z max=224.6171
# Timestep 7100: P min=194.1315, P max=967.8992, Z min=43.2477, Z max=223.3583
# Timestep 7120: P min=191.6708, P max=968.2600, Z min=44.7901, Z max=222.0518
# Timestep 7140: P min=189.3238, P max=968.0128, Z min=46.3873, Z max=220.7005
# Timestep 7160: P min=187.0898, P max=967.1369, Z min=48.0383, Z max=219.3072
# Timestep 7180: P min=184.9683, P max=965.6138, Z min=49.7418, Z max=217.8748
# Timestep 7200: P min=182.9583, P max=963.4264, Z min=51.4956, Z max=216.4063
# Timestep 7220: P min=181.0589, P max=960.5606, Z min=53.2975, Z max=214.9044
# Timestep 7240: P min=179.2692, P max=957.0044, Z min=55.1442, Z max=213.3719
# Timestep 7260: P min=177.5880, P max=952.7493, Z min=57.0323, Z max=211.8117
# Timestep 7280: P min=176.0142, P max=947.7898, Z min=58.9575, Z max=210.2264
# Timestep 7300: P min=174.5467, P max=942.1239, Z min=60.9150, Z max=208.6188
# Timestep 7320: P min=173.1843, P max=935.7535, Z min=62.8992, Z max=206.9914
# Timestep 7340: P min=171.9256, P max=928.6845, Z min=64.9041, Z max=205.3468
# Timestep 7360: P min=170.7694, P max=920.9271, Z min=66.9229, Z max=203.6876
# Timestep 7380: P min=169.7144, P max=912.4955, Z min=68.9484, Z max=202.0163
# Timestep 7400: P min=168.7594, P max=903.4085, Z min=70.9727, Z max=200.3351
# Timestep 7420: P min=167.9030, P max=893.6890, Z min=72.9875, Z max=198.6464
# Timestep 7440: P min=167.1441, P max=883.3644, Z min=74.9840, Z max=196.9525
# Timestep 7460: P min=166.4813, P max=872.4660, Z min=76.9532, Z max=195.2555
# Timestep 7480: P min=165.9133, P max=861.0290, Z min=78.8857, Z max=193.5576
# Timestep 7500: P min=165.4390, P max=849.0922, Z min=80.7721, Z max=191.8607
# Timestep 7520: P min=165.0570, P max=836.6977, Z min=82.6028, Z max=190.1669
# Timestep 7540: P min=164.7664, P max=823.8903, Z min=84.3684, Z max=188.4780
# Timestep 7560: P min=164.5657, P max=810.7173, Z min=86.0596, Z max=186.7958
# Timestep 7580: P min=164.4540, P max=797.2276, Z min=87.6676, Z max=185.1221
# Timestep 7600: P min=164.4300, P max=783.4716, Z min=89.1839, Z max=183.4585
# Timestep 7620: P min=164.4928, P max=769.5004, Z min=90.6005, Z max=181.8066
# Timestep 7640: P min=164.6412, P max=755.3653, Z min=91.9102, Z max=180.1679
# Timestep 7660: P min=164.8742, P max=741.1175, Z min=93.1064, Z max=178.5439
# Timestep 7680: P min=165.1907, P max=726.8069, Z min=94.1833, Z max=176.9359
# Timestep 7700: P min=165.5899, P max=712.4824, Z min=95.1362, Z max=175.3453
# Timestep 7720: P min=166.0707, P max=698.1912, Z min=95.9612, Z max=173.7732
# Timestep 7740: P min=166.6321, P max=683.9780, Z min=96.6553, Z max=172.2209
# Timestep 7760: P min=167.2733, P max=669.8853, Z min=97.2165, Z max=170.6895
# Timestep 7780: P min=167.9934, P max=655.9526, Z min=97.6438, Z max=169.1799
# Timestep 7800: P min=168.7914, P max=642.2166, Z min=97.9373, Z max=167.6933
# Timestep 7820: P min=169.6666, P max=628.7107, Z min=98.0977, Z max=166.2304
# Timestep 7840: P min=170.6181, P max=615.4651, Z min=98.1268, Z max=164.7923
# Timestep 7860: P min=171.6450, P max=602.5068, Z min=98.0273, Z max=163.3796
# Timestep 7880: P min=172.7465, P max=589.8593, Z min=97.8024, Z max=161.9931
# Timestep 7900: P min=173.9218, P max=577.5432, Z min=97.4561, Z max=160.6336
# Timestep 7920: P min=175.1701, P max=565.5757, Z min=96.9930, Z max=159.3017
# Timestep 7940: P min=176.4907, P max=553.9711, Z min=96.4183, Z max=157.9980
# Timestep 7960: P min=177.8827, P max=542.7410, Z min=95.7374, Z max=156.7231
# Timestep 7980: P min=179.3453, P max=531.8942, Z min=94.9563, Z max=155.4775
# Timestep 8000: P min=180.8778, P max=521.4370, Z min=94.0812, Z max=154.2617
# Timestep 8020: P min=182.4794, P max=511.3735, Z min=93.1184, Z max=153.0761
# Timestep 8040: P min=184.1493, P max=501.7059, Z min=92.0744, Z max=151.9211
# Timestep 8060: P min=185.8867, P max=492.4342, Z min=90.9559, Z max=150.7971
# Timestep 8080: P min=187.6909, P max=483.5571, Z min=89.7693, Z max=149.7045
# Timestep 8100: P min=189.5609, P max=475.0716, Z min=88.5213, Z max=148.6435
# Timestep 8120: P min=191.4960, P max=466.9736, Z min=87.2181, Z max=147.6145
# Timestep 8140: P min=193.4954, P max=459.2579, Z min=85.8661, Z max=146.6176
# Timestep 8160: P min=195.5582, P max=451.9182, Z min=84.4714, Z max=145.6531
# Timestep 8180: P min=197.6835, P max=444.9477, Z min=83.0399, Z max=144.7213
# Timestep 8200: P min=199.8704, P max=438.3389, Z min=81.5771, Z max=143.8223
# Timestep 8220: P min=202.1181, P max=432.0835, Z min=80.0886, Z max=142.9563
# Timestep 8240: P min=204.4256, P max=426.1734, Z min=78.5793, Z max=142.1234
# Timestep 8260: P min=206.7919, P max=420.5997, Z min=77.0542, Z max=141.3238
# Timestep 8280: P min=209.2160, P max=415.3536, Z min=75.5179, Z max=140.5576
# Timestep 8300: P min=211.6969, P max=410.4261, Z min=73.9745, Z max=139.8249
# Timestep 8320: P min=214.2335, P max=405.8082, Z min=72.4280, Z max=139.1258
# Timestep 8340: P min=216.8246, P max=401.4909, Z min=70.8822, Z max=138.4605
# Timestep 8360: P min=219.4692, P max=397.4653, Z min=69.3405, Z max=137.8290
# Timestep 8380: P min=222.1660, P max=393.7227, Z min=67.8060, Z max=137.2314
# Timestep 8400: P min=224.9137, P max=390.2544, Z min=66.2815, Z max=136.6678
# Timestep 8420: P min=227.7110, P max=387.0521, Z min=64.7698, Z max=136.1383
# Timestep 8440: P min=230.5565, P max=384.1075, Z min=63.2731, Z max=135.6429
# Timestep 8460: P min=233.4488, P max=381.4127, Z min=61.7935, Z max=135.1817
# Timestep 8480: P min=236.3864, P max=378.9600, Z min=60.3331, Z max=134.7549
# Timestep 8500: P min=239.3677, P max=376.7418, Z min=58.8935, Z max=134.3624
# Timestep 8520: P min=242.3911, P max=374.7511, Z min=57.4762, Z max=134.0044
# Timestep 8540: P min=245.4548, P max=372.9809, Z min=56.0825, Z max=133.6809
# Timestep 8560: P min=248.5571, P max=371.4246, Z min=54.7135, Z max=133.3920
# Timestep 8580: P min=251.6960, P max=370.0759, Z min=53.3703, Z max=133.1379
# Timestep 8600: P min=254.8696, P max=368.9286, Z min=52.0535, Z max=132.9186
# Timestep 8620: P min=258.0758, P max=367.9770, Z min=50.7640, Z max=132.7342
# Timestep 8640: P min=261.3125, P max=367.2155, Z min=49.5023, Z max=132.5849
# Timestep 8660: P min=264.5774, P max=366.6388, Z min=48.2687, Z max=132.4706
# Timestep 8680: P min=267.8682, P max=366.2420, Z min=47.0637, Z max=132.3916
# Timestep 8700: P min=271.1824, P max=366.0202, Z min=45.8874, Z max=132.3479
# Timestep 8720: P min=274.5174, P max=365.9689, Z min=44.7399, Z max=132.3398
# Timestep 8740: P min=277.8707, P max=366.0837, Z min=43.6214, Z max=132.3672
# Timestep 8760: P min=281.2394, P max=366.3607, Z min=42.5317, Z max=132.4303
# Timestep 8780: P min=284.6207, P max=366.7960, Z min=41.4707, Z max=132.5293
# Timestep 8800: P min=288.0115, P max=367.3858, Z min=40.4384, Z max=132.6642
# Timestep 8820: P min=291.4088, P max=368.1268, Z min=39.4345, Z max=132.8353
# Timestep 8840: P min=294.8094, P max=369.0156, Z min=38.4587, Z max=133.0426
# Timestep 8860: P min=298.2099, P max=370.1755, Z min=37.5107, Z max=133.2863
# Timestep 8880: P min=301.6069, P max=373.4340, Z min=36.5902, Z max=133.5665
# Timestep 8900: P min=304.9968, P max=376.8418, Z min=35.6968, Z max=133.8834
# Timestep 8920: P min=308.3760, P max=380.3979, Z min=34.8301, Z max=134.2370
# Timestep 8940: P min=311.7407, P max=384.1015, Z min=33.9897, Z max=134.6274
# Timestep 8960: P min=315.0871, P max=387.9518, Z min=33.1751, Z max=135.0549
# Timestep 8980: P min=318.4111, P max=391.9476, Z min=32.3859, Z max=135.5194
# Timestep 9000: P min=321.7087, P max=396.0881, Z min=31.6216, Z max=136.0210
# Timestep 9020: P min=324.9757, P max=400.3722, Z min=30.8817, Z max=136.5599
# Timestep 9040: P min=328.2078, P max=404.7988, Z min=30.1657, Z max=137.1360
# Timestep 9060: P min=331.4008, P max=409.3669, Z min=29.4731, Z max=137.7495
# Timestep 9080: P min=334.5502, P max=414.0752, Z min=28.8034, Z max=138.4003
# Timestep 9100: P min=337.6515, P max=418.9223, Z min=28.1561, Z max=139.0884
# Timestep 9120: P min=340.7003, P max=423.9071, Z min=27.5308, Z max=139.8138
# Timestep 9140: P min=343.6919, P max=429.0280, Z min=26.9268, Z max=140.5764
# Timestep 9160: P min=346.6217, P max=434.2834, Z min=26.3437, Z max=141.3761
# Timestep 9180: P min=349.4851, P max=439.6717, Z min=25.7811, Z max=142.2128
# Timestep 9200: P min=352.2775, P max=445.1910, Z min=25.2384, Z max=143.0864
# Timestep 9220: P min=354.9942, P max=450.8395, Z min=24.7152, Z max=143.9966
# Timestep 9240: P min=357.6306, P max=456.6151, Z min=24.2110, Z max=144.9432
# Timestep 9260: P min=360.1820, P max=462.5155, Z min=23.7253, Z max=145.9258
# Timestep 9280: P min=362.6440, P max=468.5382, Z min=23.2577, Z max=146.9443
# Timestep 9300: P min=365.0120, P max=474.6807, Z min=22.8078, Z max=147.9981
# Timestep 9320: P min=367.2816, P max=480.9402, Z min=22.3751, Z max=149.0868
# Timestep 9340: P min=369.4486, P max=487.3136, Z min=21.9592, Z max=150.2100
# Timestep 9360: P min=371.5087, P max=493.7977, Z min=21.5597, Z max=151.3671
# Timestep 9380: P min=373.4578, P max=500.3890, Z min=21.1763, Z max=152.5574
# Timestep 9400: P min=375.2920, P max=507.0838, Z min=20.8085, Z max=153.7803
# Timestep 9420: P min=377.0076, P max=513.8780, Z min=20.4560, Z max=155.0351
# Timestep 9440: P min=378.6008, P max=520.7672, Z min=20.1184, Z max=156.3209
# Timestep 9460: P min=380.0685, P max=527.7470, Z min=19.7954, Z max=157.6368
# Timestep 9480: P min=381.4072, P max=534.8124, Z min=19.4868, Z max=158.9820
# Timestep 9500: P min=382.6142, P max=541.9580, Z min=19.1921, Z max=160.3554
# Timestep 9520: P min=383.6866, P max=549.1782, Z min=18.9110, Z max=161.7560
# Timestep 9540: P min=384.6220, P max=556.4671, Z min=18.6434, Z max=163.1825
# Timestep 9560: P min=385.4182, P max=563.8183, Z min=18.3890, Z max=164.6337
# Timestep 9580: P min=386.0732, P max=571.2249, Z min=18.1474, Z max=166.1085
# Timestep 9600: P min=386.5854, P max=578.6797, Z min=17.9186, Z max=167.6053
# Timestep 9620: P min=386.9535, P max=586.1752, Z min=17.7021, Z max=169.1228
# Timestep 9640: P min=387.1762, P max=593.7031, Z min=17.4979, Z max=170.6594
# Timestep 9660: P min=387.2530, P max=601.2549, Z min=17.3058, Z max=172.2137
# Timestep 9680: P min=387.1833, P max=608.8216, Z min=17.1256, Z max=173.7840
# Timestep 9700: P min=386.9670, P max=616.3937, Z min=16.9570, Z max=175.3686
# Timestep 9720: P min=386.6041, P max=623.9610, Z min=16.8001, Z max=176.9658
# Timestep 9740: P min=386.0951, P max=631.5132, Z min=16.6547, Z max=178.5738
# Timestep 9760: P min=385.4407, P max=639.0390, Z min=16.5206, Z max=180.1907
# Timestep 9780: P min=384.6419, P max=646.5270, Z min=16.3977, Z max=181.8146
# Timestep 9800: P min=383.7001, P max=653.9650, Z min=16.2861, Z max=183.4437
# Timestep 9820: P min=382.6167, P max=661.3404, Z min=16.1855, Z max=185.0759
# Timestep 9840: P min=381.3935, P max=668.6400, Z min=16.0961, Z max=186.7092
# Timestep 9860: P min=380.0327, P max=675.8503, Z min=16.0178, Z max=188.3417
# Timestep 9880: P min=378.5364, P max=682.9571, Z min=15.9505, Z max=189.9712
# Timestep 9900: P min=376.9072, P max=689.9458, Z min=15.8942, Z max=191.5956
# Timestep 9920: P min=375.1479, P max=696.8013, Z min=15.8491, Z max=193.2128
# Timestep 9940: P min=373.2612, P max=703.5083, Z min=15.8151, Z max=194.8207
# Timestep 9960: P min=371.2502, P max=710.0508, Z min=15.7924, Z max=196.4172
# Timestep 9980: P min=369.1183, P max=716.4126, Z min=15.7810, Z max=198.0001

# %%
def generate_perturbed_initial_conditions(n_members, x_span, y_span, nx, nz):
    gen = lambda span: np.random.uniform(span[0], span[1], (nz, nx, n_members))
    P0_ensemble = gen(x_span)  # Prey initial conditions
    Z0_ensemble = gen(y_span)  # Predator initial conditions
    return P0_ensemble, Z0_ensemble

def run_ensemble_simulation(grid, params, timesteps, P0_ensemble, Z0_ensemble):
    n_members = P0_ensemble.shape[-1]
    P_history_ensemble = []
    Z_history_ensemble = []

    for i in range(n_members):
        P, Z = P0_ensemble[:, :, i], Z0_ensemble[:, :, i]
        P_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        Z_history = np.zeros((timesteps, grid['nz'], grid['nx']))
        P_history[0, :, :] = P
        Z_history[0, :, :] = Z
        
        for t in range(1, timesteps):
            P, Z = predator_prey_advection_diffusion_step(
                P, Z, grid['vx'], grid['Dx'], grid['Dz'], params, grid['dt'], grid['dx'], grid['dz']
            )
            P_history[t, :, :] = P
            Z_history[t, :, :] = Z

        P_history_ensemble.append(P_history)
        Z_history_ensemble.append(Z_history)

    return np.array(P_history_ensemble), np.array(Z_history_ensemble)

def plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx, nz):
    n_members = P_history_ensemble.shape[0]  # Number of ensemble members
    cmap = plt.cm.RdYlBu(np.linspace(0, 1, n_members))  # Colour map for ensemble runs

    fig, axes = plt.subplots(nz, nx, figsize=(12, 12), sharex=True, sharey=True)
    
    for i in range(nz):  # Rows
        for j in range(nx):  # Columns
            ax = axes[i, j]
            
            # Overlay trajectories for each ensemble member
            for k in range(n_members):
                P_traj = P_history_ensemble[k, :, i, j]  # Prey trajectory for cell (i, j)
                Z_traj = Z_history_ensemble[k, :, i, j]  # Predator trajectory for cell (i, j)
                ax.plot(P_traj, Z_traj, color=cmap[k], lw=0.5, label=f"Run {k+1}" if k == 0 else "")  # Label only once
            
            # Formatting
            ax.set_title(f"Cell ({i}, {j})")
            if i == nz - 1:
                ax.set_xlabel("Prey Density")
            if j == 0:
                ax.set_ylabel("Predator Density")
            ax.grid(True)

    plt.tight_layout()
    plt.show()

# Parameters
n_members = 20 # Number of graphs plotted in phase
x_span, y_span = (375, 425), (95, 105) # Starting conditions

# Generate perturbed initial conditions
P0_ensemble, Z0_ensemble = generate_perturbed_initial_conditions(n_members, x_span, y_span, nx=5, nz=5)

# Simulate for all ensemble members
P_history_ensemble, Z_history_ensemble = run_ensemble_simulation(grid, params, timesteps=4000, P0_ensemble=P0_ensemble, Z0_ensemble=Z0_ensemble)

# Plot the results
plot_ensemble_trajectories_in_grid(P_history_ensemble, Z_history_ensemble, nx=5, nz=5)
